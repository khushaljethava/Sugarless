# %%
import pandas as pd

# %%
from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

# %%
# Function to convert   
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
  
    text = pytesseract.pytesseract.image_to_string(Image.open(filename))
    return text  # Then we will print the text in the image

# %%
images = convert_from_path('MBA SEM 4.pdf')
img=[]
texts = []
for i, image in enumerate(images):
    fname = "image" + str(i) + ".png"
    img.append(fname)
    
    image.save(fname, "PNG")
    text  =  ocr_core(fname)
    text = listToString(text)  
    texts.append(text)
    text1 = listToString(texts)

# %%
txt1 = text1

# %%
print(txt1)
# Out:
# PROCESSED AT: grmontsng Hemoglobin Aye Testing
# Thyrocare @JNGsP
# D-37/1,TTC MIDC,Turbhe, J
#
# Navi Mumbai-400 703 SESE
#
#
#
# abby Thyrocare’
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
#
#
# Think Thyroid. Think Thyrocare.
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
#
#
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT
#
# . (5311169953),PRABHU CLINICAL
# REF. BY + SELF LABORATORY,DR.YEKKALA RAMAKRISHNA
# TEST ASKED : HBA,HEMOGRAM - 6 PART (DIFF) HOSPITAL RAMARAOPETA NARSIPATNAM
#
# 531116,531116
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TEST NAME TECHNOLOGY VALUE UNITS
# HbAi1c - (HPLC - NGSP Certified)
# H.P.L.C 8.3 %
# Reference Range :
# Reference Range: As per ADA Guidelines Guidance For Known Diabetics
# Below 5.7% : Normal Below 6.5% : Good Control
# 5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control
# >=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control
# >8% : Poor Control
# Method : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.
# AVERAGE BLOOD GLUCOSE (ABG) CALCULATED 192 mg/dl
# Reference Range :
# 90 - 120 mg/dl : Good Control
# 121 - 150 mg/dl : Fair Control
# 151 - 180 mg/dl : Unsatisfactory Control
# > 180 mg/dl : Poor Control
# Method : Derived from HBA1c_ values
# Please correlate with clinical conditions.
# Sample Collected on (SCT) :26 Aug 2019 18:00
# Sample Received on (SRT) 27 Aug 2019 22:50 Goole?
# Report Released on (RRT) :28 Aug 2019 08:25 Oe <a
#
# Sample Type bres. #EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
# Labcode : 2708040370/A6750
#
# Re . Page : 1 of 9
# Barcode Ou :M9261080
# PROCESSED AT:
# Thyrocare
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703
#
# CAP
# ACCREDITED
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
#
#
# Thyrocare’
#
# Think Thyroid. Think Thyrocare.
#
#
#
# centiieAte no: C2407
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
#
#
#
#
# NAME MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :
#
# REF. BY + SELF (5311169953),PRABHU CLINICAL
# LABORATORY,DR.YEKKALA RAMAKRISHNA
#
# TEST ASKED HBA,HEMOGRAM - 6 PART (DIFF) HOSPITAL RAMARAOPETA NARSIPATNAM
# 531116,531116
#
# TEST NAME VALUE UNITS REFERENCE RANGE
#
# TOTAL LEUCOCYTES COUNT 6.4 X103/pL  4.0-10.0
#
# NEUTROPHILS 49.7 % 40-80
#
# LYMPHOCYTE PERCENTAGE 42.8 % 20-40
#
# MONOCYTES 2.3 % 0-10
#
# EOSINOPHILS 4.7 % 0.0-6.0
#
# BASOPHILS 0.2 % <2
#
# IMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.3 % 0-0.5
#
# NEUTROPHILS - ABSOLUTE COUNT 3.18 X103/uL  2.0-7.0
#
# LYMPHOCYTES - ABSOLUTE COUNT 2.74 X103/pL  1.0-3.0
#
# MONOCYTES - ABSOLUTE COUNT 0.15 X 103 / pL 0.2-1
#
# BASOPHILS - ABSOLUTE COUNT 0.01 X103/pL  0-0.1
#
# EOSINOPHILS - ABSOLUTE COUNT 0.3 X103/pL  0-0.5
#
# IMMATURE GRANULOCYTES(IG) 0.02 X103/pL  0-0.3
#
# TOTAL RBC 6.13 X1046/pL 4.5-5.5
#
# NUCLEATED RED BLOOD CELLS Nil X103/uL  <0.01
#
# NUCLEATED RED BLOOD CELLS % Nil % <0.01
#
# HEMOGLOBIN 18.1 g/dL 13-17
#
# HEMATOCRIT(PCV) 50.68 % 40-50
#
# MEAN CORPUSCULAR VOLUME(MCV) 100.2 fl 83-101
#
# MEAN CORPUSCULAR HEMOGLOBIN(MCH) 29.5 pq 27-32
#
# MEAN CORP.HEMO.CONC(MCHC) 29.5 g/dL 31.5-34.5
#
# RED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 62.9 fL 39-46
#
# RED CELL DISTRIBUTION WIDTH (RDW-CV) 17.6 % 11.6-14
#
# PLATELET DISTRIBUTION WIDTH(PDW) 11.1 fL 9.6-15.2
#
# MEAN PLATELET VOLUME(MPV) 9.4 fL 6.5-12
#
# PLATELET COUNT 222 X103/uL 150-400
#
# PLATELET TO LARGE CELL RATIO(PLCR) 20.5 % 19.7-42.4
#
# PLATELETCRIT(PCT) 0.21 % 0.19-0.39
#
# Remarks: ALERT !!! Anisocytosis
#
# Please Correlate with clinical conditions.
#
# Method : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)
#
# (This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow
# Cytometry Method (using a semiconductor laser), and SLS- hemoglobin method)
#
#
#
# Sample Collected on (SCT)
# Sample Received on (SRT)
# Report Released on (RRT)
# Sample Type
#
# Labcode
#
# Barcode
#
# :26 Aug 2019 18:00
# 227 Aug 2019 22:50
# :28 Aug 2019 08:25
# : EDTA
#
# : 2708040370/A6750
# : M9261080
#
# ln!
#
# ra
#
# Dr.Prachi Sinkar MD(Path)
#
# Dr.Caesar Sengupta MD(Micro)
# Page : 2 of 9
# PROCESSED AT:
#
# Thyrocare wi CAP orl Thyro Cc are’
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703 Think Thyroid. Think Thyrocare.
#
#
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
#
#
# REPORT
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT
#
# . (5311169953),PRABHU CLINICAL
#
# REF. BY + SELF LABORATORY,DR.YEKKALA RAMAKRISHNA
# TEST ASKED : AAROGYAM B HOSPITAL RAMARAOPETA NARSIPATNAM
# 531116,531116
#
# TEST NAME TECHNOLOGY VALUE UNITS
#
# IRON PHOTOMETRY 69.1 g/dl
# Reference Range :
#
# Male : 65-175
#
# Female : 50 - 170
#
# Method : _ FERROZINE METHOD WITHOUT DEPROTEINIZATION
#
# TOTAL IRON BINDING CAPACITY (TIBC) PHOTOMETRY 348 g/dl
# Reference Range :
#
# Male: 225 - 535 ug/dl Female: 215 - 535 ug/dl
#
# Method : _SPECTROPHOTOMETRIC ASSAY
#
# % TRANSFERRIN SATURATION CALCULATED 19.86 %
# Reference Range :
#
# 13-45
#
# Method : DERIVED FROM IRON AND TIBC VALUES
#
# Please correlate with clinical conditions.
#
#
#
# Sample Collected on (SCT) :26 Aug 2019 18:00
#
# Sample Received on (SRT) 127 Aug 2019 22:53 Goole?
#
# Report Released on (RRT) :28 Aug 2019 02:10 Oe <a
#
# Sample Type #SERUM Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
# Labcode 1 2708040550/A6750
#
# Page : 3 of 9
# Barcode =N7212022
# PROCESSED AT:
# Thyrocare
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703
#
#
#
# ecap,, Thyrocare’
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
#
#
# Think Thyroid. Think Thyrocare.
#
# CERTIFICATE NO.: NC=2007
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com www.thyrocare.com
#
#
#
#
#
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :
# REF. BY : SELF (5311169953), PRABHU CLINICAL
#
# LABORATORY, DR.YEKKALA RAMAKRISHNA HOSPITAL
# TEST ASKED  AAROGYAM B RAMARAOPETA NARSIPATNAM 531116,531116
# TEST NAME TECHNOLOGY VALUE UNITS NORMAL RANGE
# ALKALINE PHOSPHATASE PHOTOMETRY 64.5 U/L 45 - 129
# BILIRUBIN - TOTAL PHOTOMETRY 0.35 mg/dl 0.3-1.2
# BILIRUBIN -DIRECT PHOTOMETRY 0.08 mg/dl < 0.3
# BILIRUBIN (INDIRECT) CALCULATED 0.27 mg/dl 0-0.9
# GAMMA GLUTAMYL TRANSFERASE (GGT) PHOTOMETRY 91.1 u/I <55
# ASPARTATE AMINOTRANSFERASE (SGOT ) PHOTOMETRY 22.5 u/| <35
# ALANINE TRANSAMINASE (SGPT) PHOTOMETRY 21.4 u/| < 45
# PROTEIN - TOTAL PHOTOMETRY 6.6 gm/dl 5.7-8.2
# ALBUMIN - SERUM PHOTOMETRY 41 gm/dl 3.2-4.8
# SERUM ALB/GLOBULIN RATIO CALCULATED 1.64 Ratio 0.9-2
# SERUM GLOBULIN PHOTOMETRY 2.5 gm/dL 2.5-3.4
#
# Please correlate with clinical conditions.
#
# Method :
#
# ALKP - MODIFIED IFCC METHOD
#
# BILT - VANADATE OXIDATION
#
# BILD - VANADATE OXIDATION
#
# BILI - DERIVED FROM SERUM TOTAL AND DIRECT BILIRUBIN VALUES
# GGT - MODIFIED IFCC METHOD
#
# SGOT - IFCC* WITHOUT PYRIDOXAL PHOSPHATE ACTIVATION
# SGPT - IFCC* WITHOUT PYRIDOXAL PHOSPHATE ACTIVATION
# PROT - BIURET METHOD
#
# SALB - ALBUMIN BCG:METHOD (COLORIMETRIC ASSAY ENDPOINT)
# A/GR - DERIVED FROM SERUM ALBUMIN AND PROTEIN VALUES
# SEGB - DERIVED FROM SERUM ALBUMIN AND PROTEIN VALUES
#
# Sample Collected on (SCT) : 26 Aug 2019 18:00
#
# Sample Received on (SRT) : 27 Aug 2019 22:53 heen’
#
# Report Released on (RRT) : 28 Aug 2019 02:10 q OL “
#
# Sample Type : SERUM .
#
# Labcode : 2708040550/A6750 Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
#
# Barcode : N7212022 Page : 4 of 9
# PROCESSED AT:
# Thyrocare
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703
#
#
#
# ecap,, Thyrocare’
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
# canmwoheno. WOsor Think Thyroid. Think Thyrocare.
#
#
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com www.thyrocare.com
#
#
#
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :
# REF. BY : SELF (5311169953),PRABHU CLINICAL
# LABORATORY,DR.YEKKALA RAMAKRISHNA HOSPITAL
#
#
#
# TEST ASKED  AAROGYAM B RAMARAOPETA NARSIPATNAM 531116,531116
#
# TEST NAME TECHNOLOGY VALUE UNITS NORMAL RANGE
# TOTAL CHOLESTEROL PHOTOMETRY 220 mg/dl 125-200
#
# HDL CHOLESTEROL - DIRECT PHOTOMETRY 36 mg/dl 35-80
#
# LDL CHOLESTEROL - DIRECT PHOTOMETRY 167 mg/dl 85-130
# TRIGLYCERIDES PHOTOMETRY 188 mg/dl 25-200
#
# TC/ HDL CHOLESTEROL RATIO CALCULATED 6.1 Ratio 3-5
#
# LDL / HDL RATIO CALCULATED 4.7 Ratio 1.5-3.5
#
# VLDL CHOLESTEROL CALCULATED 37.6 mg/dl 5-40
#
# NON-HDL CHOLESTEROL CALCULATED 184.1 mg/dl < 160
#
#
#
# Please correlate with clinical conditions.
#
# Method :
#
# CHOL - CHOD POD METHOD
#
# HCHO - ENZYME SELECTIVE PROTECTION METHOD
#
# LDL - HOMOGENOUS ENZYMATIC COLORIMETRIC ASSAY
#
# TRIG - ENZYMATIC COLORIMETRIC METHOD (GPO) [HIGHLY INFLUENCED BY LEVEL OF FASTING]
# TC/H - DERIVED FROM SERUM CHOLESTEROL AND HDL VALUES
#
# LDL/ - DERIVED FROM SERUM HDL AND LDL VALUES
#
# VLDL - DERIVED FROM SERUM TRIGLYCERIDE VALUES
#
# NHDL - DERIVED FROM SERUM CHOLESTEROL AND HDL VALUES
#
# *REFERENCE RANGES AS PER NCEP ATP III GUIDELINES:
#
# TOTAL CHOLESTEROL (mg/dl) HDL (mg/dl) LDL (mg/dl) TRIGLYCERIDES (mg/dl)
#
# DESIRABLE <200 Low <40 OPTIMAL <100 NORMAL <150
#
# BORDERLINE HIGH 200-239 HIGH >60 NEAR OPTIMAL 100-129 BORDERLINE HIGH 150-199
#
# HIGH >240 BORDERLINE HIGH 130-159 HIGH 200-499
# HIGH 160-189 VERY HIGH >500
# VERY HIGH >190
#
# Alert !!! 10-12 hours fasting is mandatory for lipid parameters. If not, values might fluctuate.
#
# Sample Collected on (SCT) : 26 Aug 2019 18:00
#
# Sample Received on (SRT) : 27 Aug 2019 22:53 heen’
#
# Report Released on (RRT) : 28 Aug 2019 02:10 q OL “
#
# Sample Type : SERUM .
#
# Labcode : 2708040550/A6750 Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
#
# Barcode : N7212022 Page : 5 of 9
# PROCESSED AT:
#
#
#
# Thyrocare
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703 axa eno. Oe?
#
#
#
# ECAP, Thyrocare’
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
# Think Thyroid. Think Thyrocare.
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
#
#
# REPORT
#
#
#
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT
#
# . (5311169953),PRABHU CLINICAL
# REF. BY + SELF LABORATORY, DR.YEKKALA RAMAKRISHNA HOSPITAL
# TEST ASKED : AAROGYAM B RAMARAOPETA NARSIPATNAM 531116,531116
# TEST NAME TECHNOLOGY VALUE UNITS REFERENCE RANGE
# TOTAL TRIIODOTHYRONINE (T3) CLA 99 ng/dl 60-200
# TOTAL THYROXINE (T4) CLA 6.4 ug/dl 4.5-12
# THYROID STIMULATING HORMONE (TSH) CLA 3.42 uIU/ml 0.3-5.5
#
# Comments : SUGGESTING THYRONORMALCY
#
# Please correlate with clinical conditions.
#
# Method :
#
# T3 - COMPETITIVE CHEMI LUMINESCENT IMMUNO ASSAY
# T4 - COMPETITIVE CHEMI LUMINESCENT IMMUNO ASSAY
# TSH - SANDWICH CHEMI LUMINESCENT IMMUNO ASSAY
#
# Sample Collected on (SCT) : 26 Aug 2019 18:00
# Sample Received on (SRT) : 27 Aug 2019 22:53 ac tt?
# Report Released on (RRT) : 28 Aug 2019 02:10 Oe -
# Sample Type : SERUM oo. .
# Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
# Labcode : 2708040550/A6750
# Page : 6 of 9
#
# Barcode : N7212022
# PROCESSED AT:
# Thyrocare
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703
#
#
#
# ecap,, Thyrocare’
#
# COLLEGE of AMERICAN PATHOLOGISTS
#
#
#
# Think Thyroid. Think Thyrocare.
#
# CERTIFICATE NO.: NC=2007
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com www.thyrocare.com
#
#
#
# NAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :
# REF. BY : SELF (5311169953),PRABHU CLINICAL
# LABORATORY,DR.YEKKALA RAMAKRISHNA HOSPITAL
#
#
#
# TEST ASKED  AAROGYAM B RAMARAOPETA NARSIPATNAM 531116,531116
#
# TEST NAME TECHNOLOGY VALUE UNITS NORMAL RANGE
# BLOOD UREA NITROGEN (BUN) PHOTOMETRY 12.26 mg/dl 7-25
# CREATININE - SERUM PHOTOMETRY 0.74 mg/dl 0.6-1.1
#
# BUN / SR.CREATININE RATIO CALCULATED 16.57 Ratio 9:1-23:1
# CALCIUM PHOTOMETRY 9.16 mg/dl 8.8-10.6
#
# URIC ACID PHOTOMETRY 3.3 mg/dl 4.2 -7.3
#
# Please correlate with clinical conditions.
#
# Method :
#
# BUN - KINETIC UV ASSAY.
#
# SCRE - CREATININE ENZYMATIC METHOD
#
# B/CR - DERIVED FROM SERUM BUN AND CREATININE VALUES
# CALC - ARSENAZO III METHOD, END POINT.
#
# URIC - URICASE / PEROXIDASE METHOD
#
# Sample Collected on (SCT) : 26 Aug 2019 18:00
#
# Sample Received on (SRT) : 27 Aug 2019 22:53 heen’
#
# Report Released on (RRT) : 28 Aug 2019 02:10 q OL “
#
# Sample Type : SERUM .
#
# Labcode : 2708040550/A6750 Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
#
# Barcode : N7212022 Page : 7 of 9
# PROCESSED AT:
#
# Thyrocare Thyrocare’
#
# D-37/1,TTC MIDC,Turbhe,
# Navi Mumbai-400 703 Think Thyroid. Think Thyrocare.
#
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
#
#
# NAME = MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :
# REF. BY + SELF (5311169953),PRABHU CLINICAL
# ‘ . LABORATORY,DR.YEKKALA RAMAKRISHNA
# TEST ASKED : AAROGYAM B HOSPITAL RAMARAOPETA NARSIPATNAM
# 531116,531116
#
# TEST NAME TECHNOLOGY VALUE UNITS
# EST. GLOMERULAR FILTRATION RATE (eGFR) CALCULATED 117 mL/min/1.73 m2
#
# Reference Range :-
#
# > = 90 : Normal
# 60 - 89 : Mild Decrease
# 45-59 : Mild to Moderate Decrease
#
# 30-44 : Moderate to Severe Decrease
# 15-29 : Severe Decrease
#
# Clinical Significance
#
# The normal serum creatinine reference interval does not necessarily reflect a normal GFR for a patient. Because mild
# and moderate kidney injury is poorly inferred from serum creatinine alone. Thus, it is recommended for clinical
# laboratories to routinely estimate glomerular filtration rate (eGFR), a “gold standard” measurement for assessment of
# renal function, and report the value when serum creatinine is measured for patients 18 and older, when appropriate
# and feasible. It cannot be measured easily in clinical practice, instead, GFR is estimated from equations using serum
# creatinine, age, race and sex. This provides easy to interpret information for the doctor and patient on the degree of
# renal impairment since it approximately equates to the percentage of kidney function remaining. Application of
# CKD-EPI equation together with the other diagnostic tools in renal medicine will further improve the detection and
# management of patients with CKD.
#
# Reference
#
# Levey AS, Stevens LA, Schmid CH, Zhang YL, Castro AF, 3rd, Feldman HI, et al. A new equation to estimate glomerular
# filtration rate. Ann Intern Med. 2009;150(9):604-12.
#
# Please correlate with clinical conditions.
#
# Method:- CKD-EPI Creatinine Equation
#
# «ww End of report ~~
#
# Sample Collected on (SCT) : 26 Aug 2019 18:00
# Sample Received on (SRT) 127 Aug 2019 22:53 Goole?
# Report Released on (RRT) :28 Aug 2019 02:10 “ ™
#
# Sample Type bres: SERUM Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)
# Labcode : 2708040550/A6750
#
# Barcode RO :N7212022 Page : 8 of 9
# CONDITIONS OF REPORTING
#
# “ The reported results are for information and interpretation of the referring doctor only.
#
# “It is presumed that the tests performed on the specimen belong to the patient; named or identified.
#
# “Results of tests may vary from laboratory to laboratory and also in some parameters from time to time for the
# same patient.
#
# “Should the results indicate an unexpected abnormality, the same should be reconfirmed.
#
# “Only such medical professionals who understand reporting units, reference ranges and limitations of
# technologies should interpret results.
#
# “This report is not valid for medico-legal purpose.
#
# “Neither Thyrocare, nor its employees/representatives assume any liability, responsibility for any loss or
# damage that may be incurred by any person as a result of presuming the meaning or contents of the report.
#
# EXPLANATIONS
#
# “Majority of the specimen processed in the laboratory are collected by Pathologists and Hospitals we call them
# as "Clients".
#
# ~* Name - The name is as declared by the client and recored by the personnel who collected the specimen.
#
# “  Ref.Dr - The name of the doctor who has recommended testing as declared by the client.
#
# “ Labcode - This is the accession number in our laboratory and it helps us in archiving and retrieving the data.
#
# “Barcode - This is the specimen identity number and it states that the results are for the specimen bearing
# the barcode (irrespective of the name).
#
# SCP - Specimen Collection Point - This is the location where the blood or specimen was collected as declared by
# the client.
#
# “SCT - Specimen Collection Time - The time when specimen was collected as declared by the client.
#
# “SRT - Specimen Receiving Time - This time when the specimen reached our laboratory.
#
# “* RRT - Report Releasing Time - The time when our pathologist has released the values for Reporting.
#
# “ Reference Range - Means the range of values in which 95% of the normal population would fall.
#
# SUGGESTIONS
#
# “+ Values out of reference range requires reconfirmation before starting any medical treatment.
#
# “* Retesting is needed if you suspect any quality shortcomings.
#
# “* Testing or retesting should be done in accredited laboratories.
#
# “For suggestions, complaints or feedback, write to us at info@thyrocare.com or call us on
# 022-3090 0000 / 4125 2525
#
# “* SMS:<Labcode No.> to 9870666333
#
# Preventive Healthcare is now at your fingertips!
# t=)
# Booking
#
# Track your
# Confirmatios Technician
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rig tT Nt
#
#
#
#
#
# Ly
#
# Sample
# Testing
#
# =
# a &
# &
#
# explore & Select
# Test / Profil
#
#
#
#
#
#
#
# Blood
# Collection
#
#
#
#
#
#
#
#
#
# Focus TB
#
# Towards a TB free world
#
#
#
# “Fight TB with power of
# Rapid Technology”
#
#
#
#
#
#
#
#
#
#
#
# Focus TB, powered by Thyrocare.
# A brand that will focus on TB, which is one of the major public health
#
# problems in the country. Call : 022 - 3090 0000/4125 2525
#
# Tuberculosis (TB) is a transmissible, airborne infection caused by info@focustb.com
# Mycobacterium tuberculosis (MTB). \t transpires usually when a
# person inhales microscopic droplet nuclei containing viable
# bacteria, spread through coughing by persons who have
# infectious TB.
#
# Page : 9 of 9

# %%
print(texts)
# Out:
# ['PROCESSED AT: grmontsng Hemoglobin Aye Testing\nThyrocare @JNGsP\nD-37/1,TTC MIDC,Turbhe, J\n\nNavi Mumbai-400 703 SESE\n\n    \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME : MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT\n\n. (5311169953),PRABHU CLINICAL\nREF. BY + SELF LABORATORY,DR.YEKKALA RAMAKRISHNA\nTEST ASKED : HBA,HEMOGRAM - 6 PART (DIFF) HOSPITAL RAMARAOPETA NARSIPATNAM\n\n531116,531116\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nTEST NAME TECHNOLOGY VALUE UNITS\nHbAi1c - (HPLC - NGSP Certified)\nH.P.L.C 8.3 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 192 mg/dl\nReference Range :\n90 - 120 mg/dl : Good Control\n121 - 150 mg/dl : Fair Control\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\nSample Collected on (SCT) :26 Aug 2019 18:00\nSample Received on (SRT) 27 Aug 2019 22:50 Goole?\nReport Released on (RRT) :28 Aug 2019 08:25 Oe <a\n\nSample Type bres. #EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode : 2708040370/A6750\n\nRe . Page : 1 of 9\nBarcode Ou :M9261080\n\x0c', 'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\ncentiieAte no: C2407\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME MR SRIKANTH (38Y/M) SAMPLE COLLECTED AT :\n\nREF. BY + SELF (5311169953),PRABHU CLINICAL\nLABORATORY,DR.YEKKALA RAMAKRISHNA\n\nTEST ASKED HBA,HEMOGRAM - 6 PART (DIFF) HOSPITAL RAMARAOPETA NARSIPATNAM\n531116,531116\n\nTEST NAME VALUE UNITS REFERENCE RANGE\n\nTOTAL LEUCOCYTES COUNT 6.4 X103/pL  4.0-10.0\n\nNEUTROPHILS 49.7 % 40-80\n\nLYMPHOCYTE PERCENTAGE 42.8 % 20-40\n\nMONOCYTES 2.3 % 0-10\n\nEOSINOPHILS 4.7 % 0.0-6.0\n\nBASOPHILS 0.2 % <2\n\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.3 % 0-0.5\n\nNEUTROPHILS - ABSOLUTE COUNT 3.18 X103/uL  2.0-7.0\n\nLYMPHOCYTES - ABSOLUTE COUNT 2.74 X103/pL  1.0-3.0\n\nMONOCYTES - ABSOLUTE COUNT 0.15 X 103 / pL 0.2-1\n\nBASOPHILS - ABSOLUTE COUNT 0.01 X103/pL  0-0.1\n\nEOSINOPHILS - ABSOLUTE COUNT 0.3 X103/pL  0-0.5\n\nIMMATURE GRANULOCYTES(IG) 0.02 X103/pL  0-0.3\n\nTOTAL RBC 6.13 X1046/pL 4.5-5.5\n\nNUCLEATED RED BLOOD CELLS Nil X103/uL  <0.01\n\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\n\nHEMOGLOBIN 18.1 g/dL 13-17\n\nHEMATOCRIT(PCV) 50.68 % 40-50\n\nMEAN CORPUSCULAR VOLUME(MCV) 100.2 fl 83-101\n\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 29.5 pq 27-32\n\nMEAN CORP.HEMO.CONC(MCHC) 29.5 g/dL 31.5-34.5\n\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 62.9 fL 39-46\n\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 17.6 % 11.6-14\n\nPLATELET DISTRIBUTION WIDTH(PDW) 11.1 fL 9.6-15.2\n\nMEAN PLATELET VOLUME(MPV) 9.4 fL 6.5-12\n\nPLATELET COUNT 222 X103/uL 150-400\n\nPLATELET TO LARGE CELL RATIO(PLCR) 20.5 % 19.7-42.4\n\nPLATELETCRIT(PCT) 0.21 % 0.19-0.39\n\nRemarks: ALERT !!! Anisocytosis\n\nPlease Correlate with clinical conditions.\n\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semiconductor laser), and SLS- hemoglobin method)\n\n \n\nSample Collected on (SC ...

# %%
text1 = ocr_core('image1.png')

# %%
text1 = listToString(text1)

# %%
print(text1)

# %%
print(texts)

# %%
bad_chars = [';', ':', '!', "*", "\n", "-"]

# %%
# using replace() to  
# remove bad_chars  
for i in bad_chars : 
    test_string = txt1.replace(i, ' ')

# %%
test_string

# %%
text = listToString(texts)

# %%
for row in test_string.split('\n'):
    if row.startswith("TOTAL LEUCOCYTES COUNT "):
        total = row.split()
        total = total[0:4]
    if row.startswith("NEUTROPHILS"):
        NEUTROPHILS = row.split()

# %%
total

# %%
NEUTROPHILS

# %%
# Python3 code to demonstrate  
# removal of bad_chars 
# using join() + generator 
  
# initializing bad_chars_list 
bad_chars = [';', ':', '!', "*", "\n","COUNT"] 
  
# initializing test string  
test_string = "Ge;ek * s:fo ! r;Ge * e*k:s !"
  
# printing original string  
print ("Original String : " + test_string) 
  
# using join() + generator to  
# remove bad_chars  
test_string = ''.join(i for i in text1 if not i in bad_chars)

# %%
print(test_string)

# %%
for row in txt1.split(','):
    if row.startswith("TOTAL LEUCOCYTES COUNT "):
        total = row.split()
        total = total[0:4]
        
    if row.startswith("NEUTROPHILS"):
        NEUTROPHILS = row.split()

# %%
total

# %%
txt

# %%
total
