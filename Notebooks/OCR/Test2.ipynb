# %%
import pandas as pd

# %%
from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

# %%
# Function to convert   
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
def solve(lis):
    for x in lis:
        try:
            float(x)
            return True
        except:
            return False

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
  
    text = pytesseract.pytesseract.image_to_string(Image.open(filename))
    return text  # Then we will print the text in the image

# %%
images = convert_from_path('error_files/1.pdf')
img=[]
texts = []
for i, image in enumerate(images):
    fname = "image" + str(i) + ".png"
    img.append(fname)
    
    image.save(fname, "PNG")
    text  =  ocr_core(fname)
    text = text.replace(",",".")
  
    
    text = listToString(text)
    
    texts.append(text)
    text1 = listToString(texts)

# %%
print(text1)
# Out:
# PROCESSED AT :
#
# Thyrocare
#
# H. NO. 1-9-645.Vidyanagar.
#
# Adikmet Road.Near SBH.
#
# Hyderabad-500 044
# Corporate Office : Thyrocare Technologies Limited 9 D-37/3. TTC MIDC. Turbhe. Navi Mumbai - 400703
# © 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com
#
# Thyrocare’
#
# Think Thyroid. Think Thyrocare.
#
#
#
# REPORT
#
# NAME : MRS E LAXMI (26Y/F) SAMPLE COLLECTED AT
#
# 18900). GNOSTIC C a S: 1
# REF. BY : DR N VS SUDHA SARADA.MD OB GY ANDERS PRADESH SSO NARSIPATNAM
# TEST ASKED: PRL.T3-T4-TSH
# TEST NAME TECHNOLOGY VALUE UNITS
# PROLACTIN (PRL) CLA 19.87 ng/ml
#
# Reference Range :
#
# Females :
#
# Normally Menstruating : 2.8 - 29.2
#
# Pregnant : 9.7 - 208.5
#
# Postmenopausal : 1.8 - 20.3
#
# Male : 2.1 - 17.7
#
# Method : Fully Automated Bidirectionally Interfaced Chemi Luminescent Immuno Assay
#
# Please correlate with clinical conditions.
#
#
#
# Sample Collected on (SCT)
# Sample Received on (SRT)
# Report Released on (RRT)
#
# ...

# %%
#clean_text = text1.translate({ord(i): None for i in '-© !@#$%^&*_+=|\:;/?><,)'})

# %%
#text1

# %%
#print(clean_text)

# %% [markdown]
# for row in clean_text.split('/n'):
#     if row.startswith("TOTAL LEUCOCYTES"):
#         total = row.split()
#         total = total
#     if row.startswith("NEUTROPHILS"):
#         NEUTROPHILS = row.split()
#     if row.startswith("LYMPHOCYTE"):
#         LYMPHOCYTE = row.split()
#     if row.startswith("MONOCYTES"):
#         LYMPHOCYTE = row.split()
#     if row.startswith("EOSINOPHILS"):
#         EOSINOPHILS = row.split()
#     if row.startswith("BASOPHILS"):
#         BASOPHILS = row.split()
#     if row.startswith("IMMATURE GRANULOCYTE PERCENTAGE"):
#         IMMATURE = row.split()
#     if row.startswith("NUCLEATED RED BLOOD CELLS "):
#         NUCLEATED = row.split()
#     if row.startswith("HEMOGLOBIN"):
#         HEMOGLOBIN = row.split()
#     if row.startswith("HEMATOCRIT"):
#         HEMOGLOBIN = row.split()
#     if row.startswith("MEAN CORPUSCULAR VOLUME"):
#         CORPUSCULAR = row.split()
#     if row.startswith("VLDL CHOLESTEROL CALCULATED"):
#         VLDL = row.split()

# %%
#stopwords = ['COUNT','ABSOLUTE','TOTAL']
#querywords = clean_text.split()

#resultwords  = [word for word in querywords if word.lower() not in stopwords]
#result = ' '.join(resultwords)

#print(result)

# %% [markdown]
# wordlist = ['LEUCOCYTES COUNT','NEUTROPHILS','LYMPHOCYTE','MONOCYTES','EOSINOPHILS','BASOPHILS','IMMATURE GRANULOCYTE PERCENTAGE',
# 'NEUTROPHILS - ABSOLUTE COUNT','LYMPHOCYTES - ABSOLUTE COUNT','MONOCYTES - ABSOLUTE COUNT','BASOPHILS - ABSOLUTE COUNT','EOSINOPHILS - ABSOLUTE COUNT',
# 'IMMATURE GRANULOCYTES(IG)','TOTAL RBC','NUCLEATED RED BLOOD CELLS','NUCLEATED RED BLOOD CELLS','HEMOGLOBIN','HEMATOCRIT','MEAN CORPUSCULAR VOLUME',
# 'MEAN CORPUSCULAR HEMOGLOBIN','MEAN CORP.HEMO.CONC','RED CELL DISTRIBUTION WIDTH','RED CELL DISTRIBUTION WIDTH','PLATELET DISTRIBUTION WIDTH','MEAN PLATELET VOLUME',
# 'PLATELET','PLATELET TO LARGE CELL RATIO','PLATELETCRIT','IRON','TOTAL IRON BINDING CAPACITY','TRANSFERRIN SATURATION']

# %%
word_list = ['TOTAL LEUCOCYTES COUNT',
'NEUTROPHILS',
'LYMPHOCYTE PERCENTAGE',
'MONOCYTES',
'EOSINOPHILS',
'BASOPHILS',
'IMMATURE GRANULOCYTE PERCENTAGE(IG%)',
'NEUTROPHILS - ABSOLUTE COUNT',
'LYMPHOCYTES - ABSOLUTE COUNT',
'MONOCYTES - ABSOLUTE COUNT',
'BASOPHILS - ABSOLUTE COUNT',
'EOSINOPHILS - ABSOLUTE COUNT',
'IMMATURE GRANULOCYTES(IG)',
'TOTAL RBC',
'HEMOGLOBIN',
'HEMATOCRIT(PCV)',
'MEAN CORPUSCULAR VOLUME(MCV)',
'MEAN CORPUSCULAR HEMOGLOBIN(MCH)',
'MEAN CORP.HEMO.CONC(MCHC)',
'RED CELL DISTRIBUTION WIDTH - SD(RDW-SD)',
'RED CELL DISTRIBUTION WIDTH (RDW-CV)',
'PLATELET DISTRIBUTION WIDTH(PDW)',
'MEAN PLATELET VOLUME(MPV)',
'PLATELET COUNT',
'PLATELET TO LARGE CELL RATIO(PLCR)',
'PLATELETCRIT(PCT)',
'IRON',
'TOTAL IRON BINDING CAPACITY (TIBC)',
'TRANSFERRIN SATURATION',
'ALKALINE PHOSPHATASE',
'BILIRUBIN - TOTAL',
'BILIRUBIN -DIRECT',
'BILIRUBIN (INDIRECT)',
'GAMMA GLUTAMYL TRANSFERASE (GGT)',
'ASPARTATE AMINOTRANSFERASE (SGOT )',
'ALANINE TRANSAMINASE (SGPT)',
'PROTEIN - TOTAL',
'ALBUMIN - SERUM',
'SERUM ALB/GLOBULIN RATIO	',
'SERUM GLOBULIN',
'TOTAL CHOLESTEROL',
'HDL CHOLESTEROL - DIRECT',
'LDL CHOLESTEROL - DIRECT',
'TRIGLYCERIDES',
'TC/ HDL CHOLESTEROL RATIO',
'LDL / HDL RATIO',
'VLDL CHOLESTEROL',
'NON-HDL CHOLESTEROL',
'TOTAL TRIIODOTHYRONINE (T3)',
'TOTAL THYROXINE',
'THYROID STIMULATING HORMONE',
'BLOOD UREA NITROGEN (BUN)',
'CREATININE - SERUM',
'BUN / SR.CREATININE RATIO',
'CALCIUM',
'URIC ACID',
'EST. GLOMERULAR FILTRATION RATE',
]

# %% [markdown]
# word_new= ['LEUCOCYTES COUNT',
# 'NEUTROPHILS',
# 'LYMPHOCYTE PERCENTAGE',
# 'MONOCYTES',
# 'EOSINOPHILS',
# 'BASOPHILS',
# 'IMMATURE GRANULOCYT',
# 'NEUTROPHILS',
# 'LYMPHOCYTES',
# 'MONOCYTES',
# 'BASOPHILS',
# 'EOSINOPHILS',
# 'IMMATURE GRANULOCYTES(IG)',
# 'TOTAL RBC',
# 'NUCLEATED RED BLOOD CELLS',
# 'NUCLEATED RED BLOOD CELLS',
# 'HEMOGLOBIN',
# 'HEMATOCRIT',
# 'MEAN CORPUSCULAR VOLUME',
# 'MEAN CORPUSCULAR HEMOGLOBIN',
# 'MEAN CORP.HEMO.CONC',
# 'RED CELL DISTRIBUTION WIDTH',
# 'RED CELL DISTRIBUTION WIDTH',
# 'PLATELET DISTRIBUTION WIDTH',
# 'MEAN PLATELET VOLUME',
# 'PLATELET COUNT',
# 'PLATELET TO LARGE CELL RATIO',
# 'PLATELETCRIT',
# 'IRON',
# 'TOTAL IRON BINDING CAPACITY',
# 'TRANSFERRIN SATURATION',
# 'ALKALINE PHOSPHATASE',
# 'BILIRUBIN - TOTAL',
# 'BILIRUBIN -DIRECT',
# 'BILIRUBIN (INDIRECT)',
# 'GAMMA GLUTAMYL TRANSFERASE',
# 'ASPARTATE AMINOTRANSFERASE',
# 'ALANINE TRANSAMINASE',
# 'PROTEIN',
# 'ALBUMIN',
# 'SERUM ALB/GLOBULIN RATIO',
# 'SERUM GLOBULIN',
# 'TOTAL CHOLESTEROL',
# 'HDL CHOLESTEROL',
# 'LDL CHOLESTEROL',
# 'TRIGLYCERIDES',
# 'TC/ HDL CHOLESTEROL RATIO',
# 'LDL / HDL RATIO',
# 'VLDL CHOLESTEROL',
# 'NON-HDL CHOLESTEROL',
# 'TOTAL TRIIODOTHYRONINE',
# 'TOTAL THYROXINE',
# 'THYROID STIMULATING HORMONE',
# 'BLOOD UREA NITROGEN',
# 'CREATININE - SERUM',
# 'BUN / SR.CREATININE RATIO',
# 'CALCIUM',
# 'URIC ACID',
# 'EST. GLOMERULAR FILTRATION RATE',
# ]

# %%
stopwords = ['COUNT','X103pL','X103/pL','-','4.0-10.0','ABSOLUTE','X103/uL','2.0-7.0','1.0-3.0','%',
            'PERCENTAGE','20-40','PERCENTAGE(IG%)','0-0.5','IMMATURE', '40-80','0.0-6.0','0.0-6.0','0-0.1','mg/dl',
            '<2','0-10','<','>', 'X', '103', '/', 'pL', '0.2-1','X1046/pL', '<0.01','g/dL', '13-17','fl', '83-101',
            'pq', '27-32','g/dL', '31.5-34.5','0-0.3','40-50','fL', '39-46','11.6-14','9.6-15.2','4.5-5.5','g/dl',',',
           'DIRECT','PHOTOMETRY','CALCULATED','(eGFR)', 'Ratio', '9:1-23:1', '(mg/dl)', 'HDL', 'LDL', 'TRIGLYCERIDES',
             'mL/min/1.73', 'm2','uIU/ml', '0.3-5.5','85-130','35-80','125-200','gm/dL', '2.5-3.4','u/|', '<35','(',')',
            'u/I', '<55','gm/dl', '3.2-4.8''5.7-8.2','6.5-12','19.7-42.4','0.19-0.39','0.3-1.2','0-0.9','5.7-8.2',
            '3.2-4.8','3-5', 'ng/dl', '60-200','ug/dl', '4.5-12','7-25','0.6-1.1','8.8-10.6','-7.3','5-40','U/L','1.5-3.5',
            'RATIO','150-400','4.0-10.0','25-200']

# %%
for row in text1.split('\n'):
    for word in list(word_list):
        if row.startswith(word):
            word = row.split()
            word = word
            for word_name in list(word):  
                if word_name in stopwords:
                    word.remove(word_name)
                    
                
            print(word)
# Out:
# ['TOTAL', 'TRIIODOTHYRONINE', '(T3)', 'C.LLA', '159']
# ['TOTAL', 'THYROXINE', '(T4)', 'C.LLA', '9']
# ['THYROID', 'STIMULATING', 'HORMONE', '(TSH)', 'C.LLA', '1.80', 'UIU/ml']

# %%
data = []
for row in text1.split('\n'):
    for word in list(word_list):
        if row.startswith(word):
            word = row.split()
            word = word
            for word_name in list(word):  
                if word_name in stopwords:

                    word.remove(word_name)


                
            #print(word)
            for i in word:
                if  solve(i):
        #print(i)
                    null = i
                    word.remove(null)
                    i = float(i)
                    #word.remove(str(i))
        #i = [float(ele) for ele in i] 
        #i = float(i)
#        print(i)
        #new_list.append(i)
            
            word = [x for x in word if not isinstance(x, int)]   
            word = [' '.join(word)]
            #print(word))
            word.append(i)
            #word.remove(str(i))
            #print(word)
            data.append(word)

# %%
df = pd.DataFrame(data)

# %%
df.isnull()
# Out:
#        0      1
# 0  False  False
# 1  False  False
# 2  False  False

# %%
df
# Out:
#                                                 0      1
# 0               TOTAL TRIIODOTHYRONINE (T3) C.LLA  159.0
# 1                      TOTAL THYROXINE (T4) C.LLA    9.0
# 2  THYROID STIMULATING HORMONE (TSH) C.LLA UIU/ml    1.8

# %%
word
# Out:
# 'EST. GLOMERULAR FILTRATION RATE'

# %%
for row in text1.split('\n'):
    if row.startswith("NAME"):
        name = row.split()
    if row.startswith("LEUCOCYTES"):
        LEUCOCYTES = row.split()
    if row.startswith("NEUTROPHILS"):
        NEUTROPHILS = row.split()
    if row.startswith("LYMPHOCYTE"):
        LYMPHOCYTE = row.split()
    if row.startswith("MONOCYTES"):
        MONOCYTES = row.split()
    if row.startswith("EOSINOPHILS"):
        EOSINOPHILS = row.split()
    if row.startswith("BASOPHILS"):
        BASOPHILS = row.split()
    if row.startswith("IMMATURE GRANULOCYTE PERCENTAGE"):
        IMMATURE = row.split()
    if row.startswith("NUCLEATED RED BLOOD CELLS "):
        NUCLEATED = row.split()
    if row.startswith("HEMOGLOBIN"):
        HEMOGLOBIN = row.split()
    if row.startswith("HEMATOCRIT"):
        HEMOGLOBIN = row.split()
    if row.startswith("MEAN CORPUSCULAR VOLUME"):
        CORPUSCULAR = row.split()
    if row.startswith("VLDL CHOLESTEROL CALCULATED"):
        VLDL = row.split()

# %%
name
# Out:
# ['NAME', '=', 'MR', 'SRIKANTH', '(38Y/M)', 'SAMPLE', 'COLLECTED', 'AT', ':']

# %%
NEUTROPHILS
# Out:
# ['NEUTROPHILS', '-', 'ABSOLUTE', 'COUNT', '3.18', 'X103/uL', '2.0-7.0']

# %%
is_dig =  [x for x in NEUTROPHILS if solve(x)]

# %%
is_dig
# Out:
# ['3.18', '2.0-7.0']

# %%
is_dig.remove('2.0-7.0')

# %%
is_dig
# Out:
# ['3.18']

# %%
res = [x for x in is_dig if not (x.isdigit() 
                                         or x[0] == '-' and x[1:].isdigit())]

# %%
res

# %%
res = [float(ele) for ele in is_dig] 
#res = list(map(float, is_dig))

# %%
res

# %%
res = [x for x in is_dig if not isinstance(x, float)]

# %%
res

# %%
res = [x for x in NEUTROPHILS if not (x.isdigit() 
                                         or x[0] == '-' and x[1:].isdigit())]

# %%
print(res)

# %%
stopwords = ['COUNT', 'TOTAL','X103pL','X103/pL','4.0-10.0']
for word in list(total):  # iterating on a copy since removing will mess things up
    if word in stopwords:
        total.remove(word)

# %%
total

# %%
NEUTROPHILS

# %%
stopwords = ['COUNT', 'TOTAL','X103pL','X103/pL','4.0-10.0','ABSOLUTE','-','X103/uL','2.0-7.0']
for word in list(NEUTROPHILS):  # iterating on a copy since removing will mess things up
    if word in stopwords:
        NEUTROPHILS.remove(word)

# %%
NEUTROPHILS

# %%
stopwords = ['COUNT', 'TOTAL','X103pL','X103/pL','4.0-10.0','ABSOLUTE','-','X103/uL','2.0-7.0','1.0-3.0']
for word in list(LYMPHOCYTE):  # iterating on a copy since removing will mess things up
    if word in stopwords:
        LYMPHOCYTE.remove(word)

# %%
LYMPHOCYTE

# %%
my_list1 = ['text','test1','34','54.3']
is_dig =  [x for x in my_list1 if solve(x)]
res = [float(ele) for ele in is_dig] 
print(res)
print(is_dig)
# Out:
# [34.0, 54.3]
# ['34', '54.3']

# %%
new_list = []
for i in my_list1:
    if  solve(i):
        #print(i)
        i = float(i)
        #i = [float(ele) for ele in i] 
        #i = float(i)
        print(i)
        #new_list.append(i)
    else:
        print(i)
    
    new_list.append(i)
    


    

#for i in my_list1:
#    if i.isdigit():
#        res =  [x for x in i if solve(x)]
        #res = [float(ele) for ele in res] 
#        print(res)
        #print(res)
    
#    else:
#        print("its strings")
# Out:
# text
# test1
# 34.0
# 54.3

# %%
new_list
# Out:
# ['text', 'test1', 34.0, 54.3]

# %%
v
# Out:
# ['text', 'test1', [34.0], [54.3]]

# %%
j = len(new_list)

# %%
def concatenate_list_data(list):
    result= ''
    for element in list:
        result += str(element)
    return result

# %%
print(concatenate_list_data(new_list))
# Out:
# 34.054.3

# %%
my_list1
# Out:
# ['text', 'test1', '34', '54.3']

# %%
for i in my_list1:
     print(type(i)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
my_list1
# Out:
# ['text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
#  'test1',
#  '34',
#  '54.3',
#  'text',
# ...

# %%
mylist = ['text','test1','34','54.3']
new_list = []
for value in mylist:
    try:
        new_list.append(int(value))
        new_list.append(float(value))
    except ValueError:
        continue

# %%
new_list
# Out:
# [34, 34.0]

# %%
mylist
# Out:
# ['text', 'test1', '34', '54.3']
