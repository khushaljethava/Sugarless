# %%
import pandas as pd
import json

# %%
#Convert PDF to Images , each page converted into seprate image

from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

# %%
# Function to convert to Strings  
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
#function to find all floats values from list
def solve(lis):
    for x in lis:
        try:
            float(x)
            return True
        except:
            return False

# %%
# OCR Works Here

try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
  
    text = pytesseract.pytesseract.image_to_string(Image.open(filename))
    return text  # Then we will print the text in the image

# %%
# Main Functions for OCR
images = convert_from_path('a6.pdf')
img=[]
texts = []
for i, image in enumerate(images):
    fname = "image" + str(i) + ".png"
    img.append(fname)
    
    image.save(fname, "PNG")
    text  =  ocr_core(fname)
    
    text = listToString(text)  
    texts.append(text)
    text1 = listToString(texts)

# %%
text1
# Out:
# 'PROCESSED AT:\n\nThyrocare meCAP Thyro C ar eC\n\nD-37/1,TTC MIDC,Turbhe, COLLEGE of AMERICAN PATHOLOGISTS . . .\nNavi Mumbai-400 703 ceanthewo. NSsaor Think Thyroid. Think Thyrocare.\n\n   \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : MRS K DEVI (35Y/F) SAMPLE COLLECTED AT\n. (5311164139),MYTHRI MEDICAL CENTRE,MAIN RD,\nREF. BY : DR G VIJAYASANTHI MBBS DGO,OTHER NARSIPATNAM, ANDHRA PRADESH, 531116\nTEST ASKED : T3-T4-TSH\nTEST NAME TECHNOLOGY VALUE UNITS REFERENCE RANGE\nTOTAL TRIIODOTHYRONINE (T3) C.LI.A 118 ng/d| 60-200\nTOTAL THYROXINE (T4) C.L.L.A 12.9 ug/dl 4.5-12\nTHYROID STIMULATING HORMONE (TSH) C.LI.A 5.14 HIU/ml 0.3-5.5\n\nComments: IF NOT ON DRUGS SUGGESTED FT3 & FT4 ESTIMATION\n\nPlease correlate with clinical conditions.\n\nMethod :\n\nT3 - Competitive Chemi Luminescent Immuno Assay\n\nT4 - Competitive Chemi Luminescent Immuno Assay\nTSH - SANDWICH CHEMI LUMINESCENT IMMUNO ASSAY\nPregnancy reference ranges for TSH\n\n1st Trimester : 0.10 - 2.50\n\n2nd Trimester : 0.20 - 3.00\n\n3rd Trimester : 0.30 - 3.00\n\nReference:\nGuidelines of American Thyroid Association for the Diagnosis and Management of Thyroid Disease During\nPregnancy and Postpartum, Thyroid, 2011, 21; 1-46\n\n~~ End of report ~~\n\nSample Collected on (SCT) : 26 Aug 2019 17:00\n\nSample Received on (SRT) : 27 Aug 2019 22:52 ac tt?\nReport Released on (RRT) : 28 Aug 2019 02:22 Oe ea\n\nSample Type OF . © : SERUM io .\n= Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode : 2708040474/A6750\n\nF100) . Page : 1 of 2\nBarcode Ou : 00274398\n\x0cCONDITIONS OF REPORTING\n\n“ The reported results are for information and interpretation of the referring doctor only.\n\n“It is presumed that the tests performed on the specimen belong to the patient; named or identified.\n\n“Results of tests may vary from laboratory to laboratory and also in some parameters from time to time for the\nsame patient.\n\n“Should the results indicate an unexpected abnormality, the same should be reconfirmed.\n\n“Only such medical professionals who understand reporting units, reference ranges and limitations of\ntechnologies should interpret results.\n\n“This report is not valid for medico-legal purpose.\n\n“Neither Thyrocare, nor its employees/representatives assume any liability, responsibility for any loss or\ndamage that may be incurred by any person as a result of presuming the meaning or contents of the report.\n\nEXPLANATIONS\n\n“Majority of the specimen processed in the laboratory are collected by Pathologists and Hospitals we call them\nas "Clients".\n\n~* Name - The name is as declared by the client and recored by the personnel who collected the specimen.\n\n“  Ref.Dr - The name of the doctor who has recommended testing as declared by the client.\n\n“ Labcode - This is the accession number in our laboratory and it helps us in archiving and retrieving the data.\n\n“Barcode - This is the specimen identity number and it states that the results are for the specimen bearing\nthe barcode (irrespective of the name).\n\nSCP - Specimen Collection Point - This is the location where the blood or specimen was collected as declared by\nthe client.\n\n“SCT - Specimen Collection Time - The time when specimen was collected as declared by the client.\n\n“SRT - Specimen Receiving Time - This time when the specimen reached our laboratory.\n\n“* RRT - Report Releasing Time - The time when our pathologist has released the values for Reporting.\n\n“ Reference Range - Means the range of values in which 95% of the normal population would fall.\n\nSUGGESTIONS\n\n“+ Values out of reference range requires reconfirmation before starting any medical treatment.\n\n“* Retesting is needed if you suspect any quality shortcomings.\n\n“* Testing or retesting should be done in accredited laboratories.\n\n“For suggestions, complaints or f ...

# %%
# Word List for Keywords to Fetch Info
word_list = [
'H.P.L.C',
'AVERAGE BLOOD GLUCOSE (ABG)',
'TOTAL LEUCOCYTES COUNT',
'NEUTROPHILS',
'LYMPHOCYTE PERCENTAGE',
'MONOCYTES',
'EOSINOPHILS',
'BASOPHILS',
'IMMATURE GRANULOCYTE PERCENTAGE(IG%)',
'NEUTROPHILS - ABSOLUTE COUNT',
'LYMPHOCYTES - ABSOLUTE COUNT',
'MONOCYTES - ABSOLUTE COUNT',
'BASOPHILS - ABSOLUTE COUNT',
'EOSINOPHILS - ABSOLUTE COUNT',
'IMMATURE GRANULOCYTES(IG)',
'TOTAL RBC',
'NUCLEATED RED BLOOD CELLS',
'HEMOGLOBIN',
'HEMATOCRIT(PCV)',
'MEAN CORPUSCULAR VOLUME(MCV)',
'MEAN CORPUSCULAR HEMOGLOBIN(MCH)',
'MEAN CORP.HEMO.CONC(MCHC)',
'RED CELL DISTRIBUTION WIDTH - SD(RDW-SD)',
'RED CELL DISTRIBUTION WIDTH (RDW-CV)',
'PLATELET DISTRIBUTION WIDTH(PDW)',
'MEAN PLATELET VOLUME(MPV)',
'PLATELET COUNT',
'PLATELET TO LARGE CELL RATIO(PLCR)',
'PLATELETCRIT(PCT)',
'IRON',
'TOTAL IRON BINDING CAPACITY (TIBC)',
'TRANSFERRIN SATURATION',
'ALKALINE PHOSPHATASE',
'BILIRUBIN - TOTAL',
'BILIRUBIN -DIRECT',
'BILIRUBIN (INDIRECT)',
'GAMMA GLUTAMYL TRANSFERASE (GGT)',
'ASPARTATE AMINOTRANSFERASE (SGOT )',
'ALANINE TRANSAMINASE (SGPT)',
'PROTEIN - TOTAL',
'ALBUMIN - SERUM',
'SERUM ALB/GLOBULIN RATIO',
'SERUM GLOBULIN',
'TOTAL CHOLESTEROL',
'HDL CHOLESTEROL - DIRECT',
'LDL CHOLESTEROL - DIRECT',
'TRIGLYCERIDES',
'TC/ HDL CHOLESTEROL RATIO',
'LDL / HDL RATIO',
'VLDL CHOLESTEROL',
'NON-HDL CHOLESTEROL',
'TOTAL TRIIODOTHYRONINE (T3)',
'TOTAL THYROXINE',
'THYROID STIMULATING HORMONE',
'BLOOD UREA NITROGEN (BUN)',
'CREATININE - SERUM',
'BUN / SR.CREATININE RATIO',
'CALCIUM',
'URIC ACID',
'EST. GLOMERULAR FILTRATION RATE',
]

# %%
# Wordlist to Delete Useless data from the list
stopwords = ['X103pL','X103/pL','-','4.0-10.0','X103/uL','2.0-7.0','1.0-3.0','%',
            '20-40','0-0.5', '40-80','0.0-6.0','0.0-6.0','0-0.1','mg/dl',
            '<2','0-10','<','>', 'X', '103', 'pL', '0.2-1','X1046/pL', '<0.01','g/dL', '13-17','fl', '83-101',
            'pq', '27-32','g/dL', '31.5-34.5','0-0.3','40-50','fL', '39-46','11.6-14','9.6-15.2','4.5-5.5','g/dl',
           'PHOTOMETRY','CALCULATED','(eGFR)', 'Ratio', '9:1-23:1', '(mg/dl)',
             'mL/min/1.73', 'm2','uIU/ml', '0.3-5.5','85-130','35-80','125-200','gm/dL', '2.5-3.4','u/|', '<35','(',')',
            'u/I', '<55','gm/dl', '3.2-4.8''5.7-8.2','6.5-12','19.7-42.4','0.19-0.39','0.3-1.2','0-0.9','5.7-8.2',
            '3.2-4.8','3-5', 'ng/dl', '60-200','ug/dl', '4.5-12','7-25','0.6-1.1','8.8-10.6','-7.3','5-40','U/L','1.5-3.5',
            '150-400','4.0-10.0','25-200','/','B12 pg/mL 911','B12' ,'pg/mL' ,'911',]

# %%
# Main function to collect the data

data = []
for row in text1.split('\n'):
    for word in list(word_list):
        if row.startswith(word):
            word = row.split()
            word = word
            for word_name in list(word):  
                if word_name in stopwords:

                    word.remove(word_name)
 
            for i in word:
                if  solve(i):
                    null = i
                    word.remove(null)
                    i = float(i)
            
            word = [x for x in word if not isinstance(x, int)]   
            word = [' '.join(word)]
            print(word)
            word.append(i)
            #word.remove(str(i))
            print(word)
            data.append(word)
# Out:
# ['H.P.L.C']
# ['H.P.L.C', 8.3]
# ['AVERAGE BLOOD GLUCOSE (ABG)']
# ['AVERAGE BLOOD GLUCOSE (ABG)', 192.0]
# ['TOTAL LEUCOCYTES COUNT']
# ['TOTAL LEUCOCYTES COUNT', 6.4]
# ['NEUTROPHILS']
# ['NEUTROPHILS', 49.7]
# ['LYMPHOCYTE PERCENTAGE']
# ['LYMPHOCYTE PERCENTAGE', 42.8]
# ['MONOCYTES']
# ['MONOCYTES', 2.3]
# ['EOSINOPHILS']
# ['EOSINOPHILS', 4.7]
# ['BASOPHILS']
# ['BASOPHILS', 0.2]
# ['IMMATURE GRANULOCYTE PERCENTAGE(IG%)']
# ['IMMATURE GRANULOCYTE PERCENTAGE(IG%)', 0.3]
# ['NEUTROPHILS ABSOLUTE COUNT']
# ['NEUTROPHILS ABSOLUTE COUNT', 3.18]
# ['NEUTROPHILS ABSOLUTE COUNT']
# ['NEUTROPHILS ABSOLUTE COUNT', 3.18]
# ['LYMPHOCYTES ABSOLUTE COUNT']
# ['LYMPHOCYTES ABSOLUTE COUNT', 2.74]
# ['MONOCYTES ABSOLUTE COUNT']
# ['MONOCYTES ABSOLUTE COUNT', 0.15]
# ['MONOCYTES ABSOLUTE COUNT']
# ['MONOCYTES ABSOLUTE COUNT', 0.15]
# ['BASOPHILS ABSOLUTE COUNT']
# ['BASOPHILS ABSOLUTE COUNT', 0.01]
# ['BASOPHILS ABSOLUTE COUNT']
# ['BASOPHILS ABSOLUTE COUNT', 0.01]
# ['EOSINOPHILS ABSOLUTE COUNT']
# ['EOSINOPHILS ABSOLUTE COUNT', 0.3]
# ['EOSINOPHILS ABSOLUTE COUNT']
# ['EOSINOPHILS ABSOLUTE COUNT', 0.3]
# ['IMMATURE GRANULOCYTES(IG)']
# ['IMMATURE GRANULOCYTES(IG)', 0.02]
# ['TOTAL RBC']
# ['TOTAL RBC', 6.13]
# ['NUCLEATED RED BLOOD CELLS Nil']
# ['NUCLEATED RED BLOOD CELLS Nil', 'Nil']
# ['NUCLEATED RED BLOOD CELLS Nil']
# ['NUCLEATED RED BLOOD CELLS Nil', 'Nil']
# ['HEMOGLOBIN']
# ['HEMOGLOBIN', 18.1]
# ['HEMATOCRIT(PCV)']
# ['HEMATOCRIT(PCV)', 50.68]
# ['MEAN CORPUSCULAR VOLUME(MCV)']
# ['MEAN CORPUSCULAR VOLUME(MCV)', 100.2]
# ['MEAN CORPUSCULAR HEMOGLOBIN(MCH)']
# ['MEAN CORPUSCULAR HEMOGLOBIN(MCH)', 29.5]
# ['MEAN CORP.HEMO.CONC(MCHC)']
# ['MEAN CORP.HEMO.CONC(MCHC)', 29.5]
# ['RED CELL DISTRIBUTION WIDTH SD(RDW-SD)']
# ['RED CELL DISTRIBUTION WIDTH SD(RDW-SD)', 62.9]
# ['RED CELL DISTRIBUTION WIDTH (RDW-CV)']
# ['RED CELL DISTRIBUTION WIDTH (RDW-CV)', 17.6]
# ['PLATELET DISTRIBUTION WIDTH(PDW)']
# ['PLATELET DISTRIBUTION WIDTH(PDW)', 11.1]
# ['MEAN PLATELET VOLUME(MPV)']
# ['MEAN PLATELET VOLUME(MPV)', 9.4]
# ['PLATELET COUNT']
# ['PLATELET COUNT', 222.0]
# ['PLATELET TO LARGE CELL RATIO(PLCR)']
# ['PLATELET TO LARGE CELL RATIO(PLCR)', 20.5]
# ['PLATELETCRIT(PCT)']
# ['PLATELETCRIT(PCT)', 0.21]
# ['IRON']
# ['IRON', 69.1]
# ['TOTAL IRON BINDING CAPACITY (TIBC)']
# ['TOTAL IRON BINDING CAPACITY (TIBC)', 348.0]
# ['ALKALINE PHOSPHATASE 45']
# ['ALKALINE PHOSPHATASE 45', 129.0]
# ['BILIRUBIN TOTAL']
# ['BILIRUBIN TOTAL', 0.35]
# ['BILIRUBIN -DIRECT 0.3']
# ['BILIRUBIN -DIRECT 0.3', 0.08]
# ['BILIRUBIN (INDIRECT)']
# ['BILIRUBIN (INDIRECT)', 0.27]
# ['GAMMA GLUTAMYL TRANSFERASE (GGT)']
# ['GAMMA GLUTAMYL TRANSFERASE (GGT)', 91.1]
# ['ASPARTATE AMINOTRANSFERASE (SGOT']
# ['ASPARTATE AMINOTRANSFERASE (SGOT', 22.5]
# ['ALANINE TRANSAMINASE (SGPT) 45']
# ['ALANINE TRANSAMINASE (SGPT) 45', 21.4]
# ['PROTEIN TOTAL']
# ['PROTEIN TOTAL', 6.6]
# ['ALBUMIN SERUM']
# ['ALBUMIN SERUM', 41.0]
# ['SERUM ALB/GLOBULIN RATIO 0.9-2']
# ['SERUM ALB/GLOBULIN RATIO 0.9-2', 1.64]
# ['SERUM GLOBULIN']
# ['SERUM GLOBULIN', 2.5]
# ['TOTAL CHOLESTEROL']
# ['TOTAL CHOLESTEROL', 220.0]
# ['HDL CHOLESTEROL DIRECT']
# ['HDL CHOLESTEROL DIRECT', 36.0]
# ['LDL CHOLESTEROL DIRECT']
# ['LDL CHOLESTEROL DIRECT', 167.0]
# ['TRIGLYCERIDES']
# ['TRIGLYCERIDES', 188.0]
# ['TC/ HDL CHOLESTEROL RATIO']
# ['TC/ HDL CHOLESTEROL RATIO', 6.1]
# ['LDL HDL RATIO']
# ['LDL HDL RATIO', 4.7]
# ['VLDL CHOLESTEROL']
# ['VLDL CHOLESTEROL', 37.6]
# ['NON-HDL CHOLESTEROL 160']
# ['NON-HDL CHOLESTEROL 160', 184.1]
# ['TOTAL CHOLESTEROL HDL LDL TRIGLYCERIDES']
# ['TOTAL CHOLESTEROL HDL LDL TRIGLYCERIDES', 'TRIGLYCERIDES']
# ['TOTAL TRIIODOTHYRONINE (T3) CLA']
# ['TOTAL TRIIODOTHYRONINE (T3) CLA', 99.0]
# ['TOTAL THYROXINE (T4) CLA']
# ['TOTAL THYROXINE (T4) CLA', 6.4]
# ['THYROID STIMULATING HORMONE (TSH) CLA']
# ['THYROID STIMULATING HORMONE (TSH) CLA', 3.42]
# ['BLOOD UREA NITROGEN (BUN)']
# ['BLOOD UREA NITROGEN (BUN)', 12.26]
# ['CREATININE SERUM']
# ['CREATININE SERUM', 0.74]
# ['BUN SR.CREATININE RATIO']
# ['BUN SR.CREATININE RATIO', 16.57]
# ['CALCIUM']
# ['CALCIUM', 9.16]
# ['URIC ACID 4.2']
# ['URIC ACID 4.2', 3.3]
# ['EST. GLOMERULAR FILTRATION RATE']
# ['EST. GLOMERULAR FILTRATION RATE', 117.0]

# %%
data1 = dict(data)

# %%
data1['NEUTROPHILS']
# Out:
# 49.7

# %%
columns_name = ['Keywords','Values']

# %%
df = pd.DataFrame(data)
df.head(60)
# Out:
#                                           0              1
# 0                                   H.P.L.C            8.3
# 1               AVERAGE BLOOD GLUCOSE (ABG)            192
# 2                    TOTAL LEUCOCYTES COUNT            6.4
# 3                               NEUTROPHILS           49.7
# 4                     LYMPHOCYTE PERCENTAGE           42.8
# 5                                 MONOCYTES            2.3
# 6                               EOSINOPHILS            4.7
# 7                                 BASOPHILS            0.2
# 8      IMMATURE GRANULOCYTE PERCENTAGE(IG%)            0.3
# 9                NEUTROPHILS ABSOLUTE COUNT           3.18
# 10               NEUTROPHILS ABSOLUTE COUNT           3.18
# 11               LYMPHOCYTES ABSOLUTE COUNT           2.74
# 12                 MONOCYTES ABSOLUTE COUNT           0.15
# 13                 MONOCYTES ABSOLUTE COUNT           0.15
# 14                 BASOPHILS ABSOLUTE COUNT           0.01
# 15                 BASOPHILS ABSOLUTE COUNT           0.01
# 16               EOSINOPHILS ABSOLUTE COUNT            0.3
# 17               EOSINOPHILS ABSOLUTE COUNT            0.3
# 18                IMMATURE GRANULOCYTES(IG)           0.02
# 19                                TOTAL RBC           6.13
# 20            NUCLEATED RED BLOOD CELLS Nil            Nil
# 21            NUCLEATED RED BLOOD CELLS Nil            Nil
# 22                               HEMOGLOBIN           18.1
# 23                          HEMATOCRIT(PCV)          50.68
# 24             MEAN CORPUSCULAR VOLUME(MCV)          100.2
# 25         MEAN CORPUSCULAR HEMOGLOBIN(MCH)           29.5
# 26                MEAN CORP.HEMO.CONC(MCHC)           29.5
# 27   RED CELL DISTRIBUTION WIDTH SD(RDW-SD)           62.9
# 28     RED CELL DISTRIBUTION WIDTH (RDW-CV)           17.6
# 29         PLATELET DISTRIBUTION WIDTH(PDW)           11.1
# 30                MEAN PLATELET VOLUME(MPV)            9.4
# 31                           PLATELET COUNT            222
# 32       PLATELET TO LARGE CELL RATIO(PLCR)           20.5
# 33                        PLATELETCRIT(PCT)           0.21
# 34                                     IRON           69.1
# 35       TOTAL IRON BINDING CAPACITY (TIBC)            348
# 36                  ALKALINE PHOSPHATASE 45            129
# 37                          BILIRUBIN TOTAL           0.35
# 38                    BILIRUBIN -DIRECT 0.3           0.08
# 39                     BILIRUBIN (INDIRECT)           0.27
# 40         GAMMA GLUTAMYL TRANSFERASE (GGT)           91.1
# 41         ASPARTATE AMINOTRANSFERASE (SGOT           22.5
# 42           ALANINE TRANSAMINASE (SGPT) 45           21.4
# 43                            PROTEIN TOTAL            6.6
# 44                            ALBUMIN SERUM             41
# 45           SERUM ALB/GLOBULIN RATIO 0.9-2           1.64
# 46                           SERUM GLOBULIN            2.5
# 47                        TOTAL CHOLESTEROL            220
# 48                   HDL CHOLESTEROL DIRECT             36
# 49                   LDL CHOLESTEROL DIRECT            167
# 50                            TRIGLYCERIDES            188
# 51                TC/ HDL CHOLESTEROL RATIO            6.1
# 52                            LDL HDL RATIO            4.7
# 53                         VLDL CHOLESTEROL           37.6
# 54                  NON-HDL CHOLESTEROL 160          184.1
# 55  TOTAL CHOLESTEROL HDL LDL TRIGLYCERIDES  TRIGLYCERIDES
# 56          TOTAL TRIIODOTHYRONINE (T3) CLA             99
# 57                 TOTAL THYROXINE (T4) CLA            6.4
# 58    THYROID STIMULATING HORMONE (TSH) CLA           3.42
# 59                BLOOD UREA NITROGEN (BUN)          12.26

# %%
df.columns = ['Keys','Values']

# %%
df
# Out:
#                                Keys Values
# 0                           H.P.L.C    8.3
# 1       AVERAGE BLOOD GLUCOSE (ABG)    192
# 2            TOTAL LEUCOCYTES COUNT    6.4
# 3                       NEUTROPHILS   49.7
# 4             LYMPHOCYTE PERCENTAGE   42.8
# ..                              ...    ...
# 60                 CREATININE SERUM   0.74
# 61          BUN SR.CREATININE RATIO  16.57
# 62                          CALCIUM   9.16
# 63                    URIC ACID 4.2    3.3
# 64  EST. GLOMERULAR FILTRATION RATE    117
#
# [65 rows x 2 columns]

# %%
df['Keys'] = df['Keys'].str.replace('\d+', '')

# %%
df.head(60)
# Out:
#                                        Keys         Values
# 0                                   H.P.L.C            8.3
# 1               AVERAGE BLOOD GLUCOSE (ABG)            192
# 2                    TOTAL LEUCOCYTES COUNT            6.4
# 3                               NEUTROPHILS           49.7
# 4                     LYMPHOCYTE PERCENTAGE           42.8
# 5                                 MONOCYTES            2.3
# 6                               EOSINOPHILS            4.7
# 7                                 BASOPHILS            0.2
# 8      IMMATURE GRANULOCYTE PERCENTAGE(IG%)            0.3
# 9                NEUTROPHILS ABSOLUTE COUNT           3.18
# 10               NEUTROPHILS ABSOLUTE COUNT           3.18
# 11               LYMPHOCYTES ABSOLUTE COUNT           2.74
# 12                 MONOCYTES ABSOLUTE COUNT           0.15
# 13                 MONOCYTES ABSOLUTE COUNT           0.15
# 14                 BASOPHILS ABSOLUTE COUNT           0.01
# 15                 BASOPHILS ABSOLUTE COUNT           0.01
# 16               EOSINOPHILS ABSOLUTE COUNT            0.3
# 17               EOSINOPHILS ABSOLUTE COUNT            0.3
# 18                IMMATURE GRANULOCYTES(IG)           0.02
# 19                                TOTAL RBC           6.13
# 20            NUCLEATED RED BLOOD CELLS Nil            Nil
# 21            NUCLEATED RED BLOOD CELLS Nil            Nil
# 22                               HEMOGLOBIN           18.1
# 23                          HEMATOCRIT(PCV)          50.68
# 24             MEAN CORPUSCULAR VOLUME(MCV)          100.2
# 25         MEAN CORPUSCULAR HEMOGLOBIN(MCH)           29.5
# 26                MEAN CORP.HEMO.CONC(MCHC)           29.5
# 27   RED CELL DISTRIBUTION WIDTH SD(RDW-SD)           62.9
# 28     RED CELL DISTRIBUTION WIDTH (RDW-CV)           17.6
# 29         PLATELET DISTRIBUTION WIDTH(PDW)           11.1
# 30                MEAN PLATELET VOLUME(MPV)            9.4
# 31                           PLATELET COUNT            222
# 32       PLATELET TO LARGE CELL RATIO(PLCR)           20.5
# 33                        PLATELETCRIT(PCT)           0.21
# 34                                     IRON           69.1
# 35       TOTAL IRON BINDING CAPACITY (TIBC)            348
# 36                    ALKALINE PHOSPHATASE             129
# 37                          BILIRUBIN TOTAL           0.35
# 38                      BILIRUBIN -DIRECT .           0.08
# 39                     BILIRUBIN (INDIRECT)           0.27
# 40         GAMMA GLUTAMYL TRANSFERASE (GGT)           91.1
# 41         ASPARTATE AMINOTRANSFERASE (SGOT           22.5
# 42             ALANINE TRANSAMINASE (SGPT)            21.4
# 43                            PROTEIN TOTAL            6.6
# 44                            ALBUMIN SERUM             41
# 45              SERUM ALB/GLOBULIN RATIO .-           1.64
# 46                           SERUM GLOBULIN            2.5
# 47                        TOTAL CHOLESTEROL            220
# 48                   HDL CHOLESTEROL DIRECT             36
# 49                   LDL CHOLESTEROL DIRECT            167
# 50                            TRIGLYCERIDES            188
# 51                TC/ HDL CHOLESTEROL RATIO            6.1
# 52                            LDL HDL RATIO            4.7
# 53                         VLDL CHOLESTEROL           37.6
# 54                     NON-HDL CHOLESTEROL           184.1
# 55  TOTAL CHOLESTEROL HDL LDL TRIGLYCERIDES  TRIGLYCERIDES
# 56           TOTAL TRIIODOTHYRONINE (T) CLA             99
# 57                  TOTAL THYROXINE (T) CLA            6.4
# 58    THYROID STIMULATING HORMONE (TSH) CLA           3.42
# 59                BLOOD UREA NITROGEN (BUN)          12.26
