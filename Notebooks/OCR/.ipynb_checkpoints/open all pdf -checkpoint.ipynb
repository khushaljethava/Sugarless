# %%
# Out:
# 7765

# %%
import pandas as pd
import json
import os

# %%
#Convert PDF to Images , each page converted into seprate image

from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

# %%
# Function to convert to Strings  
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
#function to find all floats values from list
def solve(lis):
    for x in lis:
        try:
            float(x)
            return True
        except:
            return False

# %%
# OCR Works Here

try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
  
    text = pytesseract.pytesseract.image_to_string(Image.open(filename))
    return text  # Then we will print the text in the image

# %%
word_list = [
    'HbA1c',
    'H.P.L.C',
    'AVERAGE BLOOD GLUCOSE (ABG)',
    'TOTAL LEUCOCYTES COUNT',
    'NEUTROPHILS',
    'LYMPHOCYTE PERCENTAGE',
    'MONOCYTES',
    'EOSINOPHILS',
    'BASOPHILS',
    'IMMATURE GRANULOCYTE PERCENTAGE(IG%)',
    'NEUTROPHILS - ABSOLUTE COUNT',
    'LYMPHOCYTES - ABSOLUTE COUNT',
    'MONOCYTES - ABSOLUTE COUNT',
    'BASOPHILS - ABSOLUTE COUNT',
    'EOSINOPHILS - ABSOLUTE COUNT',
    'IMMATURE GRANULOCYTES(IG)',
    'TOTAL RBC',
    'HEMOGLOBIN',
    'HEMATOCRIT(PCV)',
    'MEAN CORPUSCULAR VOLUME(MCV)',
    'MEAN CORPUSCULAR HEMOGLOBIN(MCH)',
    'MEAN CORP.HEMO.CONC(MCHC)',
    'RED CELL DISTRIBUTION WIDTH - SD(RDW-SD)',
    'RED CELL DISTRIBUTION WIDTH (RDW-CV)',
    'PLATELET DISTRIBUTION WIDTH(PDW)',
    'MEAN PLATELET VOLUME(MPV)',
    'PLATELET COUNT',
    'PLATELET TO LARGE CELL RATIO(PLCR)',
    'PLATELETCRIT(PCT)',
    'ARSENIC',
    'CADMIUM',
    'MERCURY',
    'LEAD',
    'CHROMIUM',
    'BARIUM',
    'COBALT',
    'CAESIUM',
    'THALLIUM',
    'URANIUM',
    'STRONTIUM',
    'ANTIMONY',
    'TIN',
    'MOLYBDENUM',
    'SILVER',
    'VANADIUM',
    'BERYLLIUM',
    'BISMUTH',
    'SELENIUM',
    'ALUMINIUM',
    'NICKEL',
    'MANGANESE',
    'HOMOCYSTEINE',
    'CYSTATIN C',
    'LIPOPROTEIN',
    'VITAMIN D',
    'VITAMIN B-12',
    'APOLIPOPROTEIN - A1 (APO-A1)',
    'APOLIPOPROTEIN - B (APO-B)',
    'APO B / APO A1 RATIO (APO B/A1)',
    'HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)',
    'SERUM COPPER',
    'SERUM ZINC',
    'TESTOSTERONE',
    'IRON',
    'TOTAL IRON BINDING CAPACITY (TIBC)',
    '% TRANSFERRIN SATURATION',
    'TRANSFERRIN SATURATION',
    'ALKALINE PHOSPHATASE',
    'BILIRUBIN - TOTAL',
    'BILIRUBIN -DIRECT',
    'BILIRUBIN (INDIRECT)',
    'GAMMA GLUTAMYL TRANSFERASE (GGT)',
    'ASPARTATE AMINOTRANSFERASE (SGOT )',
    'ALANINE TRANSAMINASE (SGPT)',
    'PROTEIN - TOTAL',
    'ALBUMIN - SERUM',
    'SERUM ALB/GLOBULIN RATIO',
    'SERUM GLOBULIN',
    'TOTAL CHOLESTEROL',
    'HDL CHOLESTEROL - DIRECT',
    'LDL CHOLESTEROL - DIRECT',
    'TRIGLYCERIDES',
    'TC/ HDL CHOLESTEROL RATIO',
    'LDL / HDL RATIO',
    'VLDL CHOLESTEROL',
    'NON-HDL CHOLESTEROL',
    'TOTAL TRIIODOTHYRONINE (T3)',
    'TOTAL THYROXINE',
    'THYROID STIMULATING HORMONE',
    'BLOOD UREA NITROGEN (BUN)',
    'CREATININE - SERUM',
    'BUN / SR.CREATININE RATIO',
    'CALCIUM',
    'URIC ACID',
    'EST. GLOMERULAR FILTRATION RATE (eGFR)',
    'Vitamin',
    ]

# %%
# Wordlist to Delete Useless data from the list
stopwords = ['0.02-0.1','3.9-4.8','58-159','X103pL','X103/pL','-','4.0-10.0','X103/uL','2.0-7.0','1.0-3.0','%','CLIA','ng/d|',
                 'C.LI.A','HIU/ml','C.L.L.A','(SGOT','(SGOT)','CLA','<','<2','20.0-40.0','0.0-0.4','ul','39.0-46.0','0.0-0.3',
                '20-40','PERCENTAGE(IG%)','0-0.5','40-80','0.0-6.0','0.0-6.0','0-0.1','mg/dl','CLIA','HIU/ml','U/I','12.0-15.0',
                '<2','0-10','<','>', 'X', '103', '/', 'pL', '0.2-1','X1046/pL','<0.01','g/dL','13-17','fl','83-101','C.M.1.A','ng/di',
                'pq', '27-32','g/dL', '31.5-34.5','0-0.3','40-50','fL', '39-46','11.6-14','9.6-15.2','4.5-5.5','g/dl',
                 'IMMUNOTURBIDIMETRY','ICP-MS','ug/l','<5','ug/I','0.10 - 1.50','<1','<4','<4','<15','yumol/L',
             'mg/L','(A)','[LP(A)]','pg/ml','mg/dL','ng/dL','Hg/dl',
               'PHOTOMETRY','CALCULATED','(eGFR)', 'Ratio', '9:1-23:1', '(mg/dl)','0.02-0.5','X10%6/uL =:','36.0-46.0',
                 'mL/min/1.73', 'm2','uIU/ml', '0.3-5.5','85-130','35-80','125-200','gm/dL', '2.5-3.4','u/|', '<35','(',')','0.35 - 4.94',
                'u/I', '<55','gm/dl', '3.2-4.8''5.7-8.2','6.5-12','19.7-42.4','0.19-0.39','0.3-1.2','0-0.9','5.7-8.2',
                '3.2-4.8','3-5', 'ng/dl', '60-200','ug/dl', '4.5-12','7-25','0.6-1.1','8.8-10.6','-7.3','5-40','U/L','1.5-3.5',
                'RATIO','150-400','4.0-10.0','25-200','B12 pg/mL 911','B12' ,'pg/mL','911','0.2-1.0','uL','0.0-10.0','0.02-0.1',
                '83.0-101.0','27.0-32.0','3.2-6.1','0.5-0.8','C.M.1.A 0.35','C.M.1.A ng/di','ma/dl','0.9-2','<31','11.6-14.0','27.0-32.0','X%/uL','=:','=:',

            ]

# %%
import glob
main = []
i = 0
pdf_dir = "pdd_info"
pdf_files = glob.glob("%s/*.pdf" % pdf_dir)
for file in pdf_files:
    images = convert_from_path(file)
    texts = []
    for i, image in enumerate(images):
        fname = "image" + str(i) + ".png"
        img.append(fname)
        image.save(fname, "PNG")
        text  =  ocr_core(fname)
        text = listToString(text)  
        texts.append(text)
        os.remove(fname)
        extracted_text = listToString(texts)
        Report_List = []
        for row in extracted_text.split('\n'):
            for word in list(word_list):
                if row.startswith(word):
                    word = row.split()
                    word = word
                    for word_name in list(word):
                        if word_name in stopwords:
                            word.remove(word_name)
                    for i in word:
                        if  solve(i):
                            null = i
                            word.remove(null)
                            i = float(i)
                    word = [x for x in word if not isinstance(x, int)]
                    word = [' '.join(word)]
                    #print(word)
                    word.append(i)
                    #word.remove(str(i))
                    #print(word)
                    Report_List.append(word)
        extracted_DataFrame = pd.DataFrame(Report_List)
        #Data Cleaning
        extracted_DataFrame.columns = ['Keys','Values']
    #        extracted_DataFrame.rename(columns={'Keys':'Values'},inplace=True)
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\d+', '')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\.','')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\-','')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.rstrip()
        extracted_DataFrame['Values'] = extracted_DataFrame['Values'].apply(lambda x: pd.to_numeric(x, errors = 'coerce')).dropna()
        extracted_DataFrame = extracted_DataFrame.dropna(axis=0)
        #DataFrame to Dictionary
        extracted_Dictionary = extracted_DataFrame.set_index('Keys')['Values'].to_dict()
        Report_Dictionary = {}

        if 'HPLC' in extracted_Dictionary.keys():
            HPLC = extracted_Dictionary['HPLC']
            Report_Dictionary["HPLC"] = HPLC
        else:
            Report_Dictionary["HPLC"] = None
        if 'AVERAGE BLOOD GLUCOSE (ABG)' in extracted_Dictionary.keys():
            AVERAGE_BLOOD_GLUCOSE = extracted_Dictionary['AVERAGE BLOOD GLUCOSE (ABG)']
            Report_Dictionary["AVERAGE_BLOOD_GLUCOSE"] = AVERAGE_BLOOD_GLUCOSE
        else:
            Report_Dictionary["AVERAGE_BLOOD_GLUCOSE"] = None
        if 'TOTAL LEUCOCYTES COUNT' in extracted_Dictionary.keys():
            TOTAL_LEUCOCYTES_COUNT = extracted_Dictionary['TOTAL LEUCOCYTES COUNT']
            Report_Dictionary["TOTAL_LEUCOCYTES_COUNT"] = TOTAL_LEUCOCYTES_COUNT
        else:
            Report_Dictionary["TOTAL_LEUCOCYTES_COUNT"] = None

        if 'NEUTROPHILS' in extracted_Dictionary.keys():
            NEUTROPHILS = extracted_Dictionary['NEUTROPHILS']
            Report_Dictionary["NEUTROPHILS"] = NEUTROPHILS
        else:
            Report_Dictionary["NEUTROPHILS"] = None

        if 'LYMPHOCYTE PERCENTAGE' in extracted_Dictionary.keys():
            LYMPHOCYTE_PERCENTAGE = extracted_Dictionary['LYMPHOCYTE PERCENTAGE']
            Report_Dictionary["LYMPHOCYTE_PERCENTAGE"] = LYMPHOCYTE_PERCENTAGE
        else:
            Report_Dictionary["LYMPHOCYTE_PERCENTAGE"] = None

        if 'MONOCYTES' in extracted_Dictionary.keys():
            MONOCYTES = extracted_Dictionary['MONOCYTES']
            Report_Dictionary["MONOCYTES"] = MONOCYTES
        else:
            Report_Dictionary["MONOCYTES"] = None

        if 'EOSINOPHILS' in extracted_Dictionary.keys():
            EOSINOPHILS = extracted_Dictionary['EOSINOPHILS']
            Report_Dictionary["EOSINOPHILS"] = EOSINOPHILS
        else:
            Report_Dictionary["EOSINOPHILS"] = None

        if 'BASOPHILS' in extracted_Dictionary.keys():
            BASOPHILS = extracted_Dictionary['BASOPHILS']
            Report_Dictionary["BASOPHILS"] = BASOPHILS
        else:
            Report_Dictionary["BASOPHILS"] = None

        if 'IMMATURE GRANULOCYTE' in extracted_Dictionary.keys():
            IMMATURE_GRANULOCYTE_PERCENTAGE = extracted_Dictionary['IMMATURE GRANULOCYTE']
            Report_Dictionary["IMMATURE_GRANULOCYTE_PERCENTAGE"] = IMMATURE_GRANULOCYTE_PERCENTAGE
        else:
            Report_Dictionary["IMMATURE_GRANULOCYTE_PERCENTAGE"] = None

        if 'NEUTROPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            NEUTROPHILS_ABSOLUTE_COUNT = extracted_Dictionary['NEUTROPHILS ABSOLUTE COUNT']
            Report_Dictionary["NEUTROPHILS_ABSOLUTE_COUNT"] = NEUTROPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["NEUTROPHILS_ABSOLUTE_COUNT"] = None

        if 'LYMPHOCYTES ABSOLUTE COUNT' in extracted_Dictionary.keys():
            LYMPHOCYTES_ABSOLUTE_COUNT = extracted_Dictionary['LYMPHOCYTES ABSOLUTE COUNT']
            Report_Dictionary["LYMPHOCYTES_ABSOLUTE_COUNT"] = LYMPHOCYTES_ABSOLUTE_COUNT
        else:
            Report_Dictionary["LYMPHOCYTES_ABSOLUTE_COUNT"] = None

        if 'MONOCYTES ABSOLUTE COUNT' in extracted_Dictionary.keys():
            MONOCYTES_ABSOLUTE_COUNT = extracted_Dictionary['MONOCYTES ABSOLUTE COUNT']
            Report_Dictionary["MONOCYTES_ABSOLUTE_COUNT"] = MONOCYTES_ABSOLUTE_COUNT
        else:
            Report_Dictionary["MONOCYTES_ABSOLUTE_COUNT"] = None

        if 'BASOPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            BASOPHILS_ABSOLUTE_COUNT = extracted_Dictionary['BASOPHILS ABSOLUTE COUNT']
            Report_Dictionary["BASOPHILS_ABSOLUTE_COUNT"] = BASOPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["BASOPHILS_ABSOLUTE_COUNT"] = None

        if 'EOSINOPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            EOSINOPHILS_ABSOLUTE_COUNT = extracted_Dictionary['EOSINOPHILS ABSOLUTE COUNT']
            Report_Dictionary["EOSINOPHILS_ABSOLUTE_COUNT"] = EOSINOPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["EOSINOPHILS_ABSOLUTE_COUNT"] = None

        if 'IMMATURE GRANULOCYTES(IG)' in extracted_Dictionary.keys():
            IMMATURE_GRANULOCYTES = extracted_Dictionary['IMMATURE GRANULOCYTES(IG)']
            Report_Dictionary["IMMATURE_GRANULOCYTES"] = IMMATURE_GRANULOCYTES
        else:
            Report_Dictionary["IMMATURE_GRANULOCYTES"] = None

        if 'TOTAL RBC' in extracted_Dictionary.keys():
            TOTAL_RBC = extracted_Dictionary['TOTAL RBC']
            Report_Dictionary["TOTAL_RBC"] = TOTAL_RBC
        else:
            Report_Dictionary["TOTAL_RBC"] = None

        if 'NUCLEATED RED BLOOD CELLS' in extracted_Dictionary.keys():
            NUCLEATED_RED_BLOOD_CELLS = extracted_Dictionary['NUCLEATED RED BLOOD CELLS']
            Report_Dictionary["NUCLEATED_RED_BLOOD_CELLS"] = NUCLEATED_RED_BLOOD_CELL

        else:
            Report_Dictionary["NUCLEATED_RED_BLOOD_CELLS"] = None


        if 'HEMOGLOBIN' in extracted_Dictionary.keys():
            HEMOGLOBIN = extracted_Dictionary['HEMOGLOBIN']
            Report_Dictionary["HEMOGLOBIN"] = HEMOGLOBIN
        else:
            Report_Dictionary["HEMOGLOBIN"] = None

        if 'HEMATOCRIT(PCV)' in extracted_Dictionary.keys():
            HEMATOCRIT = extracted_Dictionary['HEMATOCRIT(PCV)']
            Report_Dictionary["HEMATOCRIT"] = HEMATOCRIT
        else:
            Report_Dictionary["HEMATOCRIT"] = None

        if 'MEAN CORPUSCULAR VOLUME(MCV)' in extracted_Dictionary.keys():
            MEAN_CORPUSCULAR_VOLUME = extracted_Dictionary['MEAN CORPUSCULAR VOLUME(MCV)']
            Report_Dictionary["MEAN_CORPUSCULAR_VOLUME"] = MEAN_CORPUSCULAR_VOLUME
        else:
            Report_Dictionary["MEAN_CORPUSCULAR_VOLUME"] = None

        if 'MEAN CORPUSCULAR HEMOGLOBIN(MCH)' in extracted_Dictionary.keys():
            MEAN_CORPUSCULAR_HEMOGLOBIN = extracted_Dictionary['MEAN CORPUSCULAR HEMOGLOBIN(MCH)']
            Report_Dictionary["MEAN_CORPUSCULAR_HEMOGLOBIN"] = MEAN_CORPUSCULAR_HEMOGLOBIN
        else:
            Report_Dictionary["MEAN_CORPUSCULAR_HEMOGLOBIN"] = None

        if 'MEAN CORPHEMOCONC(MCHC)' in extracted_Dictionary.keys():
            MEAN_CORP_HEMO_CONC = extracted_Dictionary['MEAN CORPHEMOCONC(MCHC)']
            Report_Dictionary["MEAN_CORP_HEMO_CONC"] = MEAN_CORP_HEMO_CONC
        else:
            Report_Dictionary["MEAN_CORP_HEMO_CONC"] = None

        if 'RED CELL DISTRIBUTION WIDTH SD(RDWSD)' in extracted_Dictionary.keys():
            RED_CELL_DISTRIBUTION_WIDTH_SD = extracted_Dictionary['RED CELL DISTRIBUTION WIDTH SD(RDWSD)']
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_SD"] = RED_CELL_DISTRIBUTION_WIDTH_SD
        else:
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_SD"] = None

        if 'RED CELL DISTRIBUTION WIDTH (RDWCV)' in extracted_Dictionary.keys():
            RED_CELL_DISTRIBUTION_WIDTH_CV = extracted_Dictionary['RED CELL DISTRIBUTION WIDTH (RDWCV)']
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_CV"] = RED_CELL_DISTRIBUTION_WIDTH_CV
        else:
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_CV"] = None

        if 'PLATELET DISTRIBUTION WIDTH(PDW)' in extracted_Dictionary.keys():
            PLATELET_DISTRIBUTION_WIDTH = extracted_Dictionary['PLATELET DISTRIBUTION WIDTH(PDW)']
            Report_Dictionary["PLATELET_DISTRIBUTION_WIDTH"] = PLATELET_DISTRIBUTION_WIDTH
        else:
            Report_Dictionary["PLATELET_DISTRIBUTION_WIDTH"] = None

        if 'MEAN PLATELET VOLUME(MPV)' in extracted_Dictionary.keys():
            MEAN_PLATELET_VOLUME = extracted_Dictionary['MEAN PLATELET VOLUME(MPV)']
            Report_Dictionary["MEAN_PLATELET_VOLUME"] = MEAN_PLATELET_VOLUME
        else:
            Report_Dictionary["MEAN_PLATELET_VOLUME"] = None

        if 'PLATELET COUNT' in extracted_Dictionary.keys():
            PLATELET_COUNT = extracted_Dictionary['PLATELET COUNT']
            Report_Dictionary["PLATELET_COUNT"] = PLATELET_COUNT
        else:
            Report_Dictionary["PLATELET_COUNT"] = None

        if 'PLATELET TO LARGE CELL RATIO(PLCR)' in extracted_Dictionary.keys():
            PLATELET_TO_LARGE_CELL_RATIO = extracted_Dictionary['PLATELET TO LARGE CELL RATIO(PLCR)']
            Report_Dictionary["PLATELET_TO_LARGE_CELL_RATIO"] = PLATELET_TO_LARGE_CELL_RATIO
        else:
            Report_Dictionary["PLATELET_TO_LARGE_CELL_RATIO"] = None

        if 'PLATELETCRIT(PCT)' in extracted_Dictionary.keys():
            PLATELETCRIT = extracted_Dictionary['PLATELETCRIT(PCT)']
            Report_Dictionary["PLATELETCRIT"] = PLATELETCRIT
        else:
            Report_Dictionary["PLATELETCRIT"] = None

        if 'ARSENIC' in extracted_Dictionary.keys():
            ARSENIC = extracted_Dictionary['ARSENIC']
            Report_Dictionary["ARSENIC"] = ARSENIC
        else:
            Report_Dictionary["ARSENIC"] = None


        if 'CADMIUM' in extracted_Dictionary.keys():
            CADMIUM = extracted_Dictionary['CADMIUM']
            Report_Dictionary["CADMIUM"] = CADMIUM
        else:
            Report_Dictionary["CADMIUM"] = None


        if 'MERCURY' in extracted_Dictionary.keys():
            MERCURY = extracted_Dictionary['MERCURY']
            Report_Dictionary["MERCURY"] = MERCURY
        else:
            Report_Dictionary["MERCURY"] = None


        if 'LEAD' in extracted_Dictionary.keys():
            LEAD = extracted_Dictionary['LEAD']
            Report_Dictionary["LEAD"] = LEAD
        else:
            Report_Dictionary["LEAD"] = None


        if 'CHROMIUM' in extracted_Dictionary.keys():
            CHROMIUM = extracted_Dictionary['CHROMIUM']
            Report_Dictionary["CHROMIUM"] = CHROMIUM
        else:
            Report_Dictionary["CHROMIUM"] = None


        if 'BARIUM' in extracted_Dictionary.keys():
            BARIUM = extracted_Dictionary['BARIUM']
            Report_Dictionary["BARIUM"] = BARIUM
        else:
            Report_Dictionary["BARIUM"] = None


        if 'COBALT' in extracted_Dictionary.keys():
            COBALT = extracted_Dictionary['COBALT']
            Report_Dictionary["COBALT"] = COBALT
        else:
            Report_Dictionary["COBALT"] = None


        if 'CAESIUM' in extracted_Dictionary.keys():
            CAESIUM = extracted_Dictionary['CAESIUM']
            Report_Dictionary["CAESIUM"] = CAESIUM
        else:
            Report_Dictionary["CAESIUM"] = None


        if 'THALLIUM' in extracted_Dictionary.keys():
            THALLIUM = extracted_Dictionary['THALLIUM']
            Report_Dictionary["THALLIUM"] = THALLIUM
        else:
            Report_Dictionary["THALLIUM"] = None


        if 'URANIUM' in extracted_Dictionary.keys():
            URANIUM = extracted_Dictionary['URANIUM']
            Report_Dictionary["URANIUM"] = URANIUM
        else:
            Report_Dictionary["URANIUM"] = None


        if 'STRONTIUM' in extracted_Dictionary.keys():
            STRONTIUM = extracted_Dictionary['STRONTIUM']
            Report_Dictionary["STRONTIUM"] = STRONTIUM
        else:
            Report_Dictionary["STRONTIUM"] = None


        if 'ANTIMONY' in extracted_Dictionary.keys():
            ANTIMONY = extracted_Dictionary['ANTIMONY']
            Report_Dictionary["ANTIMONY"] = ANTIMONY
        else:
            Report_Dictionary["ANTIMONY"] = None


        if 'TIN' in extracted_Dictionary.keys():
            TIN = extracted_Dictionary['TIN']
            Report_Dictionary["TIN"] = TIN
        else:
            Report_Dictionary["TIN"] = None


        if 'MOLYBDENUM' in extracted_Dictionary.keys():
            MOLYBDENUM = extracted_Dictionary['MOLYBDENUM']
            Report_Dictionary["MOLYBDENUM"] = MOLYBDENUM
        else:
            Report_Dictionary["MOLYBDENUM"] = None



        if 'SILVER' in extracted_Dictionary.keys():
            SILVER = extracted_Dictionary['SILVER']
            Report_Dictionary["SILVER"] = SILVER
        else:
            Report_Dictionary["SILVER"] = None


        if 'VANADIUM' in extracted_Dictionary.keys():
            VANADIUM = extracted_Dictionary['VANADIUM']
            Report_Dictionary["VANADIUM"] = VANADIUM
        else:
            Report_Dictionary["VANADIUM"] = None


        if 'BERYLLIUM' in extracted_Dictionary.keys():
            BERYLLIUM = extracted_Dictionary['BERYLLIUM']
            Report_Dictionary["BERYLLIUM"] = BERYLLIUM
        else:
            Report_Dictionary["BERYLLIUM"] = None



        if 'BISMUTH' in extracted_Dictionary.keys():
            BISMUTH = extracted_Dictionary['BISMUTH']
            Report_Dictionary["BISMUTH"] = BISMUTH
        else:
            Report_Dictionary["BISMUTH"] = None


        if 'SELENIUM' in extracted_Dictionary.keys():
            SELENIUM = extracted_Dictionary['SELENIUM']
            Report_Dictionary["SELENIUM"] = SELENIUM
        else:
            Report_Dictionary["SELENIUM"] = None


        if 'ALUMINIUM' in extracted_Dictionary.keys():
            ALUMINIUM = extracted_Dictionary['ALUMINIUM']
            Report_Dictionary["ALUMINIUM"] = ALUMINIUM
        else:
            Report_Dictionary["ALUMINIUM"] = None


        if 'NICKEL' in extracted_Dictionary.keys():
            NICKEL = extracted_Dictionary['NICKEL']
            Report_Dictionary["NICKEL"] = NICKEL
        else:
            Report_Dictionary["NICKEL"] = None


        if 'MANGANESE' in extracted_Dictionary.keys():
            MANGANESE = extracted_Dictionary['MANGANESE']
            Report_Dictionary["MANGANESE"] = MANGANESE
        else:
            Report_Dictionary["MANGANESE"] = None


        if 'HOMOCYSTEINE' in extracted_Dictionary.keys():
            HOMOCYSTEINE = extracted_Dictionary['HOMOCYSTEINE']
            Report_Dictionary["HOMOCYSTEINE"] = HOMOCYSTEINE
        else:
            Report_Dictionary["HOMOCYSTEINE"] = None


        if 'CYSTATIN C' in extracted_Dictionary.keys():
            CYSTATIN_C = extracted_Dictionary['CYSTATIN C']
            Report_Dictionary["CYSTATIN_C"] = CYSTATIN_C
        else:
            Report_Dictionary["CYSTATIN_C"] = None

        if 'LIPOPROTEIN' in extracted_Dictionary.keys():
            LIPOPROTEIN = extracted_Dictionary['LIPOPROTEIN']
            Report_Dictionary["LIPOPROTEIN"] = LIPOPROTEIN
        else:
            Report_Dictionary["LIPOPROTEIN"] = None


        if 'VITAMIN B' in extracted_Dictionary.keys():
            VITAMIN_B = extracted_Dictionary['VITAMIN B']
            Report_Dictionary["VITAMIN_B"] = VITAMIN_B
        else:
            Report_Dictionary["VITAMIN_B"] = None


        if 'APOLIPOPROTEIN A (APOA)' in extracted_Dictionary.keys():
            APOLIPOPROTEIN_A_APOA = extracted_Dictionary['APOLIPOPROTEIN A (APOA)']
            Report_Dictionary["APOLIPOPROTEIN_A_APOA"] = APOLIPOPROTEIN_A_APOA
        else:
            Report_Dictionary["APOLIPOPROTEIN_A_APOA"] = None


        if 'APOLIPOPROTEIN B (APOB)' in extracted_Dictionary.keys():
            APOLIPOPROTEIN_B_APOB = extracted_Dictionary['APOLIPOPROTEIN B (APOB)']
            Report_Dictionary["APOLIPOPROTEIN_B_APOB"] = APOLIPOPROTEIN_B_APOB
        else:
            Report_Dictionary["APOLIPOPROTEIN_B_APOB"] = None

        if 'APO B APO Ai (APO B/A)' in extracted_Dictionary.keys():
            APOB_APOA_RATIO = extracted_Dictionary['APO B APO Ai (APO B/A)']
            Report_Dictionary["APOB_APOA_RATIO"] = APOB_APOA_RATIO
        else:
            Report_Dictionary["APOB_APOA_RATIO"] = None



        if 'HIGH SENSITIVITY CREACTIVE PROTEIN (HSCRP)' in extracted_Dictionary.keys():
            HSCRP = extracted_Dictionary['HIGH SENSITIVITY CREACTIVE PROTEIN (HSCRP)']
            Report_Dictionary["HSCRP"] = HSCRP
        else:
            Report_Dictionary["HSCRP"] = None


        if 'SERUM COPPER' in extracted_Dictionary.keys():
            SERUM_COPPER = extracted_Dictionary['SERUM COPPER']
            Report_Dictionary["SERUM_COPPER"] = SERUM_COPPER
        else:
            Report_Dictionary["SERUM_COPPER"] = None


        if 'SERUM ZINC' in extracted_Dictionary.keys():
            SERUM_ZINC = extracted_Dictionary['SERUM ZINC']
            Report_Dictionary["SERUM_ZINC"] = SERUM_ZINC
        else:
            Report_Dictionary["SERUM_ZINC"] = None


        if 'TESTOSTERONE' in extracted_Dictionary.keys():
            TESTOSTERONE = extracted_Dictionary['TESTOSTERONE']
            Report_Dictionary["TESTOSTERONE"] = TESTOSTERONE
        else:
            Report_Dictionary["TESTOSTERONE"] = None

        if 'IRON' in extracted_Dictionary.keys():
            IRON = extracted_Dictionary['IRON']
            Report_Dictionary["IRON"] = IRON
        else:
            Report_Dictionary["IRON"] = None

        if 'TOTAL IRON BINDING CAPACITY (TIBC)' in extracted_Dictionary.keys():
            TOTAL_IRON_BINDING_CAPACITY = extracted_Dictionary['TOTAL IRON BINDING CAPACITY (TIBC)']
            Report_Dictionary["TOTAL_IRON_BINDING_CAPACITY"] = TOTAL_IRON_BINDING_CAPACITY
        else:
            Report_Dictionary["TOTAL_IRON_BINDING_CAPACITY"] = None


        if 'TRANSFERRIN SATURATION' in extracted_Dictionary.keys():
            TRANSFERRIN_SATURATION = extracted_Dictionary['TRANSFERRIN SATURATION']
            Report_Dictionary["TRANSFERRIN_SATURATION"] = TRANSFERRIN_SATURATION
        else:
            Report_Dictionary["TRANSFERRIN_SATURATION"] = None

        if 'ALKALINE PHOSPHATASE' in extracted_Dictionary.keys():
            ALKALINE_PHOSPHATASE = extracted_Dictionary['ALKALINE PHOSPHATASE']
            Report_Dictionary["ALKALINE_PHOSPHATASE"] = ALKALINE_PHOSPHATASE
        else:
            Report_Dictionary["ALKALINE_PHOSPHATASE"] = None

        if 'BILIRUBIN TOTAL' in extracted_Dictionary.keys():
            BILIRUBIN_TOTAL = extracted_Dictionary['BILIRUBIN TOTAL']
            Report_Dictionary["BILIRUBIN_TOTAL"] = BILIRUBIN_TOTAL
        else:
            Report_Dictionary["BILIRUBIN_TOTAL"] = None

        if 'BILIRUBIN DIRECT' in extracted_Dictionary.keys():
            BILIRUBIN_DIRECT = extracted_Dictionary['BILIRUBIN DIRECT']
            Report_Dictionary["BILIRUBIN_DIRECT"] = BILIRUBIN_DIRECT
        else:
            Report_Dictionary["BILIRUBIN_DIRECT"] = None

        if 'BILIRUBIN (INDIRECT)' in extracted_Dictionary.keys():
            BILIRUBIN_INDIRECT = extracted_Dictionary['BILIRUBIN (INDIRECT)']
            Report_Dictionary["BILIRUBIN_INDIRECT"] = BILIRUBIN_INDIRECT
        else:
            Report_Dictionary["BILIRUBIN_INDIRECT"] = None

        if 'GAMMA GLUTAMYL TRANSFERASE (GGT)' in extracted_Dictionary.keys():
            GAMMA_GLUTAMYL_TRANSFERASE = extracted_Dictionary['GAMMA GLUTAMYL TRANSFERASE (GGT)']
            Report_Dictionary["GAMMA_GLUTAMYL_TRANSFERASE"] = GAMMA_GLUTAMYL_TRANSFERASE
        else:
            Report_Dictionary["GAMMA_GLUTAMYL_TRANSFERASE"] = None


        if 'ASPARTATE AMINOTRANSFERASE' in extracted_Dictionary.keys():
            ASPARTATE_AMINOTRANSFERASE = extracted_Dictionary['ASPARTATE AMINOTRANSFERASE']
            Report_Dictionary["ASPARTATE_AMINOTRANSFERASE"] = ASPARTATE_AMINOTRANSFERASE
        else:
            Report_Dictionary["ASPARTATE_AMINOTRANSFERASE"] = None

        if 'ALANINE TRANSAMINASE (SGPT)' in extracted_Dictionary.keys():
            ALANINE_TRANSAMINASE = extracted_Dictionary['ALANINE TRANSAMINASE (SGPT)']
            Report_Dictionary["ALANINE_TRANSAMINASE"] = ALANINE_TRANSAMINASE
        else:
            Report_Dictionary["ALANINE_TRANSAMINASE"] = None

        if 'PROTEIN TOTAL' in extracted_Dictionary.keys():
            PROTEIN_TOTAL = extracted_Dictionary['PROTEIN TOTAL']
            Report_Dictionary["PROTEIN_TOTAL"] = PROTEIN_TOTAL
        else:
            Report_Dictionary["PROTEIN_TOTAL"] = None

        if 'ALBUMIN SERUM' in extracted_Dictionary.keys():
            ALBUMIN_SERUM = extracted_Dictionary['ALBUMIN SERUM']
            Report_Dictionary["ALBUMIN_SERUM"] = ALBUMIN_SERUM
        else:
            Report_Dictionary["ALBUMIN_SERUM"] = None

        if 'SERUM ALB/GLOBULIN' in extracted_Dictionary.keys():
            SERUM_ALB = extracted_Dictionary['SERUM ALB/GLOBULIN']
            Report_Dictionary["SERUM_ALB"] = SERUM_ALB
        else:
            Report_Dictionary["SERUM_ALB"] = None

        if 'SERUM GLOBULIN' in extracted_Dictionary.keys():
            SERUM_GLOBULIN = extracted_Dictionary['SERUM GLOBULIN']
            Report_Dictionary["SERUM_GLOBULIN"] = SERUM_GLOBULIN
        else:
            Report_Dictionary["SERUM_GLOBULIN"] = None

        if 'TOTAL CHOLESTEROL' in extracted_Dictionary.keys():
            TOTAL_CHOLESTEROL = extracted_Dictionary['TOTAL CHOLESTEROL']
            Report_Dictionary["TOTAL_CHOLESTEROL"] = TOTAL_CHOLESTEROL
        else:
            Report_Dictionary["TOTAL_CHOLESTEROL"] = None

        if 'HDL CHOLESTEROL DIRECT' in extracted_Dictionary.keys():
            HDL_CHOLESTEROL_DIRECT = extracted_Dictionary['HDL CHOLESTEROL DIRECT']
            Report_Dictionary["HDL_CHOLESTEROL_DIRECT"] = HDL_CHOLESTEROL_DIRECT
        else:
            Report_Dictionary["HDL_CHOLESTEROL_DIRECT"] = None

        if 'LDL CHOLESTEROL DIRECT' in extracted_Dictionary.keys():
            LDL_CHOLESTEROL_DIRECT = extracted_Dictionary['LDL CHOLESTEROL DIRECT']
            Report_Dictionary["LDL_CHOLESTEROL_DIRECT"] = LDL_CHOLESTEROL_DIRECT
        else:
            Report_Dictionary["LDL_CHOLESTEROL_DIRECT"] = None

        if 'TRIGLYCERIDES' in extracted_Dictionary.keys():
            TRIGLYCERIDES = extracted_Dictionary['TRIGLYCERIDES']
            Report_Dictionary["TRIGLYCERIDES"] = TRIGLYCERIDES
        else:
            Report_Dictionary["TRIGLYCERIDES"] = None

        if 'TC/ HDL CHOLESTEROL' in extracted_Dictionary.keys():
            TC_HDL_CHOLESTEROL_RATIO = extracted_Dictionary['TC/ HDL CHOLESTEROL']
            Report_Dictionary["TC_HDL_CHOLESTEROL_RATIO"] = TC_HDL_CHOLESTEROL_RATIO
        else:
            Report_Dictionary["TC_HDL_CHOLESTEROL_RATIO"] = None

        if 'LDL HDL' in extracted_Dictionary.keys():
            LDL_HDL_RATIO = extracted_Dictionary['LDL HDL']
            Report_Dictionary["LDL_HDL_RATIO"] = LDL_HDL_RATIO
        else:
            Report_Dictionary["LDL_HDL_RATIO"] = None


        if 'VLDL CHOLESTEROL' in extracted_Dictionary.keys():
            VLDL_CHOLESTEROL = extracted_Dictionary['VLDL CHOLESTEROL']
            Report_Dictionary["VLDL_CHOLESTEROL"] = VLDL_CHOLESTEROL
        else:
            Report_Dictionary["VLDL_CHOLESTEROL"] = None

        if 'NONHDL CHOLESTEROL' in extracted_Dictionary.keys():
            NON_HDL_CHOLESTEROL = extracted_Dictionary['NONHDL CHOLESTEROL']
            Report_Dictionary["NON_HDL_CHOLESTEROL"] = NON_HDL_CHOLESTEROL
        else:
            Report_Dictionary["NON_HDL_CHOLESTEROL"] = None


        if 'TOTAL TRIIODOTHYRONINE (T)' in extracted_Dictionary.keys():
            TOTAL_TRIIODOTHYRONINE = extracted_Dictionary['TOTAL TRIIODOTHYRONINE (T)']
            Report_Dictionary["TOTAL_TRIIODOTHYRONINE"] = TOTAL_TRIIODOTHYRONINE
        else:
            Report_Dictionary["TOTAL_TRIIODOTHYRONINE"] = None

        if 'TOTAL THYROXINE (T)' in extracted_Dictionary.keys():
            TOTAL_THYROXINE = extracted_Dictionary['TOTAL THYROXINE (T)']
            Report_Dictionary["TOTAL_THYROXINE"] = TOTAL_THYROXINE
        else:
            Report_Dictionary["TOTAL_THYROXINE"] = None

        if 'THYROID STIMULATING HORMONE (TSH)' in extracted_Dictionary.keys():
            THYROID_STIMULATING_HORMONE = extracted_Dictionary['THYROID STIMULATING HORMONE (TSH)']
            Report_Dictionary["THYROID_STIMULATING_HORMONE"] = THYROID_STIMULATING_HORMONE
        else:
            Report_Dictionary["THYROID_STIMULATING_HORMONE"] = None

        if 'BLOOD UREA NITROGEN (BUN)' in extracted_Dictionary.keys():
            BLOOD_UREA_NITROGEN = extracted_Dictionary['BLOOD UREA NITROGEN (BUN)']
            Report_Dictionary["BLOOD_UREA_NITROGEN"] = BLOOD_UREA_NITROGEN
        else:
            Report_Dictionary["BLOOD_UREA_NITROGEN"] = None

        if 'CREATININE SERUM' in extracted_Dictionary.keys():
            CREATININE_SERUM = extracted_Dictionary['CREATININE SERUM']
            Report_Dictionary["CREATININE_SERUM"] = CREATININE_SERUM
        else:
            Report_Dictionary["CREATININE_SERUM"] = None

        if 'BUN SRCREATININE' in extracted_Dictionary.keys():
            BUN_SR_CREATININE_RATIO = extracted_Dictionary['BUN SRCREATININE']
            Report_Dictionary["BUN_SR_CREATININE_RATIO"] = BUN_SR_CREATININE_RATIO
        else:
            Report_Dictionary["BUN_SR_CREATININE_RATIO"] = None

        if 'CALCIUM' in extracted_Dictionary.keys():
            CALCIUM = extracted_Dictionary['CALCIUM']
            Report_Dictionary["CALCIUM"] = CALCIUM
        else:
            Report_Dictionary["CALCIUM"] = None

        if 'URIC ACID' in extracted_Dictionary.keys():
            URIC_ACID = extracted_Dictionary['URIC ACID']
            Report_Dictionary["URIC_ACID"] = URIC_ACID
        else:
            Report_Dictionary["URIC_ACID"] = None


        if 'EST GLOMERULAR FILTRATION RATE' in extracted_Dictionary.keys():
            EST_GLOMERULAR_FILTRATION_RATE = extracted_Dictionary['EST GLOMERULAR FILTRATION RATE']
            Report_Dictionary["EST_GLOMERULAR_FILTRATION_RATE"] = EST_GLOMERULAR_FILTRATION_RATE
        else:
            Report_Dictionary["EST_GLOMERULAR_FILTRATION_RATE"] = None
    print(Report_Dictionary)
# Out:
# {'HPLC': 5.9, 'AVERAGE_BLOOD_GLUCOSE': 123.0, 'TOTAL_LEUCOCYTES_COUNT': 8.3, 'NEUTROPHILS': 52.2, 'LYMPHOCYTE_PERCENTAGE': 42.8, 'MONOCYTES': 3.3, 'EOSINOPHILS': 1.3, 'BASOPHILS': 0.2, 'IMMATURE_GRANULOCYTE_PERCENTAGE': 0.2, 'NEUTROPHILS_ABSOLUTE_COUNT': None, 'LYMPHOCYTES_ABSOLUTE_COUNT': 3.55, 'MONOCYTES_ABSOLUTE_COUNT': 0.27, 'BASOPHILS_ABSOLUTE_COUNT': 0.02, 'EOSINOPHILS_ABSOLUTE_COUNT': None, 'IMMATURE_GRANULOCYTES': None, 'TOTAL_RBC': 4.83, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': 9.4, 'HEMATOCRIT': 37.2, 'MEAN_CORPUSCULAR_VOLUME': 77.0, 'MEAN_CORPUSCULAR_HEMOGLOBIN': 19.5, 'MEAN_CORP_HEMO_CONC': 25.3, 'RED_CELL_DISTRIBUTION_WIDTH_SD': 54.5, 'RED_CELL_DISTRIBUTION_WIDTH_CV': 19.7, 'PLATELET_DISTRIBUTION_WIDTH': 10.8, 'MEAN_PLATELET_VOLUME': 10.2, 'PLATELET_COUNT': 518.0, 'PLATELET_TO_LARGE_CELL_RATIO': 25.6, 'PLATELETCRIT': 0.53, 'ARSENIC': 1.05, 'CADMIUM': 0.37, 'MERCURY': 0.3, 'LEAD': 40.95, 'CHROMIUM': 1.18, 'BARIUM': 1.7, 'COBALT': 1.5, 'CAESIUM': 1.48, 'THALLIUM': 0.03, 'URANIUM': 0.08, 'STRONTIUM': 38.0, 'ANTIMONY': 18.0, 'TIN': 0.31, 'MOLYBDENUM': 4.0, 'SILVER': 1.07, 'VANADIUM': 0.2, 'BERYLLIUM': 0.8, 'BISMUTH': 0.8, 'SELENIUM': 340.0, 'ALUMINIUM': 9.32, 'NICKEL': 3.64, 'MANGANESE': 20.0, 'HOMOCYSTEINE': 13.7, 'CYSTATIN_C': 0.98, 'LIPOPROTEIN': 55.5, 'VITAMIN_B': 211.0, 'APOLIPOPROTEIN_A_APOA': 115.0, 'APOLIPOPROTEIN_B_APOB': 80.0, 'APOB_APOA_RATIO': None, 'HSCRP': 6.2, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': 20.2, 'TOTAL_IRON_BINDING_CAPACITY': None, 'TRANSFERRIN_SATURATION': None, 'ALKALINE_PHOSPHATASE': 129.0, 'BILIRUBIN_TOTAL': 0.32, 'BILIRUBIN_DIRECT': 0.11, 'BILIRUBIN_INDIRECT': 0.21, 'GAMMA_GLUTAMYL_TRANSFERASE': None, 'ASPARTATE_AMINOTRANSFERASE': None, 'ALANINE_TRANSAMINASE': None, 'PROTEIN_TOTAL': None, 'ALBUMIN_SERUM': 4.1, 'SERUM_ALB': -2.0, 'SERUM_GLOBULIN': 3.3, 'TOTAL_CHOLESTEROL': 153.0, 'HDL_CHOLESTEROL_DIRECT': 44.0, 'LDL_CHOLESTEROL_DIRECT': 90.0, 'TRIGLYCERIDES': 179.0, 'TC_HDL_CHOLESTEROL_RATIO': 3.5, 'LDL_HDL_RATIO': 2.1, 'VLDL_CHOLESTEROL': 35.8, 'NON_HDL_CHOLESTEROL': 109.2, 'TOTAL_TRIIODOTHYRONINE': 115.0, 'TOTAL_THYROXINE': 11.9, 'THYROID_STIMULATING_HORMONE': 1.57, 'BLOOD_UREA_NITROGEN': 8.86, 'CREATININE_SERUM': 0.72, 'BUN_SR_CREATININE_RATIO': 12.31, 'CALCIUM': 8.59, 'URIC_ACID': 4.8, 'EST_GLOMERULAR_FILTRATION_RATE': None}
# {'HPLC': 6.6, 'AVERAGE_BLOOD_GLUCOSE': 143.0, 'TOTAL_LEUCOCYTES_COUNT': 7.29, 'NEUTROPHILS': 63.7, 'LYMPHOCYTE_PERCENTAGE': 32.1, 'MONOCYTES': 2.5, 'EOSINOPHILS': 1.2, 'BASOPHILS': 0.2, 'IMMATURE_GRANULOCYTE_PERCENTAGE': 0.3, 'NEUTROPHILS_ABSOLUTE_COUNT': 4.64, 'LYMPHOCYTES_ABSOLUTE_COUNT': None, 'MONOCYTES_ABSOLUTE_COUNT': 0.18, 'BASOPHILS_ABSOLUTE_COUNT': 0.01, 'EOSINOPHILS_ABSOLUTE_COUNT': 0.09, 'IMMATURE_GRANULOCYTES': 0.02, 'TOTAL_RBC': 4.59, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': 11.4, 'HEMATOCRIT': 41.5, 'MEAN_CORPUSCULAR_VOLUME': 90.4, 'MEAN_CORPUSCULAR_HEMOGLOBIN': 24.8, 'MEAN_CORP_HEMO_CONC': 27.5, 'RED_CELL_DISTRIBUTION_WIDTH_SD': 58.2, 'RED_CELL_DISTRIBUTION_WIDTH_CV': 17.4, 'PLATELET_DISTRIBUTION_WIDTH': 14.0, 'MEAN_PLATELET_VOLUME': 11.2, 'PLATELET_COUNT': 304.0, 'PLATELET_TO_LARGE_CELL_RATIO': 34.5, 'PLATELETCRIT': 0.34, 'ARSENIC': 1.16, 'CADMIUM': 0.1, 'MERCURY': 0.43, 'LEAD': 21.59, 'CHROMIUM': 0.64, 'BARIUM': 1.84, 'COBALT': 1.5, 'CAESIUM': 1.5, 'THALLIUM': 0.03, 'URANIUM': 0.08, 'STRONTIUM': 38.0, 'ANTIMONY': 18.0, 'TIN': 0.22, 'MOLYBDENUM': 4.0, 'SILVER': 1.06, 'VANADIUM': 0.71, 'BERYLLIUM': 0.8, 'BISMUTH': 0.8, 'SELENIUM': 340.0, 'ALUMINIUM': 2.83, 'NICKEL': 2.59, 'MANGANESE': 20.0, 'HOMOCYSTEINE': 16.4, 'CYSTATIN_C': 1.02, 'LIPOPROTEIN': 29.2, 'VITAMIN_B': None, 'APOLIPOPROTEIN_A_APOA': 104.0, 'APOLIPOPROTEIN_B_APOB': 91.0, 'APOB_APOA_RATIO': None, 'HSCRP': 4.5, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': None, 'TOTAL_IRON_BINDING_CAPACITY': 373.0, 'TRANSFERRIN_SATURATION': None, 'ALKALINE_PHOSPHATASE': 129.0, 'BILIRUBIN_TOTAL': 0.41, 'BILIRUBIN_DIRECT': 0.09, 'BILIRUBIN_INDIRECT': 0.32, 'GAMMA_GLUTAMYL_TRANSFERASE': None, 'ASPARTATE_AMINOTRANSFERASE': None, 'ALANINE_TRANSAMINASE': None, 'PROTEIN_TOTAL': None, 'ALBUMIN_SERUM': 4.1, 'SERUM_ALB': -2.0, 'SERUM_GLOBULIN': 2.8, 'TOTAL_CHOLESTEROL': 169.0, 'HDL_CHOLESTEROL_DIRECT': 41.0, 'LDL_CHOLESTEROL_DIRECT': 101.0, 'TRIGLYCERIDES': 202.0, 'TC_HDL_CHOLESTEROL_RATIO': 4.2, 'LDL_HDL_RATIO': 2.5, 'VLDL_CHOLESTEROL': 40.4, 'NON_HDL_CHOLESTEROL': 128.4, 'TOTAL_TRIIODOTHYRONINE': 118.0, 'TOTAL_THYROXINE': 11.6, 'THYROID_STIMULATING_HORMONE': None, 'BLOOD_UREA_NITROGEN': 13.12, 'CREATININE_SERUM': 0.72, 'BUN_SR_CREATININE_RATIO': 18.22, 'CALCIUM': 8.84, 'URIC_ACID': 3.8, 'EST_GLOMERULAR_FILTRATION_RATE': None}
# {'HPLC': None, 'AVERAGE_BLOOD_GLUCOSE': None, 'TOTAL_LEUCOCYTES_COUNT': None, 'NEUTROPHILS': None, 'LYMPHOCYTE_PERCENTAGE': None, 'MONOCYTES': None, 'EOSINOPHILS': None, 'BASOPHILS': None, 'IMMATURE_GRANULOCYTE_PERCENTAGE': None, 'NEUTROPHILS_ABSOLUTE_COUNT': None, 'LYMPHOCYTES_ABSOLUTE_COUNT': None, 'MONOCYTES_ABSOLUTE_COUNT': None, 'BASOPHILS_ABSOLUTE_COUNT': None, 'EOSINOPHILS_ABSOLUTE_COUNT': None, 'IMMATURE_GRANULOCYTES': None, 'TOTAL_RBC': None, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': None, 'HEMATOCRIT': None, 'MEAN_CORPUSCULAR_VOLUME': None, 'MEAN_CORPUSCULAR_HEMOGLOBIN': None, 'MEAN_CORP_HEMO_CONC': None, 'RED_CELL_DISTRIBUTION_WIDTH_SD': None, 'RED_CELL_DISTRIBUTION_WIDTH_CV': None, 'PLATELET_DISTRIBUTION_WIDTH': None, 'MEAN_PLATELET_VOLUME': None, 'PLATELET_COUNT': None, 'PLATELET_TO_LARGE_CELL_RATIO': None, 'PLATELETCRIT': None, 'ARSENIC': None, 'CADMIUM': None, 'MERCURY': None, 'LEAD': None, 'CHROMIUM': None, 'BARIUM': None, 'COBALT': None, 'CAESIUM': None, 'THALLIUM': None, 'URANIUM': None, 'STRONTIUM': None, 'ANTIMONY': None, 'TIN': None, 'MOLYBDENUM': None, 'SILVER': None, 'VANADIUM': None, 'BERYLLIUM': None, 'BISMUTH': None, 'SELENIUM': None, 'ALUMINIUM': None, 'NICKEL': None, 'MANGANESE': None, 'HOMOCYSTEINE': None, 'CYSTATIN_C': None, 'LIPOPROTEIN': None, 'VITAMIN_B': None, 'APOLIPOPROTEIN_A_APOA': None, 'APOLIPOPROTEIN_B_APOB': None, 'APOB_APOA_RATIO': None, 'HSCRP': None, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': None, 'TOTAL_IRON_BINDING_CAPACITY': None, 'TRANSFERRIN_SATURATION': None, 'ALKALINE_PHOSPHATASE': None, 'BILIRUBIN_TOTAL': None, 'BILIRUBIN_DIRECT': None, 'BILIRUBIN_INDIRECT': None, 'GAMMA_GLUTAMYL_TRANSFERASE': None, 'ASPARTATE_AMINOTRANSFERASE': None, 'ALANINE_TRANSAMINASE': None, 'PROTEIN_TOTAL': None, 'ALBUMIN_SERUM': None, 'SERUM_ALB': None, 'SERUM_GLOBULIN': None, 'TOTAL_CHOLESTEROL': None, 'HDL_CHOLESTEROL_DIRECT': None, 'LDL_CHOLESTEROL_DIRECT': None, 'TRIGLYCERIDES': None, 'TC_HDL_CHOLESTEROL_RATIO': None, 'LDL_HDL_RATIO': None, 'VLDL_CHOLESTEROL': None, 'NON_HDL_CHOLESTEROL': None, 'TOTAL_TRIIODOTHYRONINE': 118.0, 'TOTAL_THYROXINE': 12.9, 'THYROID_STIMULATING_HORMONE': 5.14, 'BLOOD_UREA_NITROGEN': None, 'CREATININE_SERUM': None, 'BUN_SR_CREATININE_RATIO': None, 'CALCIUM': None, 'URIC_ACID': None, 'EST_GLOMERULAR_FILTRATION_RATE': None}
# {'HPLC': 8.3, 'AVERAGE_BLOOD_GLUCOSE': 192.0, 'TOTAL_LEUCOCYTES_COUNT': 6.4, 'NEUTROPHILS': 49.7, 'LYMPHOCYTE_PERCENTAGE': 42.8, 'MONOCYTES': 2.3, 'EOSINOPHILS': 4.7, 'BASOPHILS': 0.2, 'IMMATURE_GRANULOCYTE_PERCENTAGE': 0.3, 'NEUTROPHILS_ABSOLUTE_COUNT': 3.18, 'LYMPHOCYTES_ABSOLUTE_COUNT': 2.74, 'MONOCYTES_ABSOLUTE_COUNT': 0.15, 'BASOPHILS_ABSOLUTE_COUNT': 0.01, 'EOSINOPHILS_ABSOLUTE_COUNT': 0.3, 'IMMATURE_GRANULOCYTES': 0.02, 'TOTAL_RBC': 6.13, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': 18.1, 'HEMATOCRIT': 50.68, 'MEAN_CORPUSCULAR_VOLUME': 100.2, 'MEAN_CORPUSCULAR_HEMOGLOBIN': 29.5, 'MEAN_CORP_HEMO_CONC': 29.5, 'RED_CELL_DISTRIBUTION_WIDTH_SD': 62.9, 'RED_CELL_DISTRIBUTION_WIDTH_CV': 17.6, 'PLATELET_DISTRIBUTION_WIDTH': 11.1, 'MEAN_PLATELET_VOLUME': 9.4, 'PLATELET_COUNT': 222.0, 'PLATELET_TO_LARGE_CELL_RATIO': 20.5, 'PLATELETCRIT': 0.21, 'ARSENIC': None, 'CADMIUM': None, 'MERCURY': None, 'LEAD': None, 'CHROMIUM': None, 'BARIUM': None, 'COBALT': None, 'CAESIUM': None, 'THALLIUM': None, 'URANIUM': None, 'STRONTIUM': None, 'ANTIMONY': None, 'TIN': None, 'MOLYBDENUM': None, 'SILVER': None, 'VANADIUM': None, 'BERYLLIUM': None, 'BISMUTH': None, 'SELENIUM': None, 'ALUMINIUM': None, 'NICKEL': None, 'MANGANESE': None, 'HOMOCYSTEINE': None, 'CYSTATIN_C': None, 'LIPOPROTEIN': None, 'VITAMIN_B': None, 'APOLIPOPROTEIN_A_APOA': None, 'APOLIPOPROTEIN_B_APOB': None, 'APOB_APOA_RATIO': None, 'HSCRP': None, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': 69.1, 'TOTAL_IRON_BINDING_CAPACITY': 348.0, 'TRANSFERRIN_SATURATION': 19.86, 'ALKALINE_PHOSPHATASE': 129.0, 'BILIRUBIN_TOTAL': 0.35, 'BILIRUBIN_DIRECT': 0.08, 'BILIRUBIN_INDIRECT': 0.27, 'GAMMA_GLUTAMYL_TRANSFERASE': 91.1, 'ASPARTATE_AMINOTRANSFERASE': 22.5, 'ALANINE_TRANSAMINASE': 21.4, 'PROTEIN_TOTAL': 6.6, 'ALBUMIN_SERUM': 41.0, 'SERUM_ALB': 1.64, 'SERUM_GLOBULIN': 2.5, 'TOTAL_CHOLESTEROL': 220.0, 'HDL_CHOLESTEROL_DIRECT': 36.0, 'LDL_CHOLESTEROL_DIRECT': 167.0, 'TRIGLYCERIDES': 188.0, 'TC_HDL_CHOLESTEROL_RATIO': 6.1, 'LDL_HDL_RATIO': 4.7, 'VLDL_CHOLESTEROL': 37.6, 'NON_HDL_CHOLESTEROL': 184.1, 'TOTAL_TRIIODOTHYRONINE': 99.0, 'TOTAL_THYROXINE': 6.4, 'THYROID_STIMULATING_HORMONE': 3.42, 'BLOOD_UREA_NITROGEN': 12.26, 'CREATININE_SERUM': 0.74, 'BUN_SR_CREATININE_RATIO': 16.57, 'CALCIUM': 9.16, 'URIC_ACID': 3.3, 'EST_GLOMERULAR_FILTRATION_RATE': 117.0}
# {'HPLC': 7.2, 'AVERAGE_BLOOD_GLUCOSE': 160.0, 'TOTAL_LEUCOCYTES_COUNT': 6.6, 'NEUTROPHILS': 58.1, 'LYMPHOCYTE_PERCENTAGE': 26.7, 'MONOCYTES': 3.9, 'EOSINOPHILS': 10.2, 'BASOPHILS': 0.8, 'IMMATURE_GRANULOCYTE_PERCENTAGE': 0.3, 'NEUTROPHILS_ABSOLUTE_COUNT': 3.83, 'LYMPHOCYTES_ABSOLUTE_COUNT': 1.76, 'MONOCYTES_ABSOLUTE_COUNT': 0.26, 'BASOPHILS_ABSOLUTE_COUNT': 0.05, 'EOSINOPHILS_ABSOLUTE_COUNT': 0.67, 'IMMATURE_GRANULOCYTES': 0.02, 'TOTAL_RBC': None, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': 12.1, 'HEMATOCRIT': 43.4, 'MEAN_CORPUSCULAR_VOLUME': 103.6, 'MEAN_CORPUSCULAR_HEMOGLOBIN': 28.9, 'MEAN_CORP_HEMO_CONC': 27.9, 'RED_CELL_DISTRIBUTION_WIDTH_SD': 59.7, 'RED_CELL_DISTRIBUTION_WIDTH_CV': 15.9, 'PLATELET_DISTRIBUTION_WIDTH': 19.0, 'MEAN_PLATELET_VOLUME': 12.9, 'PLATELET_COUNT': 231.0, 'PLATELET_TO_LARGE_CELL_RATIO': 47.3, 'PLATELETCRIT': 0.3, 'ARSENIC': None, 'CADMIUM': None, 'MERCURY': None, 'LEAD': None, 'CHROMIUM': None, 'BARIUM': None, 'COBALT': None, 'CAESIUM': None, 'THALLIUM': None, 'URANIUM': None, 'STRONTIUM': None, 'ANTIMONY': None, 'TIN': None, 'MOLYBDENUM': None, 'SILVER': None, 'VANADIUM': None, 'BERYLLIUM': None, 'BISMUTH': None, 'SELENIUM': None, 'ALUMINIUM': None, 'NICKEL': None, 'MANGANESE': None, 'HOMOCYSTEINE': None, 'CYSTATIN_C': None, 'LIPOPROTEIN': None, 'VITAMIN_B': None, 'APOLIPOPROTEIN_A_APOA': None, 'APOLIPOPROTEIN_B_APOB': None, 'APOB_APOA_RATIO': None, 'HSCRP': None, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': 55.2, 'TOTAL_IRON_BINDING_CAPACITY': 394.0, 'TRANSFERRIN_SATURATION': 14.01, 'ALKALINE_PHOSPHATASE': 129.0, 'BILIRUBIN_TOTAL': 0.48, 'BILIRUBIN_DIRECT': 0.15, 'BILIRUBIN_INDIRECT': 0.33, 'GAMMA_GLUTAMYL_TRANSFERASE': 12.3, 'ASPARTATE_AMINOTRANSFERASE': 33.4, 'ALANINE_TRANSAMINASE': 27.9, 'PROTEIN_TOTAL': 7.5, 'ALBUMIN_SERUM': 4.3, 'SERUM_ALB': 1.34, 'SERUM_GLOBULIN': 3.2, 'TOTAL_CHOLESTEROL': 148.0, 'HDL_CHOLESTEROL_DIRECT': 23.0, 'LDL_CHOLESTEROL_DIRECT': 91.0, 'TRIGLYCERIDES': 201.0, 'TC_HDL_CHOLESTEROL_RATIO': 6.5, 'LDL_HDL_RATIO': 4.0, 'VLDL_CHOLESTEROL': 40.19, 'NON_HDL_CHOLESTEROL': 125.1, 'TOTAL_TRIIODOTHYRONINE': 87.0, 'TOTAL_THYROXINE': 12.1, 'THYROID_STIMULATING_HORMONE': 4.94, 'BLOOD_UREA_NITROGEN': 7.38, 'CREATININE_SERUM': 0.54, 'BUN_SR_CREATININE_RATIO': 13.67, 'CALCIUM': 9.04, 'URIC_ACID': 3.9, 'EST_GLOMERULAR_FILTRATION_RATE': None}
# {'HPLC': None, 'AVERAGE_BLOOD_GLUCOSE': None, 'TOTAL_LEUCOCYTES_COUNT': None, 'NEUTROPHILS': None, 'LYMPHOCYTE_PERCENTAGE': None, 'MONOCYTES': None, 'EOSINOPHILS': None, 'BASOPHILS': None, 'IMMATURE_GRANULOCYTE_PERCENTAGE': None, 'NEUTROPHILS_ABSOLUTE_COUNT': None, 'LYMPHOCYTES_ABSOLUTE_COUNT': None, 'MONOCYTES_ABSOLUTE_COUNT': None, 'BASOPHILS_ABSOLUTE_COUNT': None, 'EOSINOPHILS_ABSOLUTE_COUNT': None, 'IMMATURE_GRANULOCYTES': None, 'TOTAL_RBC': None, 'NUCLEATED_RED_BLOOD_CELLS': None, 'HEMOGLOBIN': None, 'HEMATOCRIT': None, 'MEAN_CORPUSCULAR_VOLUME': None, 'MEAN_CORPUSCULAR_HEMOGLOBIN': None, 'MEAN_CORP_HEMO_CONC': None, 'RED_CELL_DISTRIBUTION_WIDTH_SD': None, 'RED_CELL_DISTRIBUTION_WIDTH_CV': None, 'PLATELET_DISTRIBUTION_WIDTH': None, 'MEAN_PLATELET_VOLUME': None, 'PLATELET_COUNT': None, 'PLATELET_TO_LARGE_CELL_RATIO': None, 'PLATELETCRIT': None, 'ARSENIC': None, 'CADMIUM': None, 'MERCURY': None, 'LEAD': None, 'CHROMIUM': None, 'BARIUM': None, 'COBALT': None, 'CAESIUM': None, 'THALLIUM': None, 'URANIUM': None, 'STRONTIUM': None, 'ANTIMONY': None, 'TIN': None, 'MOLYBDENUM': None, 'SILVER': None, 'VANADIUM': None, 'BERYLLIUM': None, 'BISMUTH': None, 'SELENIUM': None, 'ALUMINIUM': None, 'NICKEL': None, 'MANGANESE': None, 'HOMOCYSTEINE': None, 'CYSTATIN_C': None, 'LIPOPROTEIN': None, 'VITAMIN_B': None, 'APOLIPOPROTEIN_A_APOA': None, 'APOLIPOPROTEIN_B_APOB': None, 'APOB_APOA_RATIO': None, 'HSCRP': None, 'SERUM_COPPER': None, 'SERUM_ZINC': None, 'TESTOSTERONE': None, 'IRON': None, 'TOTAL_IRON_BINDING_CAPACITY': None, 'TRANSFERRIN_SATURATION': None, 'ALKALINE_PHOSPHATASE': None, 'BILIRUBIN_TOTAL': None, 'BILIRUBIN_DIRECT': None, 'BILIRUBIN_INDIRECT': None, 'GAMMA_GLUTAMYL_TRANSFERASE': None, 'ASPARTATE_AMINOTRANSFERASE': None, 'ALANINE_TRANSAMINASE': None, 'PROTEIN_TOTAL': None, 'ALBUMIN_SERUM': None, 'SERUM_ALB': None, 'SERUM_GLOBULIN': None, 'TOTAL_CHOLESTEROL': None, 'HDL_CHOLESTEROL_DIRECT': None, 'LDL_CHOLESTEROL_DIRECT': None, 'TRIGLYCERIDES': None, 'TC_HDL_CHOLESTEROL_RATIO': None, 'LDL_HDL_RATIO': None, 'VLDL_CHOLESTEROL': None, 'NON_HDL_CHOLESTEROL': None, 'TOTAL_TRIIODOTHYRONINE': 118.0, 'TOTAL_THYROXINE': 12.9, 'THYROID_STIMULATING_HORMONE': 5.14, 'BLOOD_UREA_NITROGEN': None, 'CREATININE_SERUM': None, 'BUN_SR_CREATININE_RATIO': None, 'CALCIUM': None, 'URIC_ACID': None, 'EST_GLOMERULAR_FILTRATION_RATE': None}

# %%
h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-244aa7266b3f> in <module>
# ----> 1 h
#
# NameError: name 'h' is not defined

# %%
main
# Out:
# ['PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0c',
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
#  'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicon ...
# ...
#  'PROCESSED AT:\n\nThyrocare Th CO ®\nH. NO. 1-9-645,Vidyanagar, yr Care\n\nAdikmet Road,Near SBH,\n\nThink Thyroid. Think Thyrocare.\nHyderabad-500 044\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nNAME : MRS K SANDYA (32Y/F) SAMPLE COLLECTED AT\n. (18900), INDIRA DIAGNOSTIC\n\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : HEMOGRAM - 6 PART (DIFF),HBA PRADESH,531116\n\nTEST NAME TECHNOLOGY VALUE UNITS\nHbAi1c - (HPLC - NGSP Certified)\n\nH.P.L.C 7.2 %\n\nReference Range :\n\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\n\nBelow 5.7% : Normal Below 6.5% : Good Control\n\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n\n>8% : Poor Control\n\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\n\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 160 mg/dl\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n\n> 180 mg/dl : Poor Control\n\nMethod : Derived from HBA1c_ values\n\nPlease correlate with clinical conditions.\nSample Collected on (SCT) :17 May 2019 08:00\nSample Received on (SRT) :18 May 2019 16:03 “\nReport Released on (RRT) 218 May 2019 17:08 wt\nSample Type bres. #EDTA Dr.Siva Ranjan MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode 1 1805072695/A6750\n\nRe . Page : 1 of 9\nBarcode Ou 1M9261454\n\x0cPROCESSED AT:\nThyrocare\n\nH. NO. 1-9-645,Vidyanagar,\n\nAdikmet Road,Near SBH,\n\nHyderabad-500 044\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\n \n\nNAME MRS K SANDYA (32Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED HEMOGRANM - 6 PART (DIFF),HBA PRADESH,531116\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 6.6 X 103 / uL 4.0-10.0\nNEUTROPHILS 58.1 % 40-80\nLYMPHOCYTE PERCENTAGE 26.7 % 20.0-40.0\nMONOCYTES 3.9 % 0.0-10.0\nEOSINOPHILS 10.2 % 0.0-6.0\nBASOPHILS 0.8 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.3 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 3.83 X 103 / uL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 1.76 X 103 / ul 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.26 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.05 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.67 X 103 / pL  0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / uL 0.0-0.3\nTOTAL RBC 4.19 X10%6/uL =: 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 12.1 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 43.4 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 103.6 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 28.9 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 27.9 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 59.7 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 15.9 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 19 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 12.9 fL 6.5-12\nPLATELET COUNT 231 X 103 / uL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 47.3 % 19.7-42.4\nPLATELETCRIT(PCT) 0.3 % 0.19-0.39\nRemarks: = ALERT !!! Eosinophilia\n\nPlease Correlate with clinical conditions.\n\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semiconductor laser), and SLS- hemoglobin method)\n\n \n\nSample Collected on (SCT)\nSample Received on (SRT)\nReport Released on (RRT)\n\n217 May 2019 08:00\n:18 May 2019 16:03\n218 May 2019 17:08\n\nSample Type : EDTA . .\nDr.Siva Ranjan MD(Path) Dr.Caesar Sengupta MD(Micro)\nLab ...
#  'PROCESSED AT:\n\nThyrocare Th CO ®\nH. NO. 1-9-645,Vidyanagar, yr Care\n\nAdikmet Road,Near SBH,\n\nThink Thyroid. Think Thyrocare.\nHyderabad-500 044\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nNAME : MRS K SANDYA (32Y/F) SAMPLE COLLECTED AT\n. (18900), INDIRA DIAGNOSTIC\n\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : HEMOGRAM - 6 PART (DIFF),HBA PRADESH,531116\n\nTEST NAME TECHNOLOGY VALUE UNITS\nHbAi1c - (HPLC - NGSP Certified)\n\nH.P.L.C 7.2 %\n\nReference Range :\n\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\n\nBelow 5.7% : Normal Below 6.5% : Good Control\n\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n\n>8% : Poor Control\n\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\n\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 160 mg/dl\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n\n> 180 mg/dl : Poor Control\n\nMethod : Derived from HBA1c_ values\n\nPlease correlate with clinical conditions.\nSample Collected on (SCT) :17 May 2019 08:00\nSample Received on (SRT) :18 May 2019 16:03 “\nReport Released on (RRT) 218 May 2019 17:08 wt\nSample Type bres. #EDTA Dr.Siva Ranjan MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode 1 1805072695/A6750\n\nRe . Page : 1 of 9\nBarcode Ou 1M9261454\n\x0cPROCESSED AT:\nThyrocare\n\nH. NO. 1-9-645,Vidyanagar,\n\nAdikmet Road,Near SBH,\n\nHyderabad-500 044\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\n \n\nNAME MRS K SANDYA (32Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED HEMOGRANM - 6 PART (DIFF),HBA PRADESH,531116\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 6.6 X 103 / uL 4.0-10.0\nNEUTROPHILS 58.1 % 40-80\nLYMPHOCYTE PERCENTAGE 26.7 % 20.0-40.0\nMONOCYTES 3.9 % 0.0-10.0\nEOSINOPHILS 10.2 % 0.0-6.0\nBASOPHILS 0.8 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.3 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 3.83 X 103 / uL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 1.76 X 103 / ul 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.26 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.05 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.67 X 103 / pL  0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / uL 0.0-0.3\nTOTAL RBC 4.19 X10%6/uL =: 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 12.1 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 43.4 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 103.6 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 28.9 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 27.9 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 59.7 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 15.9 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 19 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 12.9 fL 6.5-12\nPLATELET COUNT 231 X 103 / uL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 47.3 % 19.7-42.4\nPLATELETCRIT(PCT) 0.3 % 0.19-0.39\nRemarks: = ALERT !!! Eosinophilia\n\nPlease Correlate with clinical conditions.\n\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semiconductor laser), and SLS- hemoglobin method)\n\n \n\nSample Collected on (SCT)\nSample Received on (SRT)\nReport Released on (RRT)\n\n217 May 2019 08:00\n:18 May 2019 16:03\n218 May 2019 17:08\n\nSample Type : EDTA . .\nDr.Siva Ranjan MD(Path) Dr.Caesar Sengupta MD(Micro)\nLab ...
#  'PROCESSED AT:\n\nThyrocare meCAP Thyro C ar eC\n\nD-37/1,TTC MIDC,Turbhe, COLLEGE of AMERICAN PATHOLOGISTS . . .\nNavi Mumbai-400 703 ceanthewo. NSsaor Think Thyroid. Think Thyrocare.\n\n   \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : MRS K DEVI (35Y/F) SAMPLE COLLECTED AT\n. (5311164139),MYTHRI MEDICAL CENTRE,MAIN RD,\nREF. BY : DR G VIJAYASANTHI MBBS DGO,OTHER NARSIPATNAM, ANDHRA PRADESH, 531116\nTEST ASKED : T3-T4-TSH\nTEST NAME TECHNOLOGY VALUE UNITS REFERENCE RANGE\nTOTAL TRIIODOTHYRONINE (T3) C.LI.A 118 ng/d| 60-200\nTOTAL THYROXINE (T4) C.L.L.A 12.9 ug/dl 4.5-12\nTHYROID STIMULATING HORMONE (TSH) C.LI.A 5.14 HIU/ml 0.3-5.5\n\nComments: IF NOT ON DRUGS SUGGESTED FT3 & FT4 ESTIMATION\n\nPlease correlate with clinical conditions.\n\nMethod :\n\nT3 - Competitive Chemi Luminescent Immuno Assay\n\nT4 - Competitive Chemi Luminescent Immuno Assay\nTSH - SANDWICH CHEMI LUMINESCENT IMMUNO ASSAY\nPregnancy reference ranges for TSH\n\n1st Trimester : 0.10 - 2.50\n\n2nd Trimester : 0.20 - 3.00\n\n3rd Trimester : 0.30 - 3.00\n\nReference:\nGuidelines of American Thyroid Association for the Diagnosis and Management of Thyroid Disease During\nPregnancy and Postpartum, Thyroid, 2011, 21; 1-46\n\n~~ End of report ~~\n\nSample Collected on (SCT) : 26 Aug 2019 17:00\n\nSample Received on (SRT) : 27 Aug 2019 22:52 ac tt?\nReport Released on (RRT) : 28 Aug 2019 02:22 Oe ea\n\nSample Type OF . © : SERUM io .\n= Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode : 2708040474/A6750\n\nF100) . Page : 1 of 2\nBarcode Ou : 00274398\n\x0c',
#  'PROCESSED AT:\n\nThyrocare meCAP Thyro C ar eC\n\nD-37/1,TTC MIDC,Turbhe, COLLEGE of AMERICAN PATHOLOGISTS . . .\nNavi Mumbai-400 703 ceanthewo. NSsaor Think Thyroid. Think Thyrocare.\n\n   \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : MRS K DEVI (35Y/F) SAMPLE COLLECTED AT\n. (5311164139),MYTHRI MEDICAL CENTRE,MAIN RD,\nREF. BY : DR G VIJAYASANTHI MBBS DGO,OTHER NARSIPATNAM, ANDHRA PRADESH, 531116\nTEST ASKED : T3-T4-TSH\nTEST NAME TECHNOLOGY VALUE UNITS REFERENCE RANGE\nTOTAL TRIIODOTHYRONINE (T3) C.LI.A 118 ng/d| 60-200\nTOTAL THYROXINE (T4) C.L.L.A 12.9 ug/dl 4.5-12\nTHYROID STIMULATING HORMONE (TSH) C.LI.A 5.14 HIU/ml 0.3-5.5\n\nComments: IF NOT ON DRUGS SUGGESTED FT3 & FT4 ESTIMATION\n\nPlease correlate with clinical conditions.\n\nMethod :\n\nT3 - Competitive Chemi Luminescent Immuno Assay\n\nT4 - Competitive Chemi Luminescent Immuno Assay\nTSH - SANDWICH CHEMI LUMINESCENT IMMUNO ASSAY\nPregnancy reference ranges for TSH\n\n1st Trimester : 0.10 - 2.50\n\n2nd Trimester : 0.20 - 3.00\n\n3rd Trimester : 0.30 - 3.00\n\nReference:\nGuidelines of American Thyroid Association for the Diagnosis and Management of Thyroid Disease During\nPregnancy and Postpartum, Thyroid, 2011, 21; 1-46\n\n~~ End of report ~~\n\nSample Collected on (SCT) : 26 Aug 2019 17:00\n\nSample Received on (SRT) : 27 Aug 2019 22:52 ac tt?\nReport Released on (RRT) : 28 Aug 2019 02:22 Oe ea\n\nSample Type OF . © : SERUM io .\n= Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\nLabcode : 2708040474/A6750\n\nF100) . Page : 1 of 2\nBarcode Ou : 00274398\n\x0cCONDITIONS OF REPORTING\n\n“ The reported results are for information and interpretation of the referring doctor only.\n\n“It is presumed that the tests performed on the specimen belong to the patient; named or identified.\n\n“Results of tests may vary from laboratory to laboratory and also in some parameters from time to time for the\nsame patient.\n\n“Should the results indicate an unexpected abnormality, the same should be reconfirmed.\n\n“Only such medical professionals who understand reporting units, reference ranges and limitations of\ntechnologies should interpret results.\n\n“This report is not valid for medico-legal purpose.\n\n“Neither Thyrocare, nor its employees/representatives assume any liability, responsibility for any loss or\ndamage that may be incurred by any person as a result of presuming the meaning or contents of the report.\n\nEXPLANATIONS\n\n“Majority of the specimen processed in the laboratory are collected by Pathologists and Hospitals we call them\nas "Clients".\n\n~* Name - The name is as declared by the client and recored by the personnel who collected the specimen.\n\n“  Ref.Dr - The name of the doctor who has recommended testing as declared by the client.\n\n“ Labcode - This is the accession number in our laboratory and it helps us in archiving and retrieving the data.\n\n“Barcode - This is the specimen identity number and it states that the results are for the specimen bearing\nthe barcode (irrespective of the name).\n\nSCP - Specimen Collection Point - This is the location where the blood or specimen was collected as declared by\nthe client.\n\n“SCT - Specimen Collection Time - The time when specimen was collected as declared by the client.\n\n“SRT - Specimen Receiving Time - This time when the specimen reached our laboratory.\n\n“* RRT - Report Releasing Time - The time when our pathologist has released the values for Reporting.\n\n“ Reference Range - Means the range of values in which 95% of the normal population would fall.\n\nSUGGESTIONS\n\n“+ Values out of reference range requires reconfirmation before starting any medical treatment.\n\n“* Retesting is needed if you suspect any quality shortcomings.\n\n“* Testing or retesting should be done in accredited laboratories.\n\n“For suggestions, complaints or  ...

# %%
    data = []
    for row in text1.split('\n'):
        for word in list(word_list):
            if row.startswith(word):
                word = row.split()
                word = word
                for word_name in list(word):  
                    if word_name in stopwords:

                        word.remove(word_name)

                for i in word:
                    if  solve(i):
                        null = i
                        word.remove(null)
                        i = float(i)

                word = [x for x in word if not isinstance(x, int)]   
                word = [' '.join(word)]
                print(word)
                word.append(i)
                #word.remove(str(i))
                print(word)
                data.append(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-151d16ddfe84> in <module>
#       1 data = []
# ----> 2 for row in text1.split('\n'):
#       3     for word in list(word_list):
#       4         if row.startswith(word):
#       5             word = row.split()
#
# NameError: name 'text1' is not defined

# %%
 extracted_DataFrame = pd.DataFrame(data)

# %%
   #Data Cleaning
        extracted_DataFrame.columns = ['Keys','Values']
    #        extracted_DataFrame.rename(columns={'Keys':'Values'},inplace=True)
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\d+', '')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\.','')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.replace('\-','')
        extracted_DataFrame['Keys'] = extracted_DataFrame['Keys'].str.rstrip()
        extracted_DataFrame['Values'] = extracted_DataFrame['Values'].apply(lambda x: pd.to_numeric(x, errors = 'coerce')).dropna()
        extracted_DataFrame = extracted_DataFrame.dropna(axis=0)
        #DataFrame to Dictionary
        extracted_Dictionary = extracted_DataFrame.set_index('Keys')['Values'].to_dict()

# %%
 Report_Dictionary = {}

        if 'HPLC' in extracted_Dictionary.keys():
            HPLC = extracted_Dictionary['HPLC']
            Report_Dictionary["HPLC"] = HPLC
        else:
            Report_Dictionary["HPLC"] = None
        if 'AVERAGE BLOOD GLUCOSE (ABG)' in extracted_Dictionary.keys():
            AVERAGE_BLOOD_GLUCOSE = extracted_Dictionary['AVERAGE BLOOD GLUCOSE (ABG)']
            Report_Dictionary["AVERAGE_BLOOD_GLUCOSE"] = AVERAGE_BLOOD_GLUCOSE
        else:
            Report_Dictionary["AVERAGE_BLOOD_GLUCOSE"] = None
        if 'TOTAL LEUCOCYTES COUNT' in extracted_Dictionary.keys():
            TOTAL_LEUCOCYTES_COUNT = extracted_Dictionary['TOTAL LEUCOCYTES COUNT']
            Report_Dictionary["TOTAL_LEUCOCYTES_COUNT"] = TOTAL_LEUCOCYTES_COUNT
        else:
            Report_Dictionary["TOTAL_LEUCOCYTES_COUNT"] = None

        if 'NEUTROPHILS' in extracted_Dictionary.keys():
            NEUTROPHILS = extracted_Dictionary['NEUTROPHILS']
            Report_Dictionary["NEUTROPHILS"] = NEUTROPHILS
        else:
            Report_Dictionary["NEUTROPHILS"] = None

        if 'LYMPHOCYTE PERCENTAGE' in extracted_Dictionary.keys():
            LYMPHOCYTE_PERCENTAGE = extracted_Dictionary['LYMPHOCYTE PERCENTAGE']
            Report_Dictionary["LYMPHOCYTE_PERCENTAGE"] = LYMPHOCYTE_PERCENTAGE
        else:
            Report_Dictionary["LYMPHOCYTE_PERCENTAGE"] = None

        if 'MONOCYTES' in extracted_Dictionary.keys():
            MONOCYTES = extracted_Dictionary['MONOCYTES']
            Report_Dictionary["MONOCYTES"] = MONOCYTES
        else:
            Report_Dictionary["MONOCYTES"] = None

        if 'EOSINOPHILS' in extracted_Dictionary.keys():
            EOSINOPHILS = extracted_Dictionary['EOSINOPHILS']
            Report_Dictionary["EOSINOPHILS"] = EOSINOPHILS
        else:
            Report_Dictionary["EOSINOPHILS"] = None

        if 'BASOPHILS' in extracted_Dictionary.keys():
            BASOPHILS = extracted_Dictionary['BASOPHILS']
            Report_Dictionary["BASOPHILS"] = BASOPHILS
        else:
            Report_Dictionary["BASOPHILS"] = None

        if 'IMMATURE GRANULOCYTE' in extracted_Dictionary.keys():
            IMMATURE_GRANULOCYTE_PERCENTAGE = extracted_Dictionary['IMMATURE GRANULOCYTE']
            Report_Dictionary["IMMATURE_GRANULOCYTE_PERCENTAGE"] = IMMATURE_GRANULOCYTE_PERCENTAGE
        else:
            Report_Dictionary["IMMATURE_GRANULOCYTE_PERCENTAGE"] = None

        if 'NEUTROPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            NEUTROPHILS_ABSOLUTE_COUNT = extracted_Dictionary['NEUTROPHILS ABSOLUTE COUNT']
            Report_Dictionary["NEUTROPHILS_ABSOLUTE_COUNT"] = NEUTROPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["NEUTROPHILS_ABSOLUTE_COUNT"] = None

        if 'LYMPHOCYTES ABSOLUTE COUNT' in extracted_Dictionary.keys():
            LYMPHOCYTES_ABSOLUTE_COUNT = extracted_Dictionary['LYMPHOCYTES ABSOLUTE COUNT']
            Report_Dictionary["LYMPHOCYTES_ABSOLUTE_COUNT"] = LYMPHOCYTES_ABSOLUTE_COUNT
        else:
            Report_Dictionary["LYMPHOCYTES_ABSOLUTE_COUNT"] = None

        if 'MONOCYTES ABSOLUTE COUNT' in extracted_Dictionary.keys():
            MONOCYTES_ABSOLUTE_COUNT = extracted_Dictionary['MONOCYTES ABSOLUTE COUNT']
            Report_Dictionary["MONOCYTES_ABSOLUTE_COUNT"] = MONOCYTES_ABSOLUTE_COUNT
        else:
            Report_Dictionary["MONOCYTES_ABSOLUTE_COUNT"] = None

        if 'BASOPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            BASOPHILS_ABSOLUTE_COUNT = extracted_Dictionary['BASOPHILS ABSOLUTE COUNT']
            Report_Dictionary["BASOPHILS_ABSOLUTE_COUNT"] = BASOPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["BASOPHILS_ABSOLUTE_COUNT"] = None

        if 'EOSINOPHILS ABSOLUTE COUNT' in extracted_Dictionary.keys():
            EOSINOPHILS_ABSOLUTE_COUNT = extracted_Dictionary['EOSINOPHILS ABSOLUTE COUNT']
            Report_Dictionary["EOSINOPHILS_ABSOLUTE_COUNT"] = EOSINOPHILS_ABSOLUTE_COUNT
        else:
            Report_Dictionary["EOSINOPHILS_ABSOLUTE_COUNT"] = None

        if 'IMMATURE GRANULOCYTES(IG)' in extracted_Dictionary.keys():
            IMMATURE_GRANULOCYTES = extracted_Dictionary['IMMATURE GRANULOCYTES(IG)']
            Report_Dictionary["IMMATURE_GRANULOCYTES"] = IMMATURE_GRANULOCYTES
        else:
            Report_Dictionary["IMMATURE_GRANULOCYTES"] = None

        if 'TOTAL RBC' in extracted_Dictionary.keys():
            TOTAL_RBC = extracted_Dictionary['TOTAL RBC']
            Report_Dictionary["TOTAL_RBC"] = TOTAL_RBC
        else:
            Report_Dictionary["TOTAL_RBC"] = None

        if 'NUCLEATED RED BLOOD CELLS' in extracted_Dictionary.keys():
            NUCLEATED_RED_BLOOD_CELLS = extracted_Dictionary['NUCLEATED RED BLOOD CELLS']
            Report_Dictionary["NUCLEATED_RED_BLOOD_CELLS"] = NUCLEATED_RED_BLOOD_CELL

        else:
            Report_Dictionary["NUCLEATED_RED_BLOOD_CELLS"] = None


        if 'HEMOGLOBIN' in extracted_Dictionary.keys():
            HEMOGLOBIN = extracted_Dictionary['HEMOGLOBIN']
            Report_Dictionary["HEMOGLOBIN"] = HEMOGLOBIN
        else:
            Report_Dictionary["HEMOGLOBIN"] = None

        if 'HEMATOCRIT(PCV)' in extracted_Dictionary.keys():
            HEMATOCRIT = extracted_Dictionary['HEMATOCRIT(PCV)']
            Report_Dictionary["HEMATOCRIT"] = HEMATOCRIT
        else:
            Report_Dictionary["HEMATOCRIT"] = None

        if 'MEAN CORPUSCULAR VOLUME(MCV)' in extracted_Dictionary.keys():
            MEAN_CORPUSCULAR_VOLUME = extracted_Dictionary['MEAN CORPUSCULAR VOLUME(MCV)']
            Report_Dictionary["MEAN_CORPUSCULAR_VOLUME"] = MEAN_CORPUSCULAR_VOLUME
        else:
            Report_Dictionary["MEAN_CORPUSCULAR_VOLUME"] = None

        if 'MEAN CORPUSCULAR HEMOGLOBIN(MCH)' in extracted_Dictionary.keys():
            MEAN_CORPUSCULAR_HEMOGLOBIN = extracted_Dictionary['MEAN CORPUSCULAR HEMOGLOBIN(MCH)']
            Report_Dictionary["MEAN_CORPUSCULAR_HEMOGLOBIN"] = MEAN_CORPUSCULAR_HEMOGLOBIN
        else:
            Report_Dictionary["MEAN_CORPUSCULAR_HEMOGLOBIN"] = None

        if 'MEAN CORPHEMOCONC(MCHC)' in extracted_Dictionary.keys():
            MEAN_CORP_HEMO_CONC = extracted_Dictionary['MEAN CORPHEMOCONC(MCHC)']
            Report_Dictionary["MEAN_CORP_HEMO_CONC"] = MEAN_CORP_HEMO_CONC
        else:
            Report_Dictionary["MEAN_CORP_HEMO_CONC"] = None

        if 'RED CELL DISTRIBUTION WIDTH SD(RDWSD)' in extracted_Dictionary.keys():
            RED_CELL_DISTRIBUTION_WIDTH_SD = extracted_Dictionary['RED CELL DISTRIBUTION WIDTH SD(RDWSD)']
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_SD"] = RED_CELL_DISTRIBUTION_WIDTH_SD
        else:
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_SD"] = None

        if 'RED CELL DISTRIBUTION WIDTH (RDWCV)' in extracted_Dictionary.keys():
            RED_CELL_DISTRIBUTION_WIDTH_CV = extracted_Dictionary['RED CELL DISTRIBUTION WIDTH (RDWCV)']
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_CV"] = RED_CELL_DISTRIBUTION_WIDTH_CV
        else:
            Report_Dictionary["RED_CELL_DISTRIBUTION_WIDTH_CV"] = None

        if 'PLATELET DISTRIBUTION WIDTH(PDW)' in extracted_Dictionary.keys():
            PLATELET_DISTRIBUTION_WIDTH = extracted_Dictionary['PLATELET DISTRIBUTION WIDTH(PDW)']
            Report_Dictionary["PLATELET_DISTRIBUTION_WIDTH"] = PLATELET_DISTRIBUTION_WIDTH
        else:
            Report_Dictionary["PLATELET_DISTRIBUTION_WIDTH"] = None

        if 'MEAN PLATELET VOLUME(MPV)' in extracted_Dictionary.keys():
            MEAN_PLATELET_VOLUME = extracted_Dictionary['MEAN PLATELET VOLUME(MPV)']
            Report_Dictionary["MEAN_PLATELET_VOLUME"] = MEAN_PLATELET_VOLUME
        else:
            Report_Dictionary["MEAN_PLATELET_VOLUME"] = None

        if 'PLATELET COUNT' in extracted_Dictionary.keys():
            PLATELET_COUNT = extracted_Dictionary['PLATELET COUNT']
            Report_Dictionary["PLATELET_COUNT"] = PLATELET_COUNT
        else:
            Report_Dictionary["PLATELET_COUNT"] = None

        if 'PLATELET TO LARGE CELL RATIO(PLCR)' in extracted_Dictionary.keys():
            PLATELET_TO_LARGE_CELL_RATIO = extracted_Dictionary['PLATELET TO LARGE CELL RATIO(PLCR)']
            Report_Dictionary["PLATELET_TO_LARGE_CELL_RATIO"] = PLATELET_TO_LARGE_CELL_RATIO
        else:
            Report_Dictionary["PLATELET_TO_LARGE_CELL_RATIO"] = None

        if 'PLATELETCRIT(PCT)' in extracted_Dictionary.keys():
            PLATELETCRIT = extracted_Dictionary['PLATELETCRIT(PCT)']
            Report_Dictionary["PLATELETCRIT"] = PLATELETCRIT
        else:
            Report_Dictionary["PLATELETCRIT"] = None

        if 'ARSENIC' in extracted_Dictionary.keys():
            ARSENIC = extracted_Dictionary['ARSENIC']
            Report_Dictionary["ARSENIC"] = ARSENIC
        else:
            Report_Dictionary["ARSENIC"] = None


        if 'CADMIUM' in extracted_Dictionary.keys():
            CADMIUM = extracted_Dictionary['CADMIUM']
            Report_Dictionary["CADMIUM"] = CADMIUM
        else:
            Report_Dictionary["CADMIUM"] = None


        if 'MERCURY' in extracted_Dictionary.keys():
            MERCURY = extracted_Dictionary['MERCURY']
            Report_Dictionary["MERCURY"] = MERCURY
        else:
            Report_Dictionary["MERCURY"] = None


        if 'LEAD' in extracted_Dictionary.keys():
            LEAD = extracted_Dictionary['LEAD']
            Report_Dictionary["LEAD"] = LEAD
        else:
            Report_Dictionary["LEAD"] = None


        if 'CHROMIUM' in extracted_Dictionary.keys():
            CHROMIUM = extracted_Dictionary['CHROMIUM']
            Report_Dictionary["CHROMIUM"] = CHROMIUM
        else:
            Report_Dictionary["CHROMIUM"] = None


        if 'BARIUM' in extracted_Dictionary.keys():
            BARIUM = extracted_Dictionary['BARIUM']
            Report_Dictionary["BARIUM"] = BARIUM
        else:
            Report_Dictionary["BARIUM"] = None


        if 'COBALT' in extracted_Dictionary.keys():
            COBALT = extracted_Dictionary['COBALT']
            Report_Dictionary["COBALT"] = COBALT
        else:
            Report_Dictionary["COBALT"] = None


        if 'CAESIUM' in extracted_Dictionary.keys():
            CAESIUM = extracted_Dictionary['CAESIUM']
            Report_Dictionary["CAESIUM"] = CAESIUM
        else:
            Report_Dictionary["CAESIUM"] = None


        if 'THALLIUM' in extracted_Dictionary.keys():
            THALLIUM = extracted_Dictionary['THALLIUM']
            Report_Dictionary["THALLIUM"] = THALLIUM
        else:
            Report_Dictionary["THALLIUM"] = None


        if 'URANIUM' in extracted_Dictionary.keys():
            URANIUM = extracted_Dictionary['URANIUM']
            Report_Dictionary["URANIUM"] = URANIUM
        else:
            Report_Dictionary["URANIUM"] = None


        if 'STRONTIUM' in extracted_Dictionary.keys():
            STRONTIUM = extracted_Dictionary['STRONTIUM']
            Report_Dictionary["STRONTIUM"] = STRONTIUM
        else:
            Report_Dictionary["STRONTIUM"] = None


        if 'ANTIMONY' in extracted_Dictionary.keys():
            ANTIMONY = extracted_Dictionary['ANTIMONY']
            Report_Dictionary["ANTIMONY"] = ANTIMONY
        else:
            Report_Dictionary["ANTIMONY"] = None


        if 'TIN' in extracted_Dictionary.keys():
            TIN = extracted_Dictionary['TIN']
            Report_Dictionary["TIN"] = TIN
        else:
            Report_Dictionary["TIN"] = None


        if 'MOLYBDENUM' in extracted_Dictionary.keys():
            MOLYBDENUM = extracted_Dictionary['MOLYBDENUM']
            Report_Dictionary["MOLYBDENUM"] = MOLYBDENUM
        else:
            Report_Dictionary["MOLYBDENUM"] = None



        if 'SILVER' in extracted_Dictionary.keys():
            SILVER = extracted_Dictionary['SILVER']
            Report_Dictionary["SILVER"] = SILVER
        else:
            Report_Dictionary["SILVER"] = None


        if 'VANADIUM' in extracted_Dictionary.keys():
            VANADIUM = extracted_Dictionary['VANADIUM']
            Report_Dictionary["VANADIUM"] = VANADIUM
        else:
            Report_Dictionary["VANADIUM"] = None


        if 'BERYLLIUM' in extracted_Dictionary.keys():
            BERYLLIUM = extracted_Dictionary['BERYLLIUM']
            Report_Dictionary["BERYLLIUM"] = BERYLLIUM
        else:
            Report_Dictionary["BERYLLIUM"] = None



        if 'BISMUTH' in extracted_Dictionary.keys():
            BISMUTH = extracted_Dictionary['BISMUTH']
            Report_Dictionary["BISMUTH"] = BISMUTH
        else:
            Report_Dictionary["BISMUTH"] = None


        if 'SELENIUM' in extracted_Dictionary.keys():
            SELENIUM = extracted_Dictionary['SELENIUM']
            Report_Dictionary["SELENIUM"] = SELENIUM
        else:
            Report_Dictionary["SELENIUM"] = None


        if 'ALUMINIUM' in extracted_Dictionary.keys():
            ALUMINIUM = extracted_Dictionary['ALUMINIUM']
            Report_Dictionary["ALUMINIUM"] = ALUMINIUM
        else:
            Report_Dictionary["ALUMINIUM"] = None


        if 'NICKEL' in extracted_Dictionary.keys():
            NICKEL = extracted_Dictionary['NICKEL']
            Report_Dictionary["NICKEL"] = NICKEL
        else:
            Report_Dictionary["NICKEL"] = None


        if 'MANGANESE' in extracted_Dictionary.keys():
            MANGANESE = extracted_Dictionary['MANGANESE']
            Report_Dictionary["MANGANESE"] = MANGANESE
        else:
            Report_Dictionary["MANGANESE"] = None


        if 'HOMOCYSTEINE' in extracted_Dictionary.keys():
            HOMOCYSTEINE = extracted_Dictionary['HOMOCYSTEINE']
            Report_Dictionary["HOMOCYSTEINE"] = HOMOCYSTEINE
        else:
            Report_Dictionary["HOMOCYSTEINE"] = None


        if 'CYSTATIN C' in extracted_Dictionary.keys():
            CYSTATIN_C = extracted_Dictionary['CYSTATIN C']
            Report_Dictionary["CYSTATIN_C"] = CYSTATIN_C
        else:
            Report_Dictionary["CYSTATIN_C"] = None

        if 'LIPOPROTEIN' in extracted_Dictionary.keys():
            LIPOPROTEIN = extracted_Dictionary['LIPOPROTEIN']
            Report_Dictionary["LIPOPROTEIN"] = LIPOPROTEIN
        else:
            Report_Dictionary["LIPOPROTEIN"] = None


        if 'VITAMIN B' in extracted_Dictionary.keys():
            VITAMIN_B = extracted_Dictionary['VITAMIN B']
            Report_Dictionary["VITAMIN_B"] = VITAMIN_B
        else:
            Report_Dictionary["VITAMIN_B"] = None


        if 'APOLIPOPROTEIN A (APOA)' in extracted_Dictionary.keys():
            APOLIPOPROTEIN_A_APOA = extracted_Dictionary['APOLIPOPROTEIN A (APOA)']
            Report_Dictionary["APOLIPOPROTEIN_A_APOA"] = APOLIPOPROTEIN_A_APOA
        else:
            Report_Dictionary["APOLIPOPROTEIN_A_APOA"] = None


        if 'APOLIPOPROTEIN B (APOB)' in extracted_Dictionary.keys():
            APOLIPOPROTEIN_B_APOB = extracted_Dictionary['APOLIPOPROTEIN B (APOB)']
            Report_Dictionary["APOLIPOPROTEIN_B_APOB"] = APOLIPOPROTEIN_B_APOB
        else:
            Report_Dictionary["APOLIPOPROTEIN_B_APOB"] = None

        if 'APO B APO Ai (APO B/A)' in extracted_Dictionary.keys():
            APOB_APOA_RATIO = extracted_Dictionary['APO B APO Ai (APO B/A)']
            Report_Dictionary["APOB_APOA_RATIO"] = APOB_APOA_RATIO
        else:
            Report_Dictionary["APOB_APOA_RATIO"] = None



        if 'HIGH SENSITIVITY CREACTIVE PROTEIN (HSCRP)' in extracted_Dictionary.keys():
            HSCRP = extracted_Dictionary['HIGH SENSITIVITY CREACTIVE PROTEIN (HSCRP)']
            Report_Dictionary["HSCRP"] = HSCRP
        else:
            Report_Dictionary["HSCRP"] = None


        if 'SERUM COPPER' in extracted_Dictionary.keys():
            SERUM_COPPER = extracted_Dictionary['SERUM COPPER']
            Report_Dictionary["SERUM_COPPER"] = SERUM_COPPER
        else:
            Report_Dictionary["SERUM_COPPER"] = None


        if 'SERUM ZINC' in extracted_Dictionary.keys():
            SERUM_ZINC = extracted_Dictionary['SERUM ZINC']
            Report_Dictionary["SERUM_ZINC"] = SERUM_ZINC
        else:
            Report_Dictionary["SERUM_ZINC"] = None


        if 'TESTOSTERONE' in extracted_Dictionary.keys():
            TESTOSTERONE = extracted_Dictionary['TESTOSTERONE']
            Report_Dictionary["TESTOSTERONE"] = TESTOSTERONE
        else:
            Report_Dictionary["TESTOSTERONE"] = None

        if 'IRON' in extracted_Dictionary.keys():
            IRON = extracted_Dictionary['IRON']
            Report_Dictionary["IRON"] = IRON
        else:
            Report_Dictionary["IRON"] = None

        if 'TOTAL IRON BINDING CAPACITY (TIBC)' in extracted_Dictionary.keys():
            TOTAL_IRON_BINDING_CAPACITY = extracted_Dictionary['TOTAL IRON BINDING CAPACITY (TIBC)']
            Report_Dictionary["TOTAL_IRON_BINDING_CAPACITY"] = TOTAL_IRON_BINDING_CAPACITY
        else:
            Report_Dictionary["TOTAL_IRON_BINDING_CAPACITY"] = None


        if 'TRANSFERRIN SATURATION' in extracted_Dictionary.keys():
            TRANSFERRIN_SATURATION = extracted_Dictionary['TRANSFERRIN SATURATION']
            Report_Dictionary["TRANSFERRIN_SATURATION"] = TRANSFERRIN_SATURATION
        else:
            Report_Dictionary["TRANSFERRIN_SATURATION"] = None

        if 'ALKALINE PHOSPHATASE' in extracted_Dictionary.keys():
            ALKALINE_PHOSPHATASE = extracted_Dictionary['ALKALINE PHOSPHATASE']
            Report_Dictionary["ALKALINE_PHOSPHATASE"] = ALKALINE_PHOSPHATASE
        else:
            Report_Dictionary["ALKALINE_PHOSPHATASE"] = None

        if 'BILIRUBIN TOTAL' in extracted_Dictionary.keys():
            BILIRUBIN_TOTAL = extracted_Dictionary['BILIRUBIN TOTAL']
            Report_Dictionary["BILIRUBIN_TOTAL"] = BILIRUBIN_TOTAL
        else:
            Report_Dictionary["BILIRUBIN_TOTAL"] = None

        if 'BILIRUBIN DIRECT' in extracted_Dictionary.keys():
            BILIRUBIN_DIRECT = extracted_Dictionary['BILIRUBIN DIRECT']
            Report_Dictionary["BILIRUBIN_DIRECT"] = BILIRUBIN_DIRECT
        else:
            Report_Dictionary["BILIRUBIN_DIRECT"] = None

        if 'BILIRUBIN (INDIRECT)' in extracted_Dictionary.keys():
            BILIRUBIN_INDIRECT = extracted_Dictionary['BILIRUBIN (INDIRECT)']
            Report_Dictionary["BILIRUBIN_INDIRECT"] = BILIRUBIN_INDIRECT
        else:
            Report_Dictionary["BILIRUBIN_INDIRECT"] = None

        if 'GAMMA GLUTAMYL TRANSFERASE (GGT)' in extracted_Dictionary.keys():
            GAMMA_GLUTAMYL_TRANSFERASE = extracted_Dictionary['GAMMA GLUTAMYL TRANSFERASE (GGT)']
            Report_Dictionary["GAMMA_GLUTAMYL_TRANSFERASE"] = GAMMA_GLUTAMYL_TRANSFERASE
        else:
            Report_Dictionary["GAMMA_GLUTAMYL_TRANSFERASE"] = None


        if 'ASPARTATE AMINOTRANSFERASE' in extracted_Dictionary.keys():
            ASPARTATE_AMINOTRANSFERASE = extracted_Dictionary['ASPARTATE AMINOTRANSFERASE']
            Report_Dictionary["ASPARTATE_AMINOTRANSFERASE"] = ASPARTATE_AMINOTRANSFERASE
        else:
            Report_Dictionary["ASPARTATE_AMINOTRANSFERASE"] = None

        if 'ALANINE TRANSAMINASE (SGPT)' in extracted_Dictionary.keys():
            ALANINE_TRANSAMINASE = extracted_Dictionary['ALANINE TRANSAMINASE (SGPT)']
            Report_Dictionary["ALANINE_TRANSAMINASE"] = ALANINE_TRANSAMINASE
        else:
            Report_Dictionary["ALANINE_TRANSAMINASE"] = None

        if 'PROTEIN TOTAL' in extracted_Dictionary.keys():
            PROTEIN_TOTAL = extracted_Dictionary['PROTEIN TOTAL']
            Report_Dictionary["PROTEIN_TOTAL"] = PROTEIN_TOTAL
        else:
            Report_Dictionary["PROTEIN_TOTAL"] = None

        if 'ALBUMIN SERUM' in extracted_Dictionary.keys():
            ALBUMIN_SERUM = extracted_Dictionary['ALBUMIN SERUM']
            Report_Dictionary["ALBUMIN_SERUM"] = ALBUMIN_SERUM
        else:
            Report_Dictionary["ALBUMIN_SERUM"] = None

        if 'SERUM ALB/GLOBULIN' in extracted_Dictionary.keys():
            SERUM_ALB = extracted_Dictionary['SERUM ALB/GLOBULIN']
            Report_Dictionary["SERUM_ALB"] = SERUM_ALB
        else:
            Report_Dictionary["SERUM_ALB"] = None

        if 'SERUM GLOBULIN' in extracted_Dictionary.keys():
            SERUM_GLOBULIN = extracted_Dictionary['SERUM GLOBULIN']
            Report_Dictionary["SERUM_GLOBULIN"] = SERUM_GLOBULIN
        else:
            Report_Dictionary["SERUM_GLOBULIN"] = None

        if 'TOTAL CHOLESTEROL' in extracted_Dictionary.keys():
            TOTAL_CHOLESTEROL = extracted_Dictionary['TOTAL CHOLESTEROL']
            Report_Dictionary["TOTAL_CHOLESTEROL"] = TOTAL_CHOLESTEROL
        else:
            Report_Dictionary["TOTAL_CHOLESTEROL"] = None

        if 'HDL CHOLESTEROL DIRECT' in extracted_Dictionary.keys():
            HDL_CHOLESTEROL_DIRECT = extracted_Dictionary['HDL CHOLESTEROL DIRECT']
            Report_Dictionary["HDL_CHOLESTEROL_DIRECT"] = HDL_CHOLESTEROL_DIRECT
        else:
            Report_Dictionary["HDL_CHOLESTEROL_DIRECT"] = None

        if 'LDL CHOLESTEROL DIRECT' in extracted_Dictionary.keys():
            LDL_CHOLESTEROL_DIRECT = extracted_Dictionary['LDL CHOLESTEROL DIRECT']
            Report_Dictionary["LDL_CHOLESTEROL_DIRECT"] = LDL_CHOLESTEROL_DIRECT
        else:
            Report_Dictionary["LDL_CHOLESTEROL_DIRECT"] = None

        if 'TRIGLYCERIDES' in extracted_Dictionary.keys():
            TRIGLYCERIDES = extracted_Dictionary['TRIGLYCERIDES']
            Report_Dictionary["TRIGLYCERIDES"] = TRIGLYCERIDES
        else:
            Report_Dictionary["TRIGLYCERIDES"] = None

        if 'TC/ HDL CHOLESTEROL' in extracted_Dictionary.keys():
            TC_HDL_CHOLESTEROL_RATIO = extracted_Dictionary['TC/ HDL CHOLESTEROL']
            Report_Dictionary["TC_HDL_CHOLESTEROL_RATIO"] = TC_HDL_CHOLESTEROL_RATIO
        else:
            Report_Dictionary["TC_HDL_CHOLESTEROL_RATIO"] = None

        if 'LDL HDL' in extracted_Dictionary.keys():
            LDL_HDL_RATIO = extracted_Dictionary['LDL HDL']
            Report_Dictionary["LDL_HDL_RATIO"] = LDL_HDL_RATIO
        else:
            Report_Dictionary["LDL_HDL_RATIO"] = None


        if 'VLDL CHOLESTEROL' in extracted_Dictionary.keys():
            VLDL_CHOLESTEROL = extracted_Dictionary['VLDL CHOLESTEROL']
            Report_Dictionary["VLDL_CHOLESTEROL"] = VLDL_CHOLESTEROL
        else:
            Report_Dictionary["VLDL_CHOLESTEROL"] = None

        if 'NONHDL CHOLESTEROL' in extracted_Dictionary.keys():
            NON_HDL_CHOLESTEROL = extracted_Dictionary['NONHDL CHOLESTEROL']
            Report_Dictionary["NON_HDL_CHOLESTEROL"] = NON_HDL_CHOLESTEROL
        else:
            Report_Dictionary["NON_HDL_CHOLESTEROL"] = None


        if 'TOTAL TRIIODOTHYRONINE (T)' in extracted_Dictionary.keys():
            TOTAL_TRIIODOTHYRONINE = extracted_Dictionary['TOTAL TRIIODOTHYRONINE (T)']
            Report_Dictionary["TOTAL_TRIIODOTHYRONINE"] = TOTAL_TRIIODOTHYRONINE
        else:
            Report_Dictionary["TOTAL_TRIIODOTHYRONINE"] = None

        if 'TOTAL THYROXINE (T)' in extracted_Dictionary.keys():
            TOTAL_THYROXINE = extracted_Dictionary['TOTAL THYROXINE (T)']
            Report_Dictionary["TOTAL_THYROXINE"] = TOTAL_THYROXINE
        else:
            Report_Dictionary["TOTAL_THYROXINE"] = None

        if 'THYROID STIMULATING HORMONE (TSH)' in extracted_Dictionary.keys():
            THYROID_STIMULATING_HORMONE = extracted_Dictionary['THYROID STIMULATING HORMONE (TSH)']
            Report_Dictionary["THYROID_STIMULATING_HORMONE"] = THYROID_STIMULATING_HORMONE
        else:
            Report_Dictionary["THYROID_STIMULATING_HORMONE"] = None

        if 'BLOOD UREA NITROGEN (BUN)' in extracted_Dictionary.keys():
            BLOOD_UREA_NITROGEN = extracted_Dictionary['BLOOD UREA NITROGEN (BUN)']
            Report_Dictionary["BLOOD_UREA_NITROGEN"] = BLOOD_UREA_NITROGEN
        else:
            Report_Dictionary["BLOOD_UREA_NITROGEN"] = None

        if 'CREATININE SERUM' in extracted_Dictionary.keys():
            CREATININE_SERUM = extracted_Dictionary['CREATININE SERUM']
            Report_Dictionary["CREATININE_SERUM"] = CREATININE_SERUM
        else:
            Report_Dictionary["CREATININE_SERUM"] = None

        if 'BUN SRCREATININE' in extracted_Dictionary.keys():
            BUN_SR_CREATININE_RATIO = extracted_Dictionary['BUN SRCREATININE']
            Report_Dictionary["BUN_SR_CREATININE_RATIO"] = BUN_SR_CREATININE_RATIO
        else:
            Report_Dictionary["BUN_SR_CREATININE_RATIO"] = None

        if 'CALCIUM' in extracted_Dictionary.keys():
            CALCIUM = extracted_Dictionary['CALCIUM']
            Report_Dictionary["CALCIUM"] = CALCIUM
        else:
            Report_Dictionary["CALCIUM"] = None

        if 'URIC ACID' in extracted_Dictionary.keys():
            URIC_ACID = extracted_Dictionary['URIC ACID']
            Report_Dictionary["URIC_ACID"] = URIC_ACID
        else:
            Report_Dictionary["URIC_ACID"] = None


        if 'EST GLOMERULAR FILTRATION RATE' in extracted_Dictionary.keys():
            EST_GLOMERULAR_FILTRATION_RATE = extracted_Dictionary['EST GLOMERULAR FILTRATION RATE']
            Report_Dictionary["EST_GLOMERULAR_FILTRATION_RATE"] = EST_GLOMERULAR_FILTRATION_RATE
        else:
            Report_Dictionary["EST_GLOMERULAR_FILTRATION_RATE"] = None
