# %%
import pandas as pd
import json

# %%
#Convert PDF to Images , each page converted into seprate image

from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

# %%
# Function to convert to Strings  
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
#function to find all floats values from list
def solve(lis):
    for x in lis:
        try:
            float(x)
            return True
        except:
            return False

# %%
# OCR Works Here

try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
  
    text = pytesseract.pytesseract.image_to_string(Image.open(filename))
    return text  # Then we will print the text in the image

# %%
# Main Functions for OCR
images = convert_from_path('test2.pdf')
img=[]
texts = []
for i, image in enumerate(images):
    fname = "image" + str(i) + ".png"
    img.append(fname)
    
    image.save(fname, "PNG")
    text  =  ocr_core(fname)
    
    text = listToString(text)  
    texts.append(text)
    text1 = listToString(texts)

# %%
text1
# Out:
# 'PROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\n   \n\n@JNGsP\n\n \n\nabby Thyrocare’\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\ncentiieAte no: C2407\n\nThink Thyroid. Think Thyrocare.\n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\nNAME\n\n: DR G SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT\n\n \n\n \n\n \n\n \n\n \n\n \n\n. (18900), INDIRA DIAGNOSTIC\nREF. BY + SELF CENTRE, NARSIPATNAM, ANDHRA\nTEST ASKED : ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME TECHNOLOGY VALUE UNITS\nHbA1c - (HPLC - NGSP Certified)\nH.P.L.C 5.9 %\nReference Range :\nReference Range: As per ADA Guidelines Guidance For Known Diabetics\nBelow 5.7% : Normal Below 6.5% : Good Control\n5.7% - 6.4% : Prediabetic 6.5% - 7% : Fair Control\n>=6.5% : Diabetic 7.0% - 8% : Unsatisfactory Control\n>8% : Poor Control\nMethod : Fully Automated H.P.L.C. using Biorad Variant II Turbo, NGSP Certified.\nAVERAGE BLOOD GLUCOSE (ABG) CALCULATED 123 mg/dl\n\nReference Range :\n\n90 - 120 mg/dl : Good Control\n\n121 - 150 mg/dl : Fair Control\n\n151 - 180 mg/dl : Unsatisfactory Control\n> 180 mg/dl : Poor Control\n\n \n\n \n\n \n\n \n\nMethod : Derived from HBA1c_ values\nPlease correlate with clinical conditions.\n\n \n\nSample Collected on (SCT) :21 Jul 2019 06:00\n\nSample Received on (SRT)\nReport Released on (RRT)\n\nSample Type vert\nLabcode 3)\nPereode @uty\n\n22 Jul 2019 00:06 ac tt?\n122 Jul 2019 03:42 Oe\n\n#EDTA Dr.Prachi Sinkar MD(Path) Dr.Caesar Sengupta MD(Micro)\n1 2107031728/A6750 .\n\nPage : 1 of 19\n:M9261472\n\x0cPROCESSED AT:\nThyrocare\n\nD-37/1,TTC MIDC,Turbhe,\nNavi Mumbai-400 703\n\nCAP\nACCREDITED\n\nCOLLEGE of AMERICAN PATHOLOGISTS\n\n \n\nThyrocare’\n\nThink Thyroid. Think Thyrocare.\n\n \n\nCorporate Office : Thyrocare Technologies Limited 9 D-37/3, TTC MIDC, Turbhe, Navi Mumbai - 400703\n© 022 - 3090 0000 / 41252525 8691866066 4 wellness@thyrocare.com (www.thyrocare.com\n\n \n\n \n\nNAME : DRG SANTHI PRIYA (28Y/F) SAMPLE COLLECTED AT_:\nREF. BY : SELF (18900), INDIRA DIAGNOSTIC\nCENTRE,NARSIPATNAM, ANDHRA\nTEST ASKED ELEMENTS 22 (TOXIC AND NUTRIENTS),HBA,HEMOGRAM PRADESH,531116\n- 6 PART (DIFF)\nTEST NAME VALUE UNITS REFERENCE RANGE\nTOTAL LEUCOCYTES COUNT 8.3 X103/uL  4.0-10.0\nNEUTROPHILS 52.2 % 40-80\nLYMPHOCYTE PERCENTAGE 42.8 % 20.0-40.0\nMONOCYTES 3.3 % 0.0-10.0\nEOSINOPHILS 1.3 % 0.0-6.0\nBASOPHILS 0.2 % <2\nIMMATURE GRANULOCYTE PERCENTAGE(IG%) 0.2 % 0.0-0.4\nNEUTROPHILS - ABSOLUTE COUNT 4.33 X 103 / UL 2.0-7.0\nLYMPHOCYTES - ABSOLUTE COUNT 3.55 X 103 / pL 1.0-3.0\nMONOCYTES - ABSOLUTE COUNT 0.27 X 103 / ul 0.2-1.0\nBASOPHILS - ABSOLUTE COUNT 0.02 X 103 / ul 0.02-0.1\nEOSINOPHILS - ABSOLUTE COUNT 0.11 X 103 / UL 0.02-0.5\nIMMATURE GRANULOCYTES(IG) 0.02 X 103 / UL 0.0-0.3\nTOTAL RBC 4.83 X1046/pL 3.9-4.8\nNUCLEATED RED BLOOD CELLS Nil X 103 / ul <0.01\nNUCLEATED RED BLOOD CELLS % Nil % <0.01\nHEMOGLOBIN 9.4 g/dL 12.0-15.0\nHEMATOCRIT(PCV) 37.2 % 36.0-46.0\nMEAN CORPUSCULAR VOLUME(MCV) 77 fL 83.0-101.0\nMEAN CORPUSCULAR HEMOGLOBIN(MCH) 19.5 pq 27.0-32.0\nMEAN CORP.HEMO.CONC(MCHC) 25.3 g/dL 31.5-34.5\nRED CELL DISTRIBUTION WIDTH - SD(RDW-SD) 54.5 fL 39.0-46.0\nRED CELL DISTRIBUTION WIDTH (RDW-CV) 19.7 % 11.6-14.0\nPLATELET DISTRIBUTION WIDTH(PDW) 10.8 fL 9.6-15.2\nMEAN PLATELET VOLUME(MPV) 10.2 fL 6.5-12\nPLATELET COUNT 518 X 103 / pL 150-400\nPLATELET TO LARGE CELL RATIO(PLCR) 25.6 % 19.7-42.4\nPLATELETCRIT(PCT) 0.53 % 0.19-0.39\nRemarks: = Alert!!! RBCs:Moderate anisocytosis mild poikilocytosis. Predominantly normocytic normochromic with microcytes &\n\novalocytes.\nPlease Correlate with clinical conditions.\nMethod : Fully automated bidirectional analyser (6 Part Differential SYSMEX XN-1000)\n(This device performs hematology analyses according to the Hydrodynamic Focussing (DC method), Flow\nCytometry Method (using a semicond ...

# %%
word_list = [
    'H.P.L.C',
    'AVERAGE BLOOD GLUCOSE (ABG)',
    'TOTAL LEUCOCYTES COUNT',
    'NEUTROPHILS',
    'LYMPHOCYTE PERCENTAGE',
    'MONOCYTES',
    'EOSINOPHILS',
    'BASOPHILS',
    'IMMATURE GRANULOCYTE PERCENTAGE(IG%)',
    'NEUTROPHILS - ABSOLUTE COUNT',
    'LYMPHOCYTES - ABSOLUTE COUNT',
    'MONOCYTES - ABSOLUTE COUNT',
    'BASOPHILS - ABSOLUTE COUNT',
    'EOSINOPHILS - ABSOLUTE COUNT',
    'IMMATURE GRANULOCYTES(IG)',
    'TOTAL RBC',
    'HEMOGLOBIN',
    'HEMATOCRIT(PCV)',
    'MEAN CORPUSCULAR VOLUME(MCV)',
    'MEAN CORPUSCULAR HEMOGLOBIN(MCH)',
    'MEAN CORP.HEMO.CONC(MCHC)',
    'RED CELL DISTRIBUTION WIDTH - SD(RDW-SD)',
    'RED CELL DISTRIBUTION WIDTH (RDW-CV)',
    'PLATELET DISTRIBUTION WIDTH(PDW)',
    'MEAN PLATELET VOLUME(MPV)',
    'PLATELET COUNT',
    'PLATELET TO LARGE CELL RATIO(PLCR)',
    'PLATELETCRIT(PCT)',
    'ARSENIC',
    'CADMIUM',
    'MERCURY',
    'LEAD',
    'CHROMIUM',
    'BARIUM',
    'COBALT',
    'CAESIUM',
    'THALLIUM',
    'URANIUM',
    'STRONTIUM',
    'ANTIMONY',
    'TIN',
    'MOLYBDENUM',
    'SILVER',
    'VANADIUM',
    'BERYLLIUM',
    'BISMUTH',
    'SELENIUM',
    'ALUMINIUM',
    'NICKEL',
    'MANGANESE',
    'HOMOCYSTEINE',
    'CYSTATIN C',
    'LIPOPROTEIN',
    'VITAMIN D',
    'VITAMIN B-12',
    'APOLIPOPROTEIN - A1 (APO-A1)',
    'APOLIPOPROTEIN - B (APO-B)',
    'APO B / APO A1 RATIO (APO B/A1)',
    'HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)',
    'SERUM COPPER',
    'SERUM ZINC',
    'TESTOSTERONE',
    'IRON',
    'TOTAL IRON BINDING CAPACITY (TIBC)',
    '% TRANSFERRIN SATURATION',
    'TRANSFERRIN SATURATION',
    'ALKALINE PHOSPHATASE',
    'BILIRUBIN - TOTAL',
    'BILIRUBIN -DIRECT',
    'BILIRUBIN (INDIRECT)',
    'GAMMA GLUTAMYL TRANSFERASE (GGT)',
    'ASPARTATE AMINOTRANSFERASE (SGOT )',
    'ALANINE TRANSAMINASE (SGPT)',
    'PROTEIN - TOTAL',
    'ALBUMIN - SERUM',
    'SERUM ALB/GLOBULIN RATIO',
    'SERUM GLOBULIN',
    'TOTAL CHOLESTEROL',
    'HDL CHOLESTEROL - DIRECT',
    'LDL CHOLESTEROL - DIRECT',
    'TRIGLYCERIDES',
    'TC/ HDL CHOLESTEROL RATIO',
    'LDL / HDL RATIO',
    'VLDL CHOLESTEROL',
    'NON-HDL CHOLESTEROL',
    'TOTAL TRIIODOTHYRONINE (T3)',
    'TOTAL THYROXINE',
    'THYROID STIMULATING HORMONE',
    'BLOOD UREA NITROGEN (BUN)',
    'CREATININE - SERUM',
    'BUN / SR.CREATININE RATIO',
    'CALCIUM',
    'URIC ACID',
    'EST. GLOMERULAR FILTRATION RATE (eGFR)',
    'Vitamin',
    ]

# %%
word_list = [
    'ARSENIC',
    'CADMIUM',
    'MERCURY',
    'LEAD',
    'CHROMIUM',
    'BARIUM',
    'COBALT',
    'CAESIUM',
    'THALLIUM',
    'URANIUM',
    'STRONTIUM',
    'ANTIMONY',
    'TIN',
    'MOLYBDENUM',
    'SILVER',
    'VANADIUM',
    'BERYLLIUM',
    'BISMUTH',
    'SELENIUM',
    'ALUMINIUM',
    'NICKEL',
    'MANGANESE',
    'HOMOCYSTEINE',
    'CYSTATIN C',
    'LIPOPROTEIN',
    'VITAMIN D',
    'VITAMIN B-12',
    'APOLIPOPROTEIN - A1 (APO-A1)',
    'APOLIPOPROTEIN - B (APO-B)',
    'APO B / APO A1 RATIO (APO B/A1)',
    'HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)',
    'SERUM COPPER',
    'SERUM ZINC',
    'TESTOSTERONE',
    'IRON'
    ]

# %%
# Wordlist to Delete Useless data from the list
stopwords = ['0.02-0.1','3.9-4.8','58-159','X103pL','X103/pL','-','4.0-10.0','X103/uL','2.0-7.0','1.0-3.0','%','CLIA','ng/d|',
                 'C.LI.A','HIU/ml','C.L.L.A','(SGOT','(SGOT)','CLA','<','<2','20.0-40.0','0.0-0.4','ul','39.0-46.0','0.0-0.3',
                '20-40','PERCENTAGE(IG%)','0-0.5','40-80','0.0-6.0','0.0-6.0','0-0.1','mg/dl','CLIA','HIU/ml','U/I','12.0-15.0',
                '<2','0-10','<','>', 'X', '103', '/', 'pL', '0.2-1','X1046/pL','<0.01','g/dL','13-17','fl','83-101','C.M.1.A','ng/di',
                'pq', '27-32','g/dL', '31.5-34.5','0-0.3','40-50','fL', '39-46','11.6-14','9.6-15.2','4.5-5.5','g/dl',
                 'IMMUNOTURBIDIMETRY','ICP-MS','ug/l','<5','ug/I','0.10 - 1.50','<1','<4','<4','<15','yumol/L',
             'mg/L','(A)','[LP(A)]','pg/ml','mg/dL','ng/dL','Hg/dl',
               'PHOTOMETRY','CALCULATED','(eGFR)', 'Ratio', '9:1-23:1', '(mg/dl)','0.02-0.5','X10%6/uL =:','36.0-46.0',
                 'mL/min/1.73', 'm2','uIU/ml', '0.3-5.5','85-130','35-80','125-200','gm/dL', '2.5-3.4','u/|', '<35','(',')','0.35 - 4.94',
                'u/I', '<55','gm/dl', '3.2-4.8''5.7-8.2','6.5-12','19.7-42.4','0.19-0.39','0.3-1.2','0-0.9','5.7-8.2',
                '3.2-4.8','3-5', 'ng/dl', '60-200','ug/dl', '4.5-12','7-25','0.6-1.1','8.8-10.6','-7.3','5-40','U/L','1.5-3.5',
                'RATIO','150-400','4.0-10.0','25-200','B12 pg/mL 911','B12' ,'pg/mL','911','0.2-1.0','uL','0.0-10.0','0.02-0.1',
                '83.0-101.0','27.0-32.0','3.2-6.1','0.5-0.8','C.M.1.A 0.35','C.M.1.A ng/di','ma/dl','0.9-2','<31','11.6-14.0','27.0-32.0','X%/uL','=:','=:',

            ]

# %%
# Main function to collect the data

data = []
for row in text1.split('\n'):
    for word in list(word_list):
        if row.startswith(word):
            word = row.split()
            word = word
            for word_name in list(word):  
                if word_name in stopwords:

                    word.remove(word_name)
 
            for i in word:
                if  solve(i):
                    null = i
                    word.remove(null)
                    i = float(i)
            
            word = [x for x in word if not isinstance(x, int)]   
            word = [' '.join(word)]
            print(word)
            word.append(i)
            #word.remove(str(i))
            print(word)
            data.append(word)
# Out:
# ['ARSENIC']
# ['ARSENIC', 1.05]
# ['CADMIUM 1.5']
# ['CADMIUM 1.5', 0.37]
# ['MERCURY']
# ['MERCURY', 0.3]
# ['LEAD 150']
# ['LEAD 150', 40.95]
# ['CHROMIUM 30']
# ['CHROMIUM 30', 1.18]
# ['BARIUM 30']
# ['BARIUM 30', 1.7]
# ['COBALT 0.10']
# ['COBALT 0.10', 1.5]
# ['CAESIUM']
# ['CAESIUM', 1.48]
# ['THALLIUM']
# ['THALLIUM', 0.03]
# ['URANIUM']
# ['URANIUM', 0.08]
# ['STRONTIUM 8']
# ['STRONTIUM 8', 38.0]
# ['ANTIMONY 0.10']
# ['ANTIMONY 0.10', 18.0]
# ['TIN']
# ['TIN', 0.31]
# ['MOLYBDENUM 0.70']
# ['MOLYBDENUM 0.70', 4.0]
# ['SILVER']
# ['SILVER', 1.07]
# ['VANADIUM 0.8']
# ['VANADIUM 0.8', 0.2]
# ['BERYLLIUM 0.10']
# ['BERYLLIUM 0.10', 0.8]
# ['BISMUTH 0.10']
# ['BISMUTH 0.10', 0.8]
# ['SELENIUM 60']
# ['SELENIUM 60', 340.0]
# ['ALUMINIUM 30']
# ['ALUMINIUM 30', 9.32]
# ['NICKEL']
# ['NICKEL', 3.64]
# ['MANGANESE 7.10']
# ['MANGANESE 7.10', 20.0]
# ['HOMOCYSTEINE']
# ['HOMOCYSTEINE', 13.7]
# ['HOMOCYSTEINE IS LINKED TO INCREASED RISK OF PREMATURE CORONARY ARTERY DISEASE, STROKE AND']
# ['HOMOCYSTEINE IS LINKED TO INCREASED RISK OF PREMATURE CORONARY ARTERY DISEASE, STROKE AND', 'AND']
# ['CYSTATIN C']
# ['CYSTATIN C', 0.98]
# ['CYSTATIN C, IS A SMALL -KDA PROTEIN AND IS A MEMBER OF THE CYSTEINE PROTEINASE INHIBITOR FAMILY, IT']
# ['CYSTATIN C, IS A SMALL -KDA PROTEIN AND IS A MEMBER OF THE CYSTEINE PROTEINASE INHIBITOR FAMILY, IT', 'IT']
# ['LIPOPROTEIN']
# ['LIPOPROTEIN', 55.5]
# ['VITAMIN B-12']
# ['VITAMIN B-12', 211.0]
# ['APOLIPOPROTEIN A1 (APO-A1)']
# ['APOLIPOPROTEIN A1 (APO-A1)', 115.0]
# ['APOLIPOPROTEIN B (APO-B)']
# ['APOLIPOPROTEIN B (APO-B)', 80.0]
# ['HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)']
# ['HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)', 6.2]
# ['SERUM COPPER yg/dL']
# ['SERUM COPPER yg/dL', 119.8]
# ['SERUM ZINC yg/dL']
# ['SERUM ZINC yg/dL', 75.2]
# ['TESTOSTERONE C.L.I.A']
# ['TESTOSTERONE C.L.I.A', 16.02]
# ['IRON']
# ['IRON', 20.2]

# %%
data1 = dict(data)

# %%
data1['NEUTROPHILS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-80429ae14d88> in <module>
# ----> 1 data1['NEUTROPHILS']
#
# KeyError: 'NEUTROPHILS'

# %%
columns_name = ['Keywords','Values']

# %%
df = pd.DataFrame(data)
df.head(30)
# Out:
#                                                     0      1
# 0                                             ARSENIC   1.05
# 1                                         CADMIUM 1.5   0.37
# 2                                             MERCURY    0.3
# 3                                            LEAD 150  40.95
# 4                                         CHROMIUM 30   1.18
# 5                                           BARIUM 30    1.7
# 6                                         COBALT 0.10    1.5
# 7                                             CAESIUM   1.48
# 8                                            THALLIUM   0.03
# 9                                             URANIUM   0.08
# 10                                        STRONTIUM 8     38
# 11                                      ANTIMONY 0.10     18
# 12                                                TIN   0.31
# 13                                    MOLYBDENUM 0.70      4
# 14                                             SILVER   1.07
# 15                                       VANADIUM 0.8    0.2
# 16                                     BERYLLIUM 0.10    0.8
# 17                                       BISMUTH 0.10    0.8
# 18                                        SELENIUM 60    340
# 19                                       ALUMINIUM 30   9.32
# 20                                             NICKEL   3.64
# 21                                     MANGANESE 7.10     20
# 22                                       HOMOCYSTEINE   13.7
# 23  HOMOCYSTEINE IS LINKED TO INCREASED RISK OF PR...    AND
# 24                                         CYSTATIN C   0.98
# 25  CYSTATIN C, IS A SMALL -KDA PROTEIN AND IS A M...     IT
# 26                                        LIPOPROTEIN   55.5
# 27                                       VITAMIN B-12    211
# 28                         APOLIPOPROTEIN A1 (APO-A1)    115
# 29                           APOLIPOPROTEIN B (APO-B)     80

# %%
df.columns = ['Keys','Values']

# %%
df
# Out:
#                                                  Keys Values
# 0                                             ARSENIC   1.05
# 1                                         CADMIUM 1.5   0.37
# 2                                             MERCURY    0.3
# 3                                            LEAD 150  40.95
# 4                                         CHROMIUM 30   1.18
# 5                                           BARIUM 30    1.7
# 6                                         COBALT 0.10    1.5
# 7                                             CAESIUM   1.48
# 8                                            THALLIUM   0.03
# 9                                             URANIUM   0.08
# 10                                        STRONTIUM 8     38
# 11                                      ANTIMONY 0.10     18
# 12                                                TIN   0.31
# 13                                    MOLYBDENUM 0.70      4
# 14                                             SILVER   1.07
# 15                                       VANADIUM 0.8    0.2
# 16                                     BERYLLIUM 0.10    0.8
# 17                                       BISMUTH 0.10    0.8
# 18                                        SELENIUM 60    340
# 19                                       ALUMINIUM 30   9.32
# 20                                             NICKEL   3.64
# 21                                     MANGANESE 7.10     20
# 22                                       HOMOCYSTEINE   13.7
# 23  HOMOCYSTEINE IS LINKED TO INCREASED RISK OF PR...    AND
# 24                                         CYSTATIN C   0.98
# 25  CYSTATIN C, IS A SMALL -KDA PROTEIN AND IS A M...     IT
# 26                                        LIPOPROTEIN   55.5
# 27                                       VITAMIN B-12    211
# 28                         APOLIPOPROTEIN A1 (APO-A1)    115
# 29                           APOLIPOPROTEIN B (APO-B)     80
# 30       HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)    6.2
# 31                                 SERUM COPPER yg/dL  119.8
# 32                                   SERUM ZINC yg/dL   75.2
# 33                         TESTOSTERONE C.L.I.A ng/dL  16.02
# 34                                         IRON Hg/dl   20.2

# %%
df['Keys'] = df['Keys'].str.replace('\d+', '')

# %%
df.head(60)
# Out:
#                                                  Keys Values
# 0                                             ARSENIC   1.05
# 1                                           CADMIUM .   0.37
# 2                                             MERCURY    0.3
# 3                                               LEAD   40.95
# 4                                           CHROMIUM    1.18
# 5                                             BARIUM     1.7
# 6                                            COBALT .    1.5
# 7                                             CAESIUM   1.48
# 8                                            THALLIUM   0.03
# 9                                             URANIUM   0.08
# 10                                         STRONTIUM      38
# 11                                         ANTIMONY .     18
# 12                                                TIN   0.31
# 13                                       MOLYBDENUM .      4
# 14                                             SILVER   1.07
# 15                                         VANADIUM .    0.2
# 16                                        BERYLLIUM .    0.8
# 17                                          BISMUTH .    0.8
# 18                                          SELENIUM     340
# 19                                         ALUMINIUM    9.32
# 20                                             NICKEL   3.64
# 21                                        MANGANESE .     20
# 22                                       HOMOCYSTEINE   13.7
# 23  HOMOCYSTEINE IS LINKED TO INCREASED RISK OF PR...    AND
# 24                                         CYSTATIN C   0.98
# 25  CYSTATIN C, IS A SMALL -KDA PROTEIN AND IS A M...     IT
# 26                                        LIPOPROTEIN   55.5
# 27                                         VITAMIN B-    211
# 28                           APOLIPOPROTEIN A (APO-A)    115
# 29                           APOLIPOPROTEIN B (APO-B)     80
# 30       HIGH SENSITIVITY C-REACTIVE PROTEIN (HS-CRP)    6.2
# 31                                 SERUM COPPER yg/dL  119.8
# 32                                   SERUM ZINC yg/dL   75.2
# 33                         TESTOSTERONE C.L.I.A ng/dL  16.02
# 34                                         IRON Hg/dl   20.2
